# %% [markdown]
# # `Create Database for MIMIC Dataset`
#
# ### Access Data Files
# - [ ] file1
# - [ ] file2
#
# ### Create Databases
# - [ ] table1
# - [ ] table2
#
# ### Read Aquisition Parameters
# - [ ] table1

# %% [markdown]
# ## 1. `Define Data Files`

# %%
print("Hello, World!")
# Out:
# Hello, World!
