# %% [markdown]
# # 1 `MIMIC-IV`

# %% [markdown]
# ## 1.1 `Download Data`

# %%
import os, sys, subprocess
from getpass import getpass

username = input("Enter PhysioNet username: ")
password = getpass("Enter PhysioNet password: ")
location = input("Enter download location (full path): ")

os.makedirs(location, exist_ok=True)
os.chdir(location)

url = "https://physionet.org/files/mimiciv/3.1/"

# Force progress bar output even in Jupyter
cmd = [
    "wget",
    "-r", "-N", "-c", "-np",
    "--show-progress", "--progress=bar:force:noscroll",
    "--user", username,
    "--password", password,
    url,
]

# Stream wget output live so progress is visible
proc = subprocess.Popen(
    cmd,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1,
)

for line in proc.stdout:
    print(line, end="")
    sys.stdout.flush()

proc.wait()
if proc.returncode == 0:
    print("\n✅ Download complete.")
else:
    print(f"\n❌ wget exited with code {proc.returncode}")

# %% [markdown]
# ## 1.2 `Check files`

# %%
import os
import hashlib
from pathlib import Path

# --- Step 1: Define and check the base location ---
# location = Path("E:/Data/MIMIC_IV")  # example path — adjust for your setup
if 'location' not in locals():
    location = Path(input("Enter download location (full path): "))

print(f"\n✅ Checking data in folder: {location}")


# --- Step 2: Define checksum file path ---
checksum_file = location / "SHA256SUMS.txt"
if not checksum_file.exists():
    raise FileNotFoundError(f"Checksum file not found: {checksum_file}")

# --- Step 3: Load checksums ---
checksums = {}
with open(checksum_file, "r", encoding="utf-8") as f:
    for line in f:
        hash_val, rel_path = line.split(" ")
        cur_path = location / rel_path.strip()
        checksums[ cur_path ] = hash_val.strip()

print(f"Found {len(checksums)} entries in {checksum_file.name}")


# --- Step 4: Verify files ---
def sha256sum(file_path):
    """Compute SHA256 hash for a file."""
    h = hashlib.sha256()
    with open(file_path, "rb") as f:
        for chunk in iter(lambda: f.read(8192), b""):
            h.update(chunk)
    return h.hexdigest()

results = []
for rel_path, expected_hash in checksums.items():
    file_path = location / rel_path
    if not file_path.exists():
        results.append((rel_path, "❌ Missing", None))
        continue

    actual_hash = sha256sum(file_path)
    if actual_hash.lower() == expected_hash.lower():
        results.append((rel_path, "✅ OK", actual_hash))
    else:
        results.append((rel_path, "⚠️ Mismatch", actual_hash))

# --- Step 5: Display results ---
print("\n=== Verification Report ===")
for rel_path, status, actual in results:
    print(f"{status:10s}  {rel_path}")

# Optional: summary counts
ok = sum(1 for r in results if "OK" in r[1])
missing = sum(1 for r in results if "Missing" in r[1])
mismatch = sum(1 for r in results if "Mismatch" in r[1])
print(f"\nSummary: {ok} OK, {missing} Missing, {mismatch} Mismatch\n")

# %% [markdown]
# ## 1.3. `UnZip Files`

# %%
import os
import gzip
import shutil
from pathlib import Path

# --- 0) Base folder ---
if 'location' not in locals():
    location = Path(input("Enter download location (full path): ").strip()).expanduser().resolve()

print(f"\n📁 Using folder: {location}")

checksum_file = location / "SHA256SUMS.txt"
if not checksum_file.exists():
    raise FileNotFoundError(f"Checksum file not found: {checksum_file}")

# --- 1) Read relative paths from SHA256SUMS.txt ---
rel_paths = []
with open(checksum_file, "r", encoding="utf-8") as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        # Robust split: first token is hash, the rest is the path (may contain spaces)
        parts = line.split(maxsplit=1)
        if len(parts) != 2:
            continue
        _, rel_path = parts
        rel_paths.append(rel_path.strip())

# --- 2) Filter only .gz files ---
gz_paths = [rp for rp in rel_paths if rp.endswith(".gz")]
print(f"Found {len(gz_paths)} .gz files to process")

# --- 3) Decompress settings ---
OVERWRITE = False  # set to True to overwrite existing outputs
CHUNK_SIZE = 1024 * 1024  # 1 MB chunks

# --- 4) Decompress loop ---
done = 0
skipped = 0
missing = 0
failed = 0
log = []

for rp in gz_paths:
    src = (location / rp).resolve()
    # Destination: remove the final ".gz" only
    dst = src.with_name(src.name[:-3])  # e.g., "file.csv.gz" -> "file.csv"

    if not src.exists():
        missing += 1
        log.append(("❌ Missing", rp))
        continue

    # Ensure destination folder exists
    dst.parent.mkdir(parents=True, exist_ok=True)

    if dst.exists() and not OVERWRITE:
        skipped += 1
        log.append(("⏩ Skipped (exists)", str(dst.relative_to(location))))
        continue

    try:
        with gzip.open(src, "rb") as f_in, open(dst, "wb") as f_out:
            shutil.copyfileobj(f_in, f_out, length=CHUNK_SIZE)
        done += 1
        log.append(("✅ Unzipped", f"{rp}  ->  {dst.relative_to(location)}"))
    except Exception as e:
        failed += 1
        log.append(("⚠️ Failed", f"{rp}  ({e})"))

# --- 5) Report ---
print("\n=== Decompression Report ===")
for status, msg in log:
    print(f"{status:16s} {msg}")

print(
    f"\nSummary: {done} unzipped, {skipped} skipped, {missing} missing, {failed} failed.\n"
    f"Outputs are written next to sources (e.g., *.csv beside *.csv.gz)."
)

# %% [markdown]
# # 2 `MIMIC-CXR`

# %% [markdown]
# ## 2.1 `Download Data`

# %%
import os, sys, subprocess
from getpass import getpass

username = input("Enter PhysioNet username: ")
password = getpass("Enter PhysioNet password: ")
location = input("Enter download location (full path): ")

os.makedirs(location, exist_ok=True)
os.chdir(location)

"""
#url = "https://physionet.org/files/mimic-cxr/2.1.0/files/p10/"
url = "https://physionet.org/files/mimic-cxr/2.1.0/"

# Download data parent folder excluding pXX subfolders
# Force progress bar output even in Jupyter
cmd = [
    "wget",
    "-r", "-N", "-c", "-np",
    "--show-progress", "--progress=bar:force:noscroll",
    "--reject-regex", ".*/files/p[0-9]+",
    "--user", username,
    "--password", password,
    url,
]

# Stream wget output live so progress is visible
proc = subprocess.Popen(
    cmd,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1,
)

for line in proc.stdout:
    print(line, end="")
    sys.stdout.flush()

proc.wait()
if proc.returncode == 0:
    print("\n✅ Root Folder download complete.")
else:
    print(f"\n❌ wget exited with code {proc.returncode}")

"""

url = "https://physionet.org/files/mimic-cxr/2.1.0/"
cmd = [
    "wget",
    "-r", "-N", "-c", "-np",
    "--show-progress", "--progress=bar:force:noscroll",
#    "--accept-regex", "(/files/|/files/p10/|/files/p10/p1000.*)",
    "--user", username,
    "--password", password,
    url,
]

# Stream wget output live so progress is visible
proc = subprocess.Popen(
    cmd,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1,
)

for line in proc.stdout:
    print(line, end="")
    sys.stdout.flush()

proc.wait()
if proc.returncode == 0:
    print("\n✅ Files folder download complete.")
else:
    print(f"\n❌ wget exited with code {proc.returncode}")
# Out:
# --2025-11-10 12:30:14--  https://physionet.org/files/mimic-cxr/2.1.0/
# Resolving physionet.org (physionet.org)... 18.18.42.54
# Connecting to physionet.org (physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="PhysioNet", charset="UTF-8"
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'physionet.org/files/mimic-cxr/2.1.0/index.html'
#
#
# physionet.org/files     [<=>                 ]       0  --.-KB/s
# physionet.org/files     [ <=>                ]   1.05K  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-11-10 12:30:15 (198 MB/s) - 'physionet.org/files/mimic-cxr/2.1.0/index.html' saved [1079]
#
# Loading robots.txt; please ignore errors.
# --2025-11-10 12:30:15--  https://physionet.org/robots.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 22 [text/plain]
# Saving to: 'physionet.org/robots.txt'
#
#
# physionet.org/robot   0%[                    ]       0  --.-KB/s
# physionet.org/robot 100%[===================>]      22  --.-KB/s    in 0s
#
# 2025-11-10 12:30:15 (15.0 MB/s) - 'physionet.org/robots.txt' saved [22/22]
#
# --2025-11-10 12:30:15--  https://physionet.org/files/mimic-cxr/2.1.0/files/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'physionet.org/files/mimic-cxr/2.1.0/files/index.html'
#
#
# physionet.org/files     [<=>                 ]       0  --.-KB/s
# physionet.org/files     [ <=>                ]   1.30K  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-11-10 12:30:15 (383 MB/s) - 'physionet.org/files/mimic-cxr/2.1.0/files/index.html' saved [1327]
#
# --2025-11-10 12:30:15--  https://physionet.org/files/mimic-cxr/2.1.0/LICENSE.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2518 (2.5K) [text/plain]
# Saving to: 'physionet.org/files/mimic-cxr/2.1.0/LICENSE.txt'
#
#
# physionet.org/files   0%[                    ]       0  --.-KB/s
# physionet.org/files 100%[===================>]   2.46K  --.-KB/s    in 0s
#
# 2025-11-10 12:30:15 (1.68 GB/s) - 'physionet.org/files/mimic-cxr/2.1.0/LICENSE.txt' saved [2518/2518]
#
# --2025-11-10 12:30:15--  https://physionet.org/files/mimic-cxr/2.1.0/SHA256SUMS.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 76859934 (73M) [text/plain]
# Saving to: 'physionet.org/files/mimic-cxr/2.1.0/SHA256SUMS.txt'
#
#
# physionet.org/files   0%[                    ]       0  --.-KB/s
# physionet.org/files   0%[                    ] 111.64K   481KB/s
# physionet.org/files   0%[                    ] 159.64K   322KB/s
# physionet.org/files   0%[                    ] 335.64K   482KB/s
# physionet.org/files   0%[                    ] 415.64K   423KB/s
# physionet.org/files   0%[                    ] 575.64K   480KB/s
# physionet.org/files   1%[                    ] 751.64K   523KB/s
# physionet.org/files   1%[                    ] 847.64K   503KB/s
# physionet.org/files   1%[                    ] 927.64K   490KB/s
# physionet.org/files   1%[                    ]   1008K   479KB/s
# physionet.org/files   1%[                    ]   1.08M   473KB/s
# physionet.org/files   1%[                    ]   1.16M   467KB/s
# physionet.org/files   1%[                    ]   1.23M   449KB/s
# physionet.org/files   1%[                    ]   1.34M   453KB/s    eta 2m 43s
# physionet.org/files   1%[                    ]   1.42M   444KB/s    eta 2m 43s
# physionet.org/files   2%[                    ]   1.50M   440KB/s    eta 2m 43s
# physionet.org/files   2%[                    ]   1.58M   436KB/s    eta 2m 43s
# physionet.org/files   2%[                    ]   1.67M   420KB/s    eta 2m 53s
# physionet.org/files   2%[                    ]   1.78M   440KB/s    eta 2m 53s
# physionet.org/files   2%[                    ]   1.84M   411KB/s    eta 2m 53s
# physionet.org/files   2%[                    ]   1.91M   415KB/s    eta 2m 53s
# physionet.org/files   2%[                    ]   1.97M   381KB/s    eta 2m 53s
# physionet.org/files   2%[                    ]   2.05M   372KB/s    eta 2m 58s
# physionet.org/files   2%[                    ]   2.11M   359KB/s    eta 2m 58s
# physionet.org/files   2%[                    ]   2.19M   358KB/s    eta 2m 58s
# physionet.org/files   3%[                    ]   2.26M   355KB/s    eta 2m 58s
# physionet.org/files   3%[                    ]   2.34M   353KB/s    eta 2m 58s
# physionet.org/files   3%[                    ]   2.42M   354KB/s    eta 3m 2s
# physionet.org/files   3%[                    ]   2.50M   361KB/s    eta 3m 2s
# physionet.org/files   3%[                    ]   2.59M   355KB/s    eta 3m 2s
# physionet.org/files   3%[                    ]   2.62M   344KB/s    eta 3m 2s
# physionet.org/files   3%[                    ]   2.73M   353KB/s    eta 3m 2s
# physionet.org/files   3%[                    ]   2.80M   348KB/s    eta 3m 4s
# physionet.org/files   3%[                    ]   2.87M   355KB/s    eta 3m 4s
# physionet.org/files   4%[                    ]   2.95M   347KB/s    eta 3m 4s
# physionet.org/files   4%[                    ]   3.03M   350KB/s    eta 3m 4s
# physionet.org/files   4%[                    ]   3.12M   358KB/s    eta 3m 4s
# physionet.org/files   4%[                    ]   3.20M   361KB/s    eta 3m 4s
# physionet.org/files   4%[                    ]   3.30M   366KB/s    eta 3m 4s
# physionet.org/files   4%[                    ]   3.37M   361KB/s    eta 3m 4s
# physionet.org/files   4%[                    ]   3.48M   368KB/s    eta 3m 4s
# physionet.org/files   4%[                    ]   3.53M   357KB/s    eta 3m 6s
# physionet.org/files   4%[                    ]   3.62M   358KB/s    eta 3m 6s
# physionet.org/files   5%[>                   ]   3.69M   344KB/s    eta 3m 6s
# physionet.org/files   5%[>                   ]   3.75M   329KB/s    eta 3m 6s
# physionet.org/files   5%[>                   ]   3.81M   322KB/s    eta 3m 11s
# physionet.org/files   5%[>                   ]   3.86M   318KB/s    eta 3m 11s
# physionet.org/files   5%[>                   ]   3.91M   311KB/s    eta 3m 11s
# physionet.org/files   5%[>                   ]   3.95M   305KB/s    eta 3m 11s
# physionet.org/files   5%[>                   ]   4.01M   297KB/s    eta 3m 11s
# physionet.org/files   5%[>                   ]   4.05M   285KB/s    eta 3m 19s
# physionet.org/files   5%[>                   ]   4.09M   277KB/s    eta 3m 19s
# physionet.org/files   5%[>                   ]   4.14M   268KB/s    eta 3m 19s
# physionet.org/files   5%[>                   ]   4.19M   259KB/s    eta 3m 19s
# physionet.org/files   5%[>                   ]   4.23M   243KB/s    eta 3m 19s
# physionet.org/files   5%[>                   ]   4.30M   245KB/s    eta 3m 25s
# physionet.org/files   5%[>                   ]   4.34M   234KB/s    eta 3m 25s
# physionet.org/files   5%[>                   ]   4.39M   226KB/s    eta 3m 25s
# physionet.org/files   6%[>                   ]   4.45M   222KB/s    eta 3m 25s
# physionet.org/files   6%[>                   ]   4.50M   218KB/s    eta 3m 30s
# physionet.org/files   6%[>                   ]   4.55M   218KB/s    eta 3m 30s
# physionet.org/files   6%[>                   ]   4.59M   216KB/s    eta 3m 30s
# physionet.org/files   6%[>                   ]   4.64M   217KB/s    eta 3m 30s
# physionet.org/files   6%[>                   ]   4.70M   220KB/s    eta 3m 30s
# physionet.org/files   6%[>                   ]   4.76M   224KB/s    eta 3m 33s
# physionet.org/files   6%[>                   ]   4.81M   225KB/s    eta 3m 33s
# physionet.org/files   6%[>                   ]   4.87M   228KB/s    eta 3m 33s
# physionet.org/files   6%[>                   ]   4.91M   227KB/s    eta 3m 33s
# physionet.org/files   6%[>                   ]   4.98M   233KB/s    eta 3m 33s
# physionet.org/files   6%[>                   ]   5.03M   233KB/s    eta 3m 37s
# physionet.org/files   6%[>                   ]   5.09M   236KB/s    eta 3m 37s
# physionet.org/files   7%[>                   ]   5.16M   237KB/s    eta 3m 37s
# physionet.org/files   7%[>                   ]   5.22M   240KB/s    eta 3m 37s
# physionet.org/files   7%[>                   ]   5.28M   249KB/s    eta 3m 37s
# physionet.org/files   7%[>                   ]   5.34M   250KB/s    eta 3m 38s
# physionet.org/files   7%[>                   ]   5.37M   247KB/s    eta 3m 38s
# physionet.org/files   7%[>                   ]   5.45M   253KB/s    eta 3m 38s
# physionet.org/files   7%[>                   ]   5.51M   252KB/s    eta 3m 38s
# physionet.org/files   7%[>                   ]   5.58M   255KB/s    eta 3m 40s
# physionet.org/files   7%[>                   ]   5.64M   254KB/s    eta 3m 40s
# physionet.org/files   7%[>                   ]   5.70M   257KB/s    eta 3m 40s
# physionet.org/files   7%[>                   ]   5.76M   257KB/s    eta 3m 40s
# physionet.org/files   7%[>                   ]   5.83M   257KB/s    eta 3m 40s
# physionet.org/files   8%[>                   ]   5.89M   262KB/s    eta 3m 41s
# physionet.org/files   8%[>                   ]   5.95M   260KB/s    eta 3m 41s
# physionet.org/files   8%[>                   ]   6.03M   264KB/s    eta 3m 41s
# physionet.org/files   8%[>                   ]   6.09M   264KB/s    eta 3m 41s
# physionet.org/files   8%[>                   ]   6.16M   261KB/s    eta 3m 42s
# physionet.org/files   8%[>                   ]   6.22M   262KB/s    eta 3m 42s
# physionet.org/files   8%[>                   ]   6.25M   254KB/s    eta 3m 42s
# physionet.org/files   8%[>                   ]   6.33M   257KB/s    eta 3m 42s
# physionet.org/files   8%[>                   ]   6.37M   261KB/s    eta 3m 42s
# physionet.org/files   8%[>                   ]   6.44M   257KB/s    eta 3m 44s
# physionet.org/files   8%[>                   ]   6.50M   259KB/s    eta 3m 44s
# physionet.org/files   8%[>                   ]   6.56M   258KB/s    eta 3m 44s
# physionet.org/files   9%[>                   ]   6.62M   260KB/s    eta 3m 44s
# physionet.org/files   9%[>                   ]   6.69M   259KB/s    eta 3m 44s
# physionet.org/files   9%[>                   ]   6.75M   259KB/s    eta 3m 44s
# physionet.org/files   9%[>                   ]   6.81M   262KB/s    eta 3m 44s
# physionet.org/files   9%[>                   ]   6.87M   262KB/s    eta 3m 44s
# physionet.org/files   9%[>                   ]   6.95M   264KB/s    eta 3m 44s
# physionet.org/files   9%[>                   ]   7.03M   263KB/s    eta 3m 43s
# physionet.org/files   9%[>                   ]   7.09M   268KB/s    eta 3m 43s
# physionet.org/files   9%[>                   ]   7.16M   266KB/s    eta 3m 43s
# physionet.org/files   9%[>                   ]   7.22M   267KB/s    eta 3m 43s
# physionet.org/files   9%[>                   ]   7.26M   264KB/s    eta 3m 43s
# physionet.org/files   9%[>                   ]   7.31M   267KB/s    eta 3m 45s
# physionet.org/files  10%[=>                  ]   7.36M   260KB/s    eta 3m 45s
# physionet.org/files  10%[=>                  ]   7.41M   262KB/s    eta 3m 45s
# physionet.org/files  10%[=>                  ]   7.47M   263KB/s    eta 3m 45s
# physionet.org/files  10%[=>                  ]   7.53M   263KB/s    eta 3m 45s
# physionet.org/files  10%[=>                  ]   7.58M   264KB/s    eta 3m 46s
# physionet.org/files  10%[=>                  ]   7.64M   265KB/s    eta 3m 46s
# physionet.org/files  10%[=>                  ]   7.67M   255KB/s    eta 3m 46s
# physionet.org/files  10%[=>                  ]   7.73M   256KB/s    eta 3m 46s
# physionet.org/files  10%[=>                  ]   7.80M   254KB/s    eta 3m 46s
# physionet.org/files  10%[=>                  ]   7.86M   254KB/s    eta 3m 46s
# physionet.org/files  10%[=>                  ]   7.91M   249KB/s    eta 3m 46s
# physionet.org/files  10%[=>                  ]   7.97M   244KB/s    eta 3m 46s
# physionet.org/files  10%[=>                  ]   8.03M   246KB/s    eta 3m 46s
# physionet.org/files  11%[=>                  ]   8.08M   243KB/s    eta 3m 46s
# physionet.org/files  11%[=>                  ]   8.12M   247KB/s    eta 3m 47s
# physionet.org/files  11%[=>                  ]   8.19M   242KB/s    eta 3m 47s
# physionet.org/files  11%[=>                  ]   8.23M   242KB/s    eta 3m 47s
# physionet.org/files  11%[=>                  ]   8.30M   246KB/s    eta 3m 47s
# physionet.org/files  11%[=>                  ]   8.36M   247KB/s    eta 3m 47s
# physionet.org/files  11%[=>                  ]   8.42M   251KB/s    eta 3m 47s
# physionet.org/files  11%[=>                  ]   8.48M   251KB/s    eta 3m 47s
# physionet.org/files  11%[=>                  ]   8.56M   255KB/s    eta 3m 47s
# physionet.org/files  11%[=>                  ]   8.64M   259KB/s    eta 3m 47s
# physionet.org/files  11%[=>                  ]   8.70M   267KB/s    eta 3m 47s
# physionet.org/files  11%[=>                  ]   8.78M   271KB/s    eta 3m 45s
# physionet.org/files  12%[=>                  ]   8.86M   279KB/s    eta 3m 45s
# physionet.org/files  12%[=>                  ]   8.95M   288KB/s    eta 3m 45s
# physionet.org/files  12%[=>                  ]   9.03M   292KB/s    eta 3m 45s
# physionet.org/files  12%[=>                  ]   9.12M   309KB/s    eta 3m 45s
# physionet.org/files  12%[=>                  ]   9.22M   321KB/s    eta 3m 41s
# physionet.org/files  12%[=>                  ]   9.31M   334KB/s    eta 3m 41s
# physionet.org/files  12%[=>                  ]   9.41M   350KB/s    eta 3m 41s
# physionet.org/files  12%[=>                  ]   9.50M   363KB/s    eta 3m 41s
# physionet.org/files  13%[=>                  ]   9.61M   374KB/s    eta 3m 41s
# physionet.org/files  13%[=>                  ]   9.72M   390KB/s    eta 3m 35s
# physionet.org/files  13%[=>                  ]   9.83M   407KB/s    eta 3m 35s
# physionet.org/files  13%[=>                  ]   9.94M   417KB/s    eta 3m 35s
# physionet.org/files  13%[=>                  ]  10.05M   429KB/s    eta 3m 35s
# physionet.org/files  13%[=>                  ]  10.17M   445KB/s    eta 3m 35s
# physionet.org/files  14%[=>                  ]  10.30M   466KB/s    eta 3m 28s
# physionet.org/files  14%[=>                  ]  10.44M   481KB/s    eta 3m 28s
# physionet.org/files  14%[=>                  ]  10.59M   505KB/s    eta 3m 28s
# physionet.org/files  14%[=>                  ]  10.76M   533KB/s    eta 3m 28s
# physionet.org/files  14%[=>                  ]  10.94M   552KB/s    eta 3m 28s
# physionet.org/files  15%[==>                 ]  11.03M   557KB/s    eta 3m 18s
# physionet.org/files  15%[==>                 ]  11.23M   586KB/s    eta 3m 18s
# physionet.org/files  15%[==>                 ]  11.37M   608KB/s    eta 3m 18s
# physionet.org/files  15%[==>                 ]  11.51M   623KB/s    eta 3m 18s
# physionet.org/files  15%[==>                 ]  11.66M   631KB/s    eta 3m 18s
# physionet.org/files  16%[==>                 ]  11.75M   632KB/s    eta 3m 9s
# physionet.org/files  16%[==>                 ]  11.83M   611KB/s    eta 3m 9s
# physionet.org/files  16%[==>                 ]  11.94M   604KB/s    eta 3m 9s
# physionet.org/files  16%[==>                 ]  12.00M   591KB/s    eta 3m 9s
# physionet.org/files  16%[==>                 ]  12.06M   576KB/s    eta 3m 8s
# physionet.org/files  16%[==>                 ]  12.14M   562KB/s    eta 3m 8s
# physionet.org/files  16%[==>                 ]  12.20M   544KB/s    eta 3m 8s
# physionet.org/files  16%[==>                 ]  12.28M   519KB/s    eta 3m 8s
# physionet.org/files  16%[==>                 ]  12.34M   503KB/s    eta 3m 8s
# physionet.org/files  16%[==>                 ]  12.42M   476KB/s    eta 3m 7s
# physionet.org/files  17%[==>                 ]  12.50M   458KB/s    eta 3m 7s
# physionet.org/files  17%[==>                 ]  12.58M   417KB/s    eta 3m 7s
# physionet.org/files  17%[==>                 ]  12.67M   407KB/s    eta 3m 7s
# physionet.org/files  17%[==>                 ]  12.75M   377KB/s    eta 3m 7s
# physionet.org/files  17%[==>                 ]  12.81M   372KB/s    eta 3m 5s
# physionet.org/files  17%[==>                 ]  12.91M   360KB/s    eta 3m 5s
# physionet.org/files  17%[==>                 ]  12.97M   341KB/s    eta 3m 5s
# physionet.org/files  17%[==>                 ]  13.05M   340KB/s    eta 3m 5s
# physionet.org/files  17%[==>                 ]  13.12M   346KB/s    eta 3m 5s
# physionet.org/files  18%[==>                 ]  13.20M   350KB/s    eta 3m 4s
# physionet.org/files  18%[==>                 ]  13.28M   356KB/s    eta 3m 4s
# physionet.org/files  18%[==>                 ]  13.37M   362KB/s    eta 3m 4s
# physionet.org/files  18%[==>                 ]  13.47M   369KB/s    eta 3m 4s
# physionet.org/files  18%[==>                 ]  13.56M   372KB/s    eta 3m 4s
# physionet.org/files  18%[==>                 ]  13.66M   377KB/s    eta 3m 1s
# physionet.org/files  18%[==>                 ]  13.73M   380KB/s    eta 3m 1s
# physionet.org/files  18%[==>                 ]  13.83M   384KB/s    eta 3m 1s
# physionet.org/files  18%[==>                 ]  13.92M   389KB/s    eta 3m 1s
# physionet.org/files  19%[==>                 ]  14.01M   390KB/s    eta 3m 1s
# physionet.org/files  19%[==>                 ]  14.11M   393KB/s    eta 2m 59s
# physionet.org/files  19%[==>                 ]  14.20M   406KB/s    eta 2m 59s
# physionet.org/files  19%[==>                 ]  14.31M   408KB/s    eta 2m 59s
# physionet.org/files  19%[==>                 ]  14.42M   416KB/s    eta 2m 59s
# physionet.org/files  19%[==>                 ]  14.53M   428KB/s    eta 2m 59s
# physionet.org/files  19%[==>                 ]  14.64M   435KB/s    eta 2m 55s
# physionet.org/files  20%[===>                ]  14.76M   445KB/s    eta 2m 55s
# physionet.org/files  20%[===>                ]  14.87M   456KB/s    eta 2m 55s
# physionet.org/files  20%[===>                ]  15.00M   453KB/s    eta 2m 55s
# physionet.org/files  20%[===>                ]  15.16M   473KB/s    eta 2m 51s
# physionet.org/files  20%[===>                ]  15.25M   473KB/s    eta 2m 51s
# physionet.org/files  20%[===>                ]  15.34M   475KB/s    eta 2m 51s
# physionet.org/files  21%[===>                ]  15.45M   482KB/s    eta 2m 51s
# physionet.org/files  21%[===>                ]  15.56M   489KB/s    eta 2m 51s
# physionet.org/files  21%[===>                ]  15.67M   493KB/s    eta 2m 48s
# physionet.org/files  21%[===>                ]  15.80M   499KB/s    eta 2m 48s
# physionet.org/files  21%[===>                ]  15.92M   506KB/s    eta 2m 48s
# physionet.org/files  21%[===>                ]  16.05M   514KB/s    eta 2m 48s
# physionet.org/files  22%[===>                ]  16.17M   518KB/s    eta 2m 48s
# physionet.org/files  22%[===>                ]  16.28M   523KB/s    eta 2m 44s
# physionet.org/files  22%[===>                ]  16.41M   526KB/s    eta 2m 44s
# physionet.org/files  22%[===>                ]  16.53M   531KB/s    eta 2m 44s
# physionet.org/files  22%[===>                ]  16.64M   516KB/s    eta 2m 44s
# physionet.org/files  22%[===>                ]  16.80M   522KB/s    eta 2m 41s
# physionet.org/files  23%[===>                ]  16.89M   531KB/s    eta 2m 41s
# physionet.org/files  23%[===>                ]  17.00M   518KB/s    eta 2m 41s
# physionet.org/files  23%[===>                ]  17.09M   517KB/s    eta 2m 41s
# physionet.org/files  23%[===>                ]  17.20M   524KB/s    eta 2m 41s
# physionet.org/files  23%[===>                ]  17.33M   526KB/s    eta 2m 38s
# physionet.org/files  23%[===>                ]  17.44M   524KB/s    eta 2m 38s
# physionet.org/files  23%[===>                ]  17.51M   513KB/s    eta 2m 38s
# physionet.org/files  24%[===>                ]  17.61M   502KB/s    eta 2m 38s
# physionet.org/files  24%[===>                ]  17.70M   498KB/s    eta 2m 38s
# physionet.org/files  24%[===>                ]  17.80M   491KB/s    eta 2m 36s
# physionet.org/files  24%[===>                ]  17.89M   480KB/s    eta 2m 36s
# physionet.org/files  24%[===>                ]  17.98M   467KB/s    eta 2m 36s
# physionet.org/files  24%[===>                ]  18.09M   457KB/s    eta 2m 36s
# physionet.org/files  24%[===>                ]  18.19M   456KB/s    eta 2m 36s
# physionet.org/files  24%[===>                ]  18.30M   447KB/s    eta 2m 34s
# physionet.org/files  25%[====>               ]  18.41M   444KB/s    eta 2m 34s
# physionet.org/files  25%[====>               ]  18.48M   441KB/s    eta 2m 34s
# physionet.org/files  25%[====>               ]  18.59M   441KB/s    eta 2m 34s
# physionet.org/files  25%[====>               ]  18.70M   437KB/s    eta 2m 34s
# physionet.org/files  25%[====>               ]  18.83M   442KB/s    eta 2m 32s
# physionet.org/files  25%[====>               ]  18.92M   439KB/s    eta 2m 32s
# physionet.org/files  25%[====>               ]  19.05M   437KB/s    eta 2m 32s
# physionet.org/files  26%[====>               ]  19.16M   451KB/s    eta 2m 32s
# physionet.org/files  26%[====>               ]  19.25M   436KB/s    eta 2m 32s
# physionet.org/files  26%[====>               ]  19.34M   433KB/s    eta 2m 30s
# physionet.org/files  26%[====>               ]  19.47M   434KB/s    eta 2m 30s
# physionet.org/files  26%[====>               ]  19.55M   427KB/s    eta 2m 30s
# physionet.org/files  26%[====>               ]  19.66M   434KB/s    eta 2m 30s
# physionet.org/files  26%[====>               ]  19.78M   448KB/s    eta 2m 30s
# physionet.org/files  27%[====>               ]  19.91M   450KB/s    eta 2m 28s
# physionet.org/files  27%[====>               ]  20.03M   458KB/s    eta 2m 28s
# physionet.org/files  27%[====>               ]  20.16M   462KB/s    eta 2m 28s
# physionet.org/files  27%[====>               ]  20.28M   471KB/s    eta 2m 28s
# physionet.org/files  27%[====>               ]  20.39M   486KB/s    eta 2m 28s
# physionet.org/files  28%[====>               ]  20.53M   493KB/s    eta 2m 24s
# physionet.org/files  28%[====>               ]  20.66M   498KB/s    eta 2m 24s
# physionet.org/files  28%[====>               ]  20.78M   516KB/s    eta 2m 24s
# physionet.org/files  28%[====>               ]  20.91M   512KB/s    eta 2m 24s
# physionet.org/files  28%[====>               ]  21.03M   525KB/s    eta 2m 24s
# physionet.org/files  28%[====>               ]  21.16M   542KB/s    eta 2m 21s
# physionet.org/files  29%[====>               ]  21.26M   554KB/s    eta 2m 21s
# physionet.org/files  29%[====>               ]  21.41M   569KB/s    eta 2m 21s
# physionet.org/files  29%[====>               ]  21.55M   583KB/s    eta 2m 21s
# physionet.org/files  29%[====>               ]  21.62M   557KB/s    eta 2m 21s
# physionet.org/files  29%[====>               ]  21.72M   556KB/s    eta 2m 19s
# physionet.org/files  29%[====>               ]  21.83M   552KB/s    eta 2m 19s
# physionet.org/files  29%[====>               ]  21.91M   539KB/s    eta 2m 19s
# physionet.org/files  29%[====>               ]  21.98M   530KB/s    eta 2m 19s
# physionet.org/files  30%[=====>              ]  22.08M   520KB/s    eta 2m 19s
# physionet.org/files  30%[=====>              ]  22.16M   513KB/s    eta 2m 17s
# physionet.org/files  30%[=====>              ]  22.25M   500KB/s    eta 2m 17s
# physionet.org/files  30%[=====>              ]  22.34M   487KB/s    eta 2m 17s
# physionet.org/files  30%[=====>              ]  22.42M   480KB/s    eta 2m 17s
# physionet.org/files  30%[=====>              ]  22.48M   456KB/s    eta 2m 17s
# physionet.org/files  30%[=====>              ]  22.53M   440KB/s    eta 2m 16s
# physionet.org/files  30%[=====>              ]  22.59M   412KB/s    eta 2m 16s
# physionet.org/files  30%[=====>              ]  22.66M   392KB/s    eta 2m 16s
# physionet.org/files  30%[=====>              ]  22.70M   376KB/s    eta 2m 16s
# physionet.org/files  31%[=====>              ]  22.75M   340KB/s    eta 2m 16s
# physionet.org/files  31%[=====>              ]  22.81M   319KB/s    eta 2m 17s
# physionet.org/files  31%[=====>              ]  22.86M   325KB/s    eta 2m 17s
# physionet.org/files  31%[=====>              ]  22.91M   309KB/s    eta 2m 17s
# physionet.org/files  31%[=====>              ]  22.94M   289KB/s    eta 2m 17s
# physionet.org/files  31%[=====>              ]  22.98M   274KB/s    eta 2m 17s
# physionet.org/files  31%[=====>              ]  23.01M   258KB/s    eta 2m 18s
# physionet.org/files  31%[=====>              ]  23.06M   253KB/s    eta 2m 18s
# physionet.org/files  31%[=====>              ]  23.09M   239KB/s    eta 2m 18s
# physionet.org/files  31%[=====>              ]  23.14M   232KB/s    eta 2m 18s
# physionet.org/files  31%[=====>              ]  23.19M   223KB/s    eta 2m 18s
# physionet.org/files  31%[=====>              ]  23.25M   216KB/s    eta 2m 18s
# physionet.org/files  31%[=====>              ]  23.30M   220KB/s    eta 2m 18s
# physionet.org/files  31%[=====>              ]  23.36M   218KB/s    eta 2m 18s
# physionet.org/files  31%[=====>              ]  23.42M   221KB/s    eta 2m 18s
# physionet.org/files  32%[=====>              ]  23.48M   222KB/s    eta 2m 18s
# physionet.org/files  32%[=====>              ]  23.55M   223KB/s    eta 2m 18s
# physionet.org/files  32%[=====>              ]  23.62M   236KB/s    eta 2m 18s
# physionet.org/files  32%[=====>              ]  23.67M   231KB/s    eta 2m 18s
# physionet.org/files  32%[=====>              ]  23.76M   244KB/s    eta 2m 18s
# physionet.org/files  32%[=====>              ]  23.83M   249KB/s    eta 2m 18s
# physionet.org/files  32%[=====>              ]  23.89M   255KB/s    eta 2m 17s
# physionet.org/files  32%[=====>              ]  23.95M   263KB/s    eta 2m 17s
# physionet.org/files  32%[=====>              ]  24.00M   263KB/s    eta 2m 17s
# physionet.org/files  32%[=====>              ]  24.06M   268KB/s    eta 2m 17s
# physionet.org/files  32%[=====>              ]  24.11M   268KB/s    eta 2m 17s
# physionet.org/files  32%[=====>              ]  24.17M   268KB/s    eta 2m 17s
# physionet.org/files  33%[=====>              ]  24.22M   268KB/s    eta 2m 17s
# physionet.org/files  33%[=====>              ]  24.28M   268KB/s    eta 2m 17s
# physionet.org/files  33%[=====>              ]  24.33M   265KB/s    eta 2m 17s
# physionet.org/files  33%[=====>              ]  24.37M   260KB/s    eta 2m 17s
# physionet.org/files  33%[=====>              ]  24.42M   256KB/s    eta 2m 17s
# physionet.org/files  33%[=====>              ]  24.48M   254KB/s    eta 2m 17s
# physionet.org/files  33%[=====>              ]  24.53M   252KB/s    eta 2m 17s
# physionet.org/files  33%[=====>              ]  24.59M   246KB/s    eta 2m 17s
# physionet.org/files  33%[=====>              ]  24.66M   251KB/s    eta 2m 17s
# physionet.org/files  33%[=====>              ]  24.72M   244KB/s    eta 2m 17s
# physionet.org/files  33%[=====>              ]  24.78M   244KB/s    eta 2m 17s
# physionet.org/files  33%[=====>              ]  24.84M   244KB/s    eta 2m 17s
# physionet.org/files  33%[=====>              ]  24.92M   247KB/s    eta 2m 17s
# physionet.org/files  34%[=====>              ]  25.00M   255KB/s    eta 2m 17s
# physionet.org/files  34%[=====>              ]  25.06M   259KB/s    eta 2m 17s
# physionet.org/files  34%[=====>              ]  25.14M   267KB/s    eta 2m 17s
# physionet.org/files  34%[=====>              ]  25.22M   275KB/s    eta 2m 17s
# physionet.org/files  34%[=====>              ]  25.30M   279KB/s    eta 2m 17s
# physionet.org/files  34%[=====>              ]  25.39M   299KB/s    eta 2m 17s
# physionet.org/files  34%[=====>              ]  25.47M   308KB/s    eta 2m 16s
# physionet.org/files  34%[=====>              ]  25.53M   307KB/s    eta 2m 16s
# physionet.org/files  35%[======>             ]  25.66M   326KB/s    eta 2m 16s
# physionet.org/files  35%[======>             ]  25.72M   326KB/s    eta 2m 16s
# physionet.org/files  35%[======>             ]  25.78M   323KB/s    eta 2m 15s
# physionet.org/files  35%[======>             ]  25.89M   335KB/s    eta 2m 15s
# physionet.org/files  35%[======>             ]  25.94M   332KB/s    eta 2m 15s
# physionet.org/files  35%[======>             ]  26.00M   334KB/s    eta 2m 15s
# physionet.org/files  35%[======>             ]  26.06M   334KB/s    eta 2m 15s
# physionet.org/files  35%[======>             ]  26.12M   333KB/s    eta 2m 14s
# physionet.org/files  35%[======>             ]  26.20M   334KB/s    eta 2m 14s
# physionet.org/files  35%[======>             ]  26.26M   331KB/s    eta 2m 14s
# physionet.org/files  35%[======>             ]  26.33M   329KB/s    eta 2m 14s
# physionet.org/files  35%[======>             ]  26.37M   321KB/s    eta 2m 14s
# physionet.org/files  36%[======>             ]  26.41M   308KB/s    eta 2m 14s
# physionet.org/files  36%[======>             ]  26.45M   299KB/s    eta 2m 14s
# physionet.org/files  36%[======>             ]  26.50M   289KB/s    eta 2m 14s
# physionet.org/files  36%[======>             ]  26.55M   274KB/s    eta 2m 14s
# physionet.org/files  36%[======>             ]  26.59M   278KB/s    eta 2m 14s
# physionet.org/files  36%[======>             ]  26.64M   250KB/s    eta 2m 14s
# physionet.org/files  36%[======>             ]  26.70M   248KB/s    eta 2m 14s
# physionet.org/files  36%[======>             ]  26.75M   251KB/s    eta 2m 14s
# physionet.org/files  36%[======>             ]  26.80M   236KB/s    eta 2m 14s
# physionet.org/files  36%[======>             ]  26.84M   236KB/s    eta 2m 14s
# physionet.org/files  36%[======>             ]  26.89M   233KB/s    eta 2m 14s
# physionet.org/files  36%[======>             ]  26.94M   229KB/s    eta 2m 14s
# physionet.org/files  36%[======>             ]  26.98M   225KB/s    eta 2m 14s
# physionet.org/files  36%[======>             ]  27.05M   223KB/s    eta 2m 14s
# physionet.org/files  36%[======>             ]  27.09M   220KB/s    eta 2m 14s
# physionet.org/files  37%[======>             ]  27.16M   219KB/s    eta 2m 14s
# physionet.org/files  37%[======>             ]  27.22M   219KB/s    eta 2m 14s
# physionet.org/files  37%[======>             ]  27.25M   214KB/s    eta 2m 14s
# physionet.org/files  37%[======>             ]  27.34M   229KB/s    eta 2m 14s
# physionet.org/files  37%[======>             ]  27.39M   229KB/s    eta 2m 14s
# physionet.org/files  37%[======>             ]  27.44M   232KB/s    eta 2m 14s
# physionet.org/files  37%[======>             ]  27.48M   233KB/s    eta 2m 14s
# physionet.org/files  37%[======>             ]  27.55M   236KB/s    eta 2m 14s
# physionet.org/files  37%[======>             ]  27.61M   241KB/s    eta 2m 14s
# physionet.org/files  37%[======>             ]  27.67M   245KB/s    eta 2m 14s
# physionet.org/files  37%[======>             ]  27.73M   253KB/s    eta 2m 13s
# physionet.org/files  37%[======>             ]  27.81M   261KB/s    eta 2m 13s
# physionet.org/files  37%[======>             ]  27.83M   255KB/s    eta 2m 13s
# physionet.org/files  38%[======>             ]  27.92M   264KB/s    eta 2m 13s
# physionet.org/files  38%[======>             ]  27.97M   264KB/s    eta 2m 13s
# physionet.org/files  38%[======>             ]  28.01M   264KB/s    eta 2m 13s
# physionet.org/files  38%[======>             ]  28.08M   267KB/s    eta 2m 13s
# physionet.org/files  38%[======>             ]  28.14M   270KB/s    eta 2m 13s
# physionet.org/files  38%[======>             ]  28.20M   270KB/s    eta 2m 13s
# physionet.org/files  38%[======>             ]  28.26M   280KB/s    eta 2m 13s
# physionet.org/files  38%[======>             ]  28.33M   274KB/s    eta 2m 12s
# physionet.org/files  38%[======>             ]  28.39M   278KB/s    eta 2m 12s
# physionet.org/files  38%[======>             ]  28.47M   285KB/s    eta 2m 12s
# physionet.org/files  38%[======>             ]  28.55M   287KB/s    eta 2m 12s
# physionet.org/files  39%[======>             ]  28.62M   291KB/s    eta 2m 12s
# physionet.org/files  39%[======>             ]  28.70M   296KB/s    eta 2m 11s
# physionet.org/files  39%[======>             ]  28.78M   297KB/s    eta 2m 11s
# physionet.org/files  39%[======>             ]  28.86M   314KB/s    eta 2m 11s
# physionet.org/files  39%[======>             ]  28.94M   311KB/s    eta 2m 11s
# physionet.org/files  39%[======>             ]  29.03M   324KB/s    eta 2m 11s
# physionet.org/files  39%[======>             ]  29.12M   336KB/s    eta 2m 10s
# physionet.org/files  39%[======>             ]  29.19M   337KB/s    eta 2m 10s
# physionet.org/files  39%[======>             ]  29.25M   339KB/s    eta 2m 10s
# physionet.org/files  40%[=======>            ]  29.33M   344KB/s    eta 2m 10s
# physionet.org/files  40%[=======>            ]  29.41M   347KB/s    eta 2m 10s
# physionet.org/files  40%[=======>            ]  29.48M   354KB/s    eta 2m 9s
# physionet.org/files  40%[=======>            ]  29.58M   361KB/s    eta 2m 9s
# physionet.org/files  40%[=======>            ]  29.67M   369KB/s    eta 2m 9s
# physionet.org/files  40%[=======>            ]  29.76M   376KB/s    eta 2m 9s
# physionet.org/files  40%[=======>            ]  29.86M   382KB/s    eta 2m 9s
# physionet.org/files  40%[=======>            ]  29.94M   369KB/s    eta 2m 7s
# physionet.org/files  40%[=======>            ]  30.03M   372KB/s    eta 2m 7s
# physionet.org/files  41%[=======>            ]  30.09M   359KB/s    eta 2m 7s
# physionet.org/files  41%[=======>            ]  30.14M   348KB/s    eta 2m 7s
# physionet.org/files  41%[=======>            ]  30.19M   340KB/s    eta 2m 7s
# physionet.org/files  41%[=======>            ]  30.25M   342KB/s    eta 2m 7s
# physionet.org/files  41%[=======>            ]  30.30M   318KB/s    eta 2m 7s
# physionet.org/files  41%[=======>            ]  30.36M   314KB/s    eta 2m 7s
# physionet.org/files  41%[=======>            ]  30.41M   304KB/s    eta 2m 7s
# physionet.org/files  41%[=======>            ]  30.45M   301KB/s    eta 2m 7s
# physionet.org/files  41%[=======>            ]  30.51M   291KB/s    eta 2m 7s
# physionet.org/files  41%[=======>            ]  30.56M   288KB/s    eta 2m 7s
# physionet.org/files  41%[=======>            ]  30.62M   278KB/s    eta 2m 7s
# physionet.org/files  41%[=======>            ]  30.67M   272KB/s    eta 2m 7s
# physionet.org/files  41%[=======>            ]  30.73M   259KB/s    eta 2m 7s
# physionet.org/files  42%[=======>            ]  30.80M   251KB/s    eta 2m 6s
# physionet.org/files  42%[=======>            ]  30.86M   255KB/s    eta 2m 6s
# physionet.org/files  42%[=======>            ]  30.92M   249KB/s    eta 2m 6s
# physionet.org/files  42%[=======>            ]  30.98M   253KB/s    eta 2m 6s
# physionet.org/files  42%[=======>            ]  31.03M   249KB/s    eta 2m 6s
# physionet.org/files  42%[=======>            ]  31.11M   258KB/s    eta 2m 5s
# physionet.org/files  42%[=======>            ]  31.14M   252KB/s    eta 2m 5s
# physionet.org/files  42%[=======>            ]  31.20M   253KB/s    eta 2m 5s
# physionet.org/files  42%[=======>            ]  31.25M   250KB/s    eta 2m 5s
# physionet.org/files  42%[=======>            ]  31.30M   253KB/s    eta 2m 5s
# physionet.org/files  42%[=======>            ]  31.34M   253KB/s    eta 2m 5s
# physionet.org/files  42%[=======>            ]  31.39M   252KB/s    eta 2m 5s
# physionet.org/files  42%[=======>            ]  31.45M   252KB/s    eta 2m 5s
# physionet.org/files  42%[=======>            ]  31.51M   251KB/s    eta 2m 5s
# physionet.org/files  43%[=======>            ]  31.58M   253KB/s    eta 2m 5s
# physionet.org/files  43%[=======>            ]  31.64M   253KB/s    eta 2m 5s
# physionet.org/files  43%[=======>            ]  31.67M   245KB/s    eta 2m 5s
# physionet.org/files  43%[=======>            ]  31.75M   249KB/s    eta 2m 5s
# physionet.org/files  43%[=======>            ]  31.81M   245KB/s    eta 2m 5s
# physionet.org/files  43%[=======>            ]  31.87M   243KB/s    eta 2m 5s
# physionet.org/files  43%[=======>            ]  31.92M   243KB/s    eta 2m 4s
# physionet.org/files  43%[=======>            ]  31.98M   239KB/s    eta 2m 4s
# physionet.org/files  43%[=======>            ]  32.05M   247KB/s    eta 2m 4s
# physionet.org/files  43%[=======>            ]  32.11M   249KB/s    eta 2m 4s
# physionet.org/files  43%[=======>            ]  32.17M   253KB/s    eta 2m 4s
# physionet.org/files  43%[=======>            ]  32.23M   257KB/s    eta 2m 4s
# physionet.org/files  44%[=======>            ]  32.30M   264KB/s    eta 2m 4s
# physionet.org/files  44%[=======>            ]  32.37M   270KB/s    eta 2m 4s
# physionet.org/files  44%[=======>            ]  32.44M   273KB/s    eta 2m 4s
# physionet.org/files  44%[=======>            ]  32.51M   278KB/s    eta 2m 4s
# physionet.org/files  44%[=======>            ]  32.59M   283KB/s    eta 2m 3s
# physionet.org/files  44%[=======>            ]  32.64M   286KB/s    eta 2m 3s
# physionet.org/files  44%[=======>            ]  32.73M   291KB/s    eta 2m 3s
# physionet.org/files  44%[=======>            ]  32.80M   295KB/s    eta 2m 3s
# physionet.org/files  44%[=======>            ]  32.86M   299KB/s    eta 2m 3s
# physionet.org/files  44%[=======>            ]  32.94M   307KB/s    eta 2m 2s
# physionet.org/files  45%[========>           ]  33.01M   312KB/s    eta 2m 2s
# physionet.org/files  45%[========>           ]  33.09M   315KB/s    eta 2m 2s
# physionet.org/files  45%[========>           ]  33.17M   318KB/s    eta 2m 2s
# physionet.org/files  45%[========>           ]  33.26M   326KB/s    eta 2m 2s
# physionet.org/files  45%[========>           ]  33.34M   331KB/s    eta 2m 1s
# physionet.org/files  45%[========>           ]  33.42M   337KB/s    eta 2m 1s
# physionet.org/files  45%[========>           ]  33.50M   329KB/s    eta 2m 1s
# physionet.org/files  45%[========>           ]  33.61M   344KB/s    eta 2m 1s
# physionet.org/files  45%[========>           ]  33.67M   339KB/s    eta 2m 1s
# physionet.org/files  46%[========>           ]  33.75M   340KB/s    eta 1m 59s
# physionet.org/files  46%[========>           ]  33.83M   350KB/s    eta 1m 59s
# physionet.org/files  46%[========>           ]  33.91M   343KB/s    eta 1m 59s
# physionet.org/files  46%[========>           ]  33.98M   336KB/s    eta 1m 59s
# physionet.org/files  46%[========>           ]  34.09M   350KB/s    eta 1m 58s
# physionet.org/files  46%[========>           ]  34.16M   347KB/s    eta 1m 58s
# physionet.org/files  46%[========>           ]  34.22M   346KB/s    eta 1m 58s
# physionet.org/files  46%[========>           ]  34.28M   340KB/s    eta 1m 58s
# physionet.org/files  46%[========>           ]  34.34M   330KB/s    eta 1m 58s
# physionet.org/files  46%[========>           ]  34.44M   329KB/s    eta 1m 57s
# physionet.org/files  47%[========>           ]  34.50M   325KB/s    eta 1m 57s
# physionet.org/files  47%[========>           ]  34.56M   320KB/s    eta 1m 57s
# physionet.org/files  47%[========>           ]  34.62M   316KB/s    eta 1m 57s
# physionet.org/files  47%[========>           ]  34.69M   313KB/s    eta 1m 57s
# physionet.org/files  47%[========>           ]  34.75M   309KB/s    eta 1m 57s
# physionet.org/files  47%[========>           ]  34.81M   308KB/s    eta 1m 57s
# physionet.org/files  47%[========>           ]  34.86M   303KB/s    eta 1m 57s
# physionet.org/files  47%[========>           ]  34.91M   297KB/s    eta 1m 57s
# physionet.org/files  47%[========>           ]  34.97M   293KB/s    eta 1m 57s
# physionet.org/files  47%[========>           ]  35.05M   290KB/s    eta 1m 56s
# physionet.org/files  47%[========>           ]  35.11M   300KB/s    eta 1m 56s
# physionet.org/files  47%[========>           ]  35.17M   286KB/s    eta 1m 56s
# physionet.org/files  48%[========>           ]  35.25M   280KB/s    eta 1m 56s
# physionet.org/files  48%[========>           ]  35.34M   287KB/s    eta 1m 55s
# physionet.org/files  48%[========>           ]  35.39M   276KB/s    eta 1m 55s
# physionet.org/files  48%[========>           ]  35.47M   285KB/s    eta 1m 55s
# physionet.org/files  48%[========>           ]  35.51M   273KB/s    eta 1m 55s
# physionet.org/files  48%[========>           ]  35.56M   270KB/s    eta 1m 55s
# physionet.org/files  48%[========>           ]  35.61M   266KB/s    eta 1m 55s
# physionet.org/files  48%[========>           ]  35.66M   264KB/s    eta 1m 55s
# physionet.org/files  48%[========>           ]  35.72M   259KB/s    eta 1m 55s
# physionet.org/files  48%[========>           ]  35.78M   256KB/s    eta 1m 55s
# physionet.org/files  48%[========>           ]  35.84M   256KB/s    eta 1m 54s
# physionet.org/files  48%[========>           ]  35.89M   252KB/s    eta 1m 54s
# physionet.org/files  49%[========>           ]  35.97M   256KB/s    eta 1m 54s
# physionet.org/files  49%[========>           ]  36.01M   241KB/s    eta 1m 54s
# physionet.org/files  49%[========>           ]  36.08M   242KB/s    eta 1m 54s
# physionet.org/files  49%[========>           ]  36.12M   235KB/s    eta 1m 54s
# physionet.org/files  49%[========>           ]  36.17M   232KB/s    eta 1m 54s
# physionet.org/files  49%[========>           ]  36.22M   222KB/s    eta 1m 54s
# physionet.org/files  49%[========>           ]  36.26M   227KB/s    eta 1m 54s
# physionet.org/files  49%[========>           ]  36.31M   219KB/s    eta 1m 54s
# physionet.org/files  49%[========>           ]  36.37M   222KB/s    eta 1m 54s
# physionet.org/files  49%[========>           ]  36.44M   228KB/s    eta 1m 54s
# physionet.org/files  49%[========>           ]  36.50M   232KB/s    eta 1m 54s
# physionet.org/files  49%[========>           ]  36.56M   235KB/s    eta 1m 54s
# physionet.org/files  49%[========>           ]  36.62M   237KB/s    eta 1m 53s
# physionet.org/files  50%[=========>          ]  36.69M   240KB/s    eta 1m 53s
# physionet.org/files  50%[=========>          ]  36.75M   243KB/s    eta 1m 53s
# physionet.org/files  50%[=========>          ]  36.80M   246KB/s    eta 1m 53s
# physionet.org/files  50%[=========>          ]  36.86M   244KB/s    eta 1m 53s
# physionet.org/files  50%[=========>          ]  36.92M   255KB/s    eta 1m 52s
# physionet.org/files  50%[=========>          ]  36.98M   254KB/s    eta 1m 52s
# physionet.org/files  50%[=========>          ]  37.05M   261KB/s    eta 1m 52s
# physionet.org/files  50%[=========>          ]  37.11M   267KB/s    eta 1m 52s
# physionet.org/files  50%[=========>          ]  37.19M   278KB/s    eta 1m 52s
# physionet.org/files  50%[=========>          ]  37.25M   283KB/s    eta 1m 51s
# physionet.org/files  50%[=========>          ]  37.33M   292KB/s    eta 1m 51s
# physionet.org/files  51%[=========>          ]  37.41M   296KB/s    eta 1m 51s
# physionet.org/files  51%[=========>          ]  37.45M   292KB/s    eta 1m 51s
# physionet.org/files  51%[=========>          ]  37.56M   301KB/s    eta 1m 51s
# physionet.org/files  51%[=========>          ]  37.62M   300KB/s    eta 1m 50s
# physionet.org/files  51%[=========>          ]  37.70M   304KB/s    eta 1m 50s
# physionet.org/files  51%[=========>          ]  37.73M   296KB/s    eta 1m 50s
# physionet.org/files  51%[=========>          ]  37.81M   308KB/s    eta 1m 50s
# physionet.org/files  51%[=========>          ]  37.87M   299KB/s    eta 1m 50s
# physionet.org/files  51%[=========>          ]  37.92M   298KB/s    eta 1m 50s
# physionet.org/files  51%[=========>          ]  37.95M   290KB/s    eta 1m 50s
# physionet.org/files  51%[=========>          ]  38.01M   291KB/s    eta 1m 50s
# physionet.org/files  51%[=========>          ]  38.06M   286KB/s    eta 1m 50s
# physionet.org/files  51%[=========>          ]  38.11M   282KB/s    eta 1m 50s
# physionet.org/files  52%[=========>          ]  38.17M   278KB/s    eta 1m 49s
# physionet.org/files  52%[=========>          ]  38.22M   274KB/s    eta 1m 49s
# physionet.org/files  52%[=========>          ]  38.28M   274KB/s    eta 1m 49s
# physionet.org/files  52%[=========>          ]  38.34M   269KB/s    eta 1m 49s
# physionet.org/files  52%[=========>          ]  38.39M   261KB/s    eta 1m 49s
# physionet.org/files  52%[=========>          ]  38.44M   261KB/s    eta 1m 49s
# physionet.org/files  52%[=========>          ]  38.47M   240KB/s    eta 1m 49s
# physionet.org/files  52%[=========>          ]  38.51M   231KB/s    eta 1m 49s
# physionet.org/files  52%[=========>          ]  38.55M   221KB/s    eta 1m 49s
# physionet.org/files  52%[=========>          ]  38.59M   215KB/s    eta 1m 49s
# physionet.org/files  52%[=========>          ]  38.64M   212KB/s    eta 1m 49s
# physionet.org/files  52%[=========>          ]  38.69M   207KB/s    eta 1m 49s
# physionet.org/files  52%[=========>          ]  38.73M   203KB/s    eta 1m 49s
# physionet.org/files  52%[=========>          ]  38.78M   204KB/s    eta 1m 48s
# physionet.org/files  52%[=========>          ]  38.83M   200KB/s    eta 1m 48s
# physionet.org/files  53%[=========>          ]  38.87M   199KB/s    eta 1m 48s
# physionet.org/files  53%[=========>          ]  38.92M   186KB/s    eta 1m 48s
# physionet.org/files  53%[=========>          ]  38.98M   184KB/s    eta 1m 48s
# physionet.org/files  53%[=========>          ]  39.01M   177KB/s    eta 1m 48s
# physionet.org/files  53%[=========>          ]  39.06M   178KB/s    eta 1m 48s
# physionet.org/files  53%[=========>          ]  39.11M   178KB/s    eta 1m 48s
# physionet.org/files  53%[=========>          ]  39.16M   182KB/s    eta 1m 48s
# physionet.org/files  53%[=========>          ]  39.19M   178KB/s    eta 1m 48s
# physionet.org/files  53%[=========>          ]  39.23M   180KB/s    eta 1m 48s
# physionet.org/files  53%[=========>          ]  39.26M   178KB/s    eta 1m 48s
# physionet.org/files  53%[=========>          ]  39.31M   178KB/s    eta 1m 48s
# physionet.org/files  53%[=========>          ]  39.36M   177KB/s    eta 1m 48s
# physionet.org/files  53%[=========>          ]  39.41M   177KB/s    eta 1m 48s
# physionet.org/files  53%[=========>          ]  39.45M   180KB/s    eta 1m 48s
# physionet.org/files  53%[=========>          ]  39.50M   180KB/s    eta 1m 48s
# physionet.org/files  53%[=========>          ]  39.55M   182KB/s    eta 1m 48s
# physionet.org/files  54%[=========>          ]  39.59M   185KB/s    eta 1m 47s
# physionet.org/files  54%[=========>          ]  39.62M   181KB/s    eta 1m 47s
# physionet.org/files  54%[=========>          ]  39.69M   185KB/s    eta 1m 47s
# physionet.org/files  54%[=========>          ]  39.73M   186KB/s    eta 1m 47s
# physionet.org/files  54%[=========>          ]  39.78M   189KB/s    eta 1m 47s
# physionet.org/files  54%[=========>          ]  39.83M   193KB/s    eta 1m 47s
# physionet.org/files  54%[=========>          ]  39.87M   195KB/s    eta 1m 47s
# physionet.org/files  54%[=========>          ]  39.92M   195KB/s    eta 1m 47s
# physionet.org/files  54%[=========>          ]  39.97M   196KB/s    eta 1m 47s
# physionet.org/files  54%[=========>          ]  40.01M   197KB/s    eta 1m 47s
# physionet.org/files  54%[=========>          ]  40.06M   195KB/s    eta 1m 47s
# physionet.org/files  54%[=========>          ]  40.12M   197KB/s    eta 1m 47s
# physionet.org/files  54%[=========>          ]  40.16M   194KB/s    eta 1m 47s
# physionet.org/files  54%[=========>          ]  40.19M   191KB/s    eta 1m 47s
# physionet.org/files  54%[=========>          ]  40.22M   185KB/s    eta 1m 47s
# physionet.org/files  54%[=========>          ]  40.25M   179KB/s    eta 1m 47s
# physionet.org/files  54%[=========>          ]  40.28M   173KB/s    eta 1m 47s
# physionet.org/files  54%[=========>          ]  40.30M   166KB/s    eta 1m 47s
# physionet.org/files  55%[==========>         ]  40.33M   166KB/s    eta 1m 47s
# physionet.org/files  55%[==========>         ]  40.36M   160KB/s    eta 1m 47s
# physionet.org/files  55%[==========>         ]  40.39M   156KB/s    eta 1m 47s
# ...
# physionet.org/files  98%[==================> ] 132.81M   214KB/s    eta 10s
# physionet.org/files  98%[==================> ] 132.87M   212KB/s    eta 10s
# physionet.org/files  98%[==================> ] 132.94M   222KB/s    eta 10s
# physionet.org/files  98%[==================> ] 133.00M   225KB/s    eta 10s
# physionet.org/files  98%[==================> ] 133.03M   220KB/s    eta 10s
# physionet.org/files  98%[==================> ] 133.12M   232KB/s    eta 8s
# physionet.org/files  98%[==================> ] 133.17M   236KB/s    eta 8s
# physionet.org/files  98%[==================> ] 133.23M   243KB/s    eta 8s
# physionet.org/files  98%[==================> ] 133.28M   244KB/s    eta 8s
# physionet.org/files  98%[==================> ] 133.34M   248KB/s    eta 8s
# physionet.org/files  98%[==================> ] 133.41M   252KB/s    eta 7s
# physionet.org/files  98%[==================> ] 133.47M   256KB/s    eta 7s
# physionet.org/files  98%[==================> ] 133.53M   257KB/s    eta 7s
# physionet.org/files  98%[==================> ] 133.59M   258KB/s    eta 7s
# physionet.org/files  98%[==================> ] 133.66M   261KB/s    eta 7s
# physionet.org/files  98%[==================> ] 133.72M   260KB/s    eta 6s
# physionet.org/files  98%[==================> ] 133.80M   271KB/s    eta 6s
# physionet.org/files  98%[==================> ] 133.86M   271KB/s    eta 6s
# physionet.org/files  98%[==================> ] 133.92M   274KB/s    eta 6s
# physionet.org/files  98%[==================> ] 133.98M   272KB/s    eta 6s
# physionet.org/files  99%[==================> ] 134.05M   272KB/s    eta 5s
# physionet.org/files  99%[==================> ] 134.11M   283KB/s    eta 5s
# physionet.org/files  99%[==================> ] 134.19M   280KB/s    eta 5s
# physionet.org/files  99%[==================> ] 134.25M   286KB/s    eta 5s
# physionet.org/files  99%[==================> ] 134.33M   289KB/s    eta 5s
# physionet.org/files  99%[==================> ] 134.41M   302KB/s    eta 4s
# physionet.org/files  99%[==================> ] 134.48M   305KB/s    eta 4s
# physionet.org/files  99%[==================> ] 134.56M   308KB/s    eta 4s
# physionet.org/files  99%[==================> ] 134.61M   300KB/s    eta 4s
# physionet.org/files  99%[==================> ] 134.72M   312KB/s    eta 4s
# physionet.org/files  99%[==================> ] 134.75M   300KB/s    eta 2s
# physionet.org/files  99%[==================> ] 134.83M   303KB/s    eta 2s
# physionet.org/files  99%[==================> ] 134.87M   298KB/s    eta 2s
# physionet.org/files  99%[==================> ] 134.92M   290KB/s    eta 2s
# physionet.org/files  99%[==================> ] 134.98M   290KB/s    eta 2s
# physionet.org/files  99%[==================> ] 135.03M   287KB/s    eta 1s
# physionet.org/files  99%[==================> ] 135.09M   287KB/s    eta 1s
# physionet.org/files  99%[==================> ] 135.16M   286KB/s    eta 1s
# physionet.org/files  99%[==================> ] 135.22M   287KB/s    eta 1s
# physionet.org/files  99%[==================> ] 135.28M   287KB/s    eta 1s
# physionet.org/files  99%[==================> ] 135.34M   284KB/s    eta 0s
# physionet.org/files 100%[===================>] 135.37M   283KB/s    in 8m 32s
#
# 2025-11-10 12:43:57 (271 KB/s) - 'physionet.org/files/mimic-cxr/2.1.0/mimic-cxr-reports.zip' saved [141942511/141942511]
#
# --2025-11-10 12:43:57--  https://physionet.org/files/mimic-cxr/2.1.0/files/p10/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'physionet.org/files/mimic-cxr/2.1.0/files/p10/index.html'
#
#
# physionet.org/files     [<=>                 ]       0  --.-KB/s
# physionet.org/files     [ <=>                ] 463.74K  2.16MB/s
# physionet.org/files     [  <=>               ] 543.74K  1.25MB/s
# physionet.org/files     [   <=>              ] 639.74K   987KB/s
# physionet.org/files     [    <=>             ] 718.65K   856KB/s    in 0.8s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-11-10 12:43:59 (856 KB/s) - 'physionet.org/files/mimic-cxr/2.1.0/files/p10/index.html' saved [735900]
#
# --2025-11-10 12:44:00--  https://physionet.org/files/mimic-cxr/2.1.0/files/p11/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'physionet.org/files/mimic-cxr/2.1.0/files/p11/index.html'
#
#
# physionet.org/files     [<=>                 ]       0  --.-KB/s
# physionet.org/files     [ <=>                ] 335.74K  1.51MB/s
# physionet.org/files     [  <=>               ] 399.74K   817KB/s
# physionet.org/files     [   <=>              ] 415.74K   597KB/s
# physionet.org/files     [    <=>             ] 495.74K   528KB/s
# physionet.org/files     [     <=>            ] 543.74K   465KB/s
# physionet.org/files     [      <=>           ] 591.74K   429KB/s
# physionet.org/files     [       <=>          ] 639.74K   402KB/s
# physionet.org/files     [        <=>         ] 687.74K   382KB/s
# physionet.org/files     [         <=>        ] 738.19K   368KB/s
# physionet.org/files     [          <=>       ] 738.19K   368KB/s    in 2.0s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-11-10 12:44:03 (368 KB/s) - 'physionet.org/files/mimic-cxr/2.1.0/files/p11/index.html' saved [755910]
#
# --2025-11-10 12:44:03--  https://physionet.org/files/mimic-cxr/2.1.0/files/p12/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'physionet.org/files/mimic-cxr/2.1.0/files/p12/index.html'
#
#
# physionet.org/files     [<=>                 ]       0  --.-KB/s
# physionet.org/files     [ <=>                ] 319.74K  1.30MB/s
# physionet.org/files     [  <=>               ] 383.74K   803KB/s
# physionet.org/files     [   <=>              ] 431.74K   613KB/s
# physionet.org/files     [    <=>             ] 479.74K   457KB/s
# physionet.org/files     [     <=>            ] 511.74K   390KB/s
# physionet.org/files     [      <=>           ] 543.74K   350KB/s
# physionet.org/files     [       <=>          ] 575.74K   294KB/s
# physionet.org/files     [        <=>         ] 623.74K   272KB/s
# physionet.org/files     [         <=>        ] 655.74K   248KB/s
# physionet.org/files     [          <=>       ] 687.74K   231KB/s
# physionet.org/files     [           <=>      ] 719.74K   217KB/s
# physionet.org/files     [            <=>     ] 733.36K   213KB/s    in 3.4s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-11-10 12:44:08 (213 KB/s) - 'physionet.org/files/mimic-cxr/2.1.0/files/p12/index.html' saved [750965]
#
# --2025-11-10 12:44:08--  https://physionet.org/files/mimic-cxr/2.1.0/files/p13/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'physionet.org/files/mimic-cxr/2.1.0/files/p13/index.html'
#
#
# physionet.org/files     [<=>                 ]       0  --.-KB/s
# physionet.org/files     [ <=>                ] 239.74K  1.07MB/s
# physionet.org/files     [  <=>               ] 287.74K   656KB/s
# physionet.org/files     [   <=>              ] 335.74K   510KB/s
# physionet.org/files     [    <=>             ] 399.74K   431KB/s
# physionet.org/files     [     <=>            ] 463.74K   398KB/s
# physionet.org/files     [      <=>           ] 527.74K   380KB/s
# physionet.org/files     [       <=>          ] 591.74K   359KB/s
# physionet.org/files     [        <=>         ] 671.74K   356KB/s
# physionet.org/files     [         <=>        ] 735.74K   347KB/s
# physionet.org/files     [          <=>       ] 735.83K   347KB/s    in 2.1s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-11-10 12:44:11 (347 KB/s) - 'physionet.org/files/mimic-cxr/2.1.0/files/p13/index.html' saved [753495]
#
# --2025-11-10 12:44:12--  https://physionet.org/files/mimic-cxr/2.1.0/files/p14/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'physionet.org/files/mimic-cxr/2.1.0/files/p14/index.html'
#
#
# physionet.org/files     [<=>                 ]       0  --.-KB/s
# physionet.org/files     [ <=>                ] 351.74K  1.34MB/s
# physionet.org/files     [  <=>               ] 399.74K   827KB/s
# physionet.org/files     [   <=>              ] 447.74K   631KB/s
# physionet.org/files     [    <=>             ] 495.74K   531KB/s
# physionet.org/files     [     <=>            ] 543.74K   471KB/s
# physionet.org/files     [      <=>           ] 591.74K   432KB/s
# physionet.org/files     [       <=>          ] 655.74K   377KB/s
# physionet.org/files     [        <=>         ] 731.01K   366KB/s
# physionet.org/files     [         <=>        ] 731.01K   366KB/s    in 2.0s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-11-10 12:44:15 (366 KB/s) - 'physionet.org/files/mimic-cxr/2.1.0/files/p14/index.html' saved [748550]
#
# --2025-11-10 12:44:15--  https://physionet.org/files/mimic-cxr/2.1.0/files/p15/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'physionet.org/files/mimic-cxr/2.1.0/files/p15/index.html'
#
#
# physionet.org/files     [<=>                 ]       0  --.-KB/s
# physionet.org/files     [ <=>                ] 287.74K  1.07MB/s
# physionet.org/files     [  <=>               ] 319.74K   619KB/s
# physionet.org/files     [   <=>              ] 367.74K   491KB/s
# physionet.org/files     [    <=>             ] 399.74K   416KB/s
# physionet.org/files     [     <=>            ] 447.74K   371KB/s
# physionet.org/files     [      <=>           ] 495.74K   322KB/s
# physionet.org/files     [       <=>          ] 543.74K   302KB/s
# physionet.org/files     [        <=>         ] 575.74K   285KB/s
# physionet.org/files     [         <=>        ] 623.74K   271KB/s
# physionet.org/files     [          <=>       ] 671.74K   262KB/s
# physionet.org/files     [           <=>      ] 719.74K   254KB/s
# physionet.org/files     [            <=>     ] 740.66K   249KB/s    in 3.0s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-11-10 12:44:19 (249 KB/s) - 'physionet.org/files/mimic-cxr/2.1.0/files/p15/index.html' saved [758440]
#
# --2025-11-10 12:44:20--  https://physionet.org/files/mimic-cxr/2.1.0/files/p16/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'physionet.org/files/mimic-cxr/2.1.0/files/p16/index.html'
#
#
# physionet.org/files     [<=>                 ]       0  --.-KB/s
# physionet.org/files     [ <=>                ] 335.74K  1.52MB/s
# physionet.org/files     [  <=>               ] 383.74K   761KB/s
# physionet.org/files     [   <=>              ] 463.74K   643KB/s
# physionet.org/files     [    <=>             ] 479.74K   502KB/s
# physionet.org/files     [     <=>            ] 559.74K   449KB/s
# physionet.org/files     [      <=>           ] 607.74K   408KB/s
# physionet.org/files     [       <=>          ] 655.74K   375KB/s
# physionet.org/files     [        <=>         ] 703.74K   356KB/s
# physionet.org/files     [         <=>        ] 727.52K   346KB/s    in 2.1s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-11-10 12:44:23 (346 KB/s) - 'physionet.org/files/mimic-cxr/2.1.0/files/p16/index.html' saved [744985]
#
# --2025-11-10 12:44:23--  https://physionet.org/files/mimic-cxr/2.1.0/files/p17/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'physionet.org/files/mimic-cxr/2.1.0/files/p17/index.html'
#
#
# physionet.org/files     [<=>                 ]       0  --.-KB/s
# physionet.org/files     [ <=>                ] 255.74K   901KB/s
# physionet.org/files     [  <=>               ] 287.74K   577KB/s
# physionet.org/files     [   <=>              ] 335.74K   430KB/s
# physionet.org/files     [    <=>             ] 367.74K   337KB/s
# physionet.org/files     [     <=>            ] 415.74K   303KB/s
# physionet.org/files     [      <=>           ] 447.74K   279KB/s
# physionet.org/files     [       <=>          ] 479.74K   265KB/s
# physionet.org/files     [        <=>         ] 511.74K   251KB/s
# physionet.org/files     [         <=>        ] 543.74K   235KB/s
# physionet.org/files     [          <=>       ] 575.74K   227KB/s
# physionet.org/files     [           <=>      ] 607.74K   217KB/s
# physionet.org/files     [            <=>     ] 639.74K   212KB/s
# physionet.org/files     [             <=>    ] 687.74K   208KB/s
# physionet.org/files     [              <=>   ] 719.74K   205KB/s
# physionet.org/files     [               <=>  ] 746.39K   202KB/s    in 3.7s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-11-10 12:44:28 (202 KB/s) - 'physionet.org/files/mimic-cxr/2.1.0/files/p17/index.html' saved [764305]
#
# --2025-11-10 12:44:29--  https://physionet.org/files/mimic-cxr/2.1.0/files/p18/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'physionet.org/files/mimic-cxr/2.1.0/files/p18/index.html'
#
#
# physionet.org/files     [<=>                 ]       0  --.-KB/s
# physionet.org/files     [ <=>                ] 239.74K  1.07MB/s
# physionet.org/files     [  <=>               ] 271.74K   646KB/s
# physionet.org/files     [   <=>              ] 319.74K   483KB/s
# physionet.org/files     [    <=>             ] 367.74K   398KB/s
# physionet.org/files     [     <=>            ] 415.74K   348KB/s
# physionet.org/files     [      <=>           ] 447.74K   308KB/s
# physionet.org/files     [       <=>          ] 511.74K   293KB/s
# physionet.org/files     [        <=>         ] 527.74K   264KB/s
# physionet.org/files     [         <=>        ] 575.74K   259KB/s
# physionet.org/files     [          <=>       ] 607.74K   248KB/s
# physionet.org/files     [           <=>      ] 639.74K   236KB/s
# physionet.org/files     [            <=>     ] 671.74K   229KB/s
# physionet.org/files     [             <=>    ] 703.74K   223KB/s
# physionet.org/files     [              <=>   ] 735.05K   219KB/s    in 3.4s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-11-10 12:44:33 (219 KB/s) - 'physionet.org/files/mimic-cxr/2.1.0/files/p18/index.html' saved [752690]
#
# --2025-11-10 12:44:34--  https://physionet.org/files/mimic-cxr/2.1.0/files/p19/
# Reusing existing connection to physionet.org:443.

# %% [markdown]
# ## 2.2 `Check files`

# %%
import os
import hashlib
from pathlib import Path

# --- Step 1: Define and check the base location ---
# location = Path("E:/Data/MIMIC_IV")  # example path — adjust for your setup
if 'location' not in locals():
    location = Path(input("Enter download location (full path): "))

print(f"\n✅ Checking data in folder: {location}")


# --- Step 2: Define checksum file path ---
checksum_file = location / "SHA256SUMS.txt"
if not checksum_file.exists():
    raise FileNotFoundError(f"Checksum file not found: {checksum_file}")

# --- Step 3: Load checksums ---
checksums = {}
with open(checksum_file, "r", encoding="utf-8") as f:
    for line in f:
        hash_val, rel_path = line.split(" ")
        cur_path = location / rel_path.strip()
        checksums[ cur_path ] = hash_val.strip()

print(f"Found {len(checksums)} entries in {checksum_file.name}")


# --- Step 4: Verify files ---
def sha256sum(file_path):
    """Compute SHA256 hash for a file."""
    h = hashlib.sha256()
    with open(file_path, "rb") as f:
        for chunk in iter(lambda: f.read(8192), b""):
            h.update(chunk)
    return h.hexdigest()

results = []
for rel_path, expected_hash in checksums.items():
    file_path = location / rel_path
    if not file_path.exists():
        results.append((rel_path, "❌ Missing", None))
        continue

    actual_hash = sha256sum(file_path)
    if actual_hash.lower() == expected_hash.lower():
        results.append((rel_path, "✅ OK", actual_hash))
    else:
        results.append((rel_path, "⚠️ Mismatch", actual_hash))

# --- Step 5: Display results ---
print("\n=== Verification Report ===")
for rel_path, status, actual in results:
    print(f"{status:10s}  {rel_path}")

# Optional: summary counts
ok = sum(1 for r in results if "OK" in r[1])
missing = sum(1 for r in results if "Missing" in r[1])
mismatch = sum(1 for r in results if "Mismatch" in r[1])
print(f"\nSummary: {ok} OK, {missing} Missing, {mismatch} Mismatch\n")

# %% [markdown]
# # 3 `MIMIC-CXR: multi-threading`

# %% [markdown]
# ## 3.1 `Download CHECKSUM`

# %%
# Add project root to sys.path

import sys
from pathlib import Path
import os, sys, subprocess
from getpass import getpass



ROOT = Path.cwd()
for parent in [ROOT] + list(ROOT.parents):
    if (parent / "config").is_dir():
        ROOT = parent
        break
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

print( '[X] Root fount' )

from xrh.settings import write_parameter, read_parameter
# Out:
# [X] Root fount

# %%
username = input("Enter PhysioNet username: ")
password = getpass("Enter PhysioNet password: ")
location = input("Enter download location (full path): ")

write_parameter("MIMIC_CXR_src_data_path", location)

# %%
os.makedirs(location, exist_ok=True)
os.chdir(location)

url = "https://physionet.org/files/mimic-cxr/2.1.0/SHA256SUMS.txt"
cmd = [
    "wget",
    "-r", "-N", "-c", "-np",
    "--show-progress", "--progress=bar:force:noscroll",
#    "--accept-regex", "(/files/|/files/p10/|/files/p10/p1000.*)",
    "--user", username,
    "--password", password,
    url,
]

# Stream wget output live so progress is visible
proc = subprocess.Popen(
    cmd,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1,
)

for line in proc.stdout:
    print(line, end="")
    sys.stdout.flush()

proc.wait()
if proc.returncode == 0:
    print("\n✅ Files folder download complete.")
else:
    print(f"\n❌ wget exited with code {proc.returncode}")
# Out:
# --2025-11-20 21:21:27--  https://physionet.org/files/mimic-cxr/2.1.0/SHA256SUMS.txt
# Resolving physionet.org (physionet.org)... 18.18.42.54
# Connecting to physionet.org (physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="PhysioNet", charset="UTF-8"
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 76859934 (73M) [text/plain]
# Saving to: 'physionet.org/files/mimic-cxr/2.1.0/SHA256SUMS.txt'
#
#
# physionet.org/files   0%[                    ]       0  --.-KB/s
# physionet.org/files   0%[                    ]  47.49K   178KB/s
# physionet.org/files   0%[                    ]  63.49K   133KB/s
# physionet.org/files   0%[                    ] 143.49K   201KB/s
# physionet.org/files   0%[                    ] 191.49K   198KB/s
# physionet.org/files   0%[                    ] 223.49K   191KB/s
# physionet.org/files   0%[                    ] 271.49K   190KB/s
# physionet.org/files   0%[                    ] 319.49K   192KB/s
# physionet.org/files   0%[                    ] 367.49K   193KB/s
# physionet.org/files   0%[                    ] 415.49K   193KB/s
# physionet.org/files   0%[                    ] 463.49K   197KB/s
# physionet.org/files   0%[                    ] 511.49K   199KB/s
# physionet.org/files   0%[                    ] 559.49K   202KB/s
# physionet.org/files   0%[                    ] 591.49K   198KB/s
# physionet.org/files   0%[                    ] 655.49K   202KB/s    eta 6m 8s
# physionet.org/files   0%[                    ] 703.49K   202KB/s    eta 6m 8s
# physionet.org/files   1%[                    ] 751.49K   203KB/s    eta 6m 8s
# physionet.org/files   1%[                    ] 799.49K   205KB/s    eta 6m 8s
# physionet.org/files   1%[                    ] 847.49K   206KB/s    eta 6m 8s
# physionet.org/files   1%[                    ] 879.49K   210KB/s    eta 6m 8s
# physionet.org/files   1%[                    ] 943.49K   206KB/s    eta 6m 8s
# physionet.org/files   1%[                    ] 991.49K   208KB/s    eta 6m 8s
# physionet.org/files   1%[                    ]   1.01M   211KB/s    eta 6m 8s
# physionet.org/files   1%[                    ]   1.05M   208KB/s    eta 6m 8s
# physionet.org/files   1%[                    ]   1.09M   209KB/s    eta 6m 4s
# physionet.org/files   1%[                    ]   1.12M   201KB/s    eta 6m 4s
# physionet.org/files   1%[                    ]   1.16M   195KB/s    eta 6m 4s
# physionet.org/files   1%[                    ]   1.19M   190KB/s    eta 6m 4s
# physionet.org/files   1%[                    ]   1.22M   185KB/s    eta 6m 26s
# physionet.org/files   1%[                    ]   1.25M   181KB/s    eta 6m 26s
# physionet.org/files   1%[                    ]   1.30M   184KB/s    eta 6m 26s
# physionet.org/files   1%[                    ]   1.34M   179KB/s    eta 6m 26s
# physionet.org/files   1%[                    ]   1.39M   179KB/s    eta 6m 26s
# physionet.org/files   1%[                    ]   1.44M   178KB/s    eta 6m 27s
# physionet.org/files   2%[                    ]   1.48M   176KB/s    eta 6m 27s
# physionet.org/files   2%[                    ]   1.53M   177KB/s    eta 6m 27s
# physionet.org/files   2%[                    ]   1.58M   172KB/s    eta 6m 27s
# physionet.org/files   2%[                    ]   1.62M   167KB/s    eta 6m 31s
# physionet.org/files   2%[                    ]   1.69M   170KB/s    eta 6m 31s
# physionet.org/files   2%[                    ]   1.73M   170KB/s    eta 6m 31s
# physionet.org/files   2%[                    ]   1.78M   171KB/s    eta 6m 31s
# physionet.org/files   2%[                    ]   1.83M   175KB/s    eta 6m 29s
# physionet.org/files   2%[                    ]   1.87M   179KB/s    eta 6m 29s
# physionet.org/files   2%[                    ]   1.92M   184KB/s    eta 6m 29s
# physionet.org/files   2%[                    ]   1.97M   187KB/s    eta 6m 29s
# physionet.org/files   2%[                    ]   2.03M   193KB/s    eta 6m 29s
# physionet.org/files   2%[                    ]   2.09M   198KB/s    eta 6m 19s
# physionet.org/files   2%[                    ]   2.16M   202KB/s    eta 6m 19s
# physionet.org/files   3%[                    ]   2.22M   207KB/s    eta 6m 19s
# physionet.org/files   3%[                    ]   2.28M   217KB/s    eta 6m 19s
# physionet.org/files   3%[                    ]   2.34M   217KB/s    eta 6m 19s
# physionet.org/files   3%[                    ]   2.41M   218KB/s    eta 6m 4s
# physionet.org/files   3%[                    ]   2.48M   224KB/s    eta 6m 4s
# physionet.org/files   3%[                    ]   2.51M   227KB/s    eta 6m 4s
# physionet.org/files   3%[                    ]   2.56M   224KB/s    eta 6m 4s
# physionet.org/files   3%[                    ]   2.61M   225KB/s    eta 6m 4s
# physionet.org/files   3%[                    ]   2.66M   225KB/s    eta 6m 4s
# physionet.org/files   3%[                    ]   2.70M   226KB/s    eta 6m 4s
# physionet.org/files   3%[                    ]   2.75M   227KB/s    eta 6m 4s
# physionet.org/files   3%[                    ]   2.80M   226KB/s    eta 6m 4s
# physionet.org/files   3%[                    ]   2.84M   226KB/s    eta 6m 1s
# physionet.org/files   3%[                    ]   2.91M   225KB/s    eta 6m 1s
# physionet.org/files   4%[                    ]   2.97M   224KB/s    eta 6m 1s
# physionet.org/files   4%[                    ]   3.00M   216KB/s    eta 6m 1s
# physionet.org/files   4%[                    ]   3.06M   214KB/s    eta 5m 59s
# physionet.org/files   4%[                    ]   3.09M   207KB/s    eta 5m 59s
# physionet.org/files   4%[                    ]   3.12M   201KB/s    eta 5m 59s
# physionet.org/files   4%[                    ]   3.16M   194KB/s    eta 5m 59s
# physionet.org/files   4%[                    ]   3.20M   192KB/s    eta 5m 59s
# physionet.org/files   4%[                    ]   3.23M   186KB/s    eta 6m 4s
# physionet.org/files   4%[                    ]   3.28M   187KB/s    eta 6m 4s
# physionet.org/files   4%[                    ]   3.33M   187KB/s    eta 6m 4s
# physionet.org/files   4%[                    ]   3.37M   187KB/s    eta 6m 4s
# physionet.org/files   4%[                    ]   3.42M   181KB/s    eta 6m 8s
# physionet.org/files   4%[                    ]   3.47M   182KB/s    eta 6m 8s
# physionet.org/files   4%[                    ]   3.50M   180KB/s    eta 6m 8s
# physionet.org/files   4%[                    ]   3.53M   176KB/s    eta 6m 8s
# physionet.org/files   4%[                    ]   3.58M   175KB/s    eta 6m 8s
# physionet.org/files   4%[                    ]   3.62M   168KB/s    eta 6m 9s
# physionet.org/files   5%[>                   ]   3.67M   171KB/s    eta 6m 9s
# physionet.org/files   5%[>                   ]   3.72M   167KB/s    eta 6m 9s
# physionet.org/files   5%[>                   ]   3.76M   169KB/s    eta 6m 9s
# physionet.org/files   5%[>                   ]   3.80M   169KB/s    eta 6m 9s
# physionet.org/files   5%[>                   ]   3.83M   164KB/s    eta 6m 12s
# physionet.org/files   5%[>                   ]   3.89M   169KB/s    eta 6m 12s
# physionet.org/files   5%[>                   ]   3.92M   166KB/s    eta 6m 12s
# physionet.org/files   5%[>                   ]   3.95M   166KB/s    eta 6m 12s
# physionet.org/files   5%[>                   ]   3.98M   166KB/s    eta 6m 12s
# physionet.org/files   5%[>                   ]   4.03M   166KB/s    eta 6m 13s
# physionet.org/files   5%[>                   ]   4.08M   170KB/s    eta 6m 13s
# physionet.org/files   5%[>                   ]   4.12M   171KB/s    eta 6m 13s
# physionet.org/files   5%[>                   ]   4.17M   173KB/s    eta 6m 13s
# physionet.org/files   5%[>                   ]   4.20M   164KB/s    eta 6m 15s
# physionet.org/files   5%[>                   ]   4.28M   171KB/s    eta 6m 15s
# physionet.org/files   5%[>                   ]   4.33M   169KB/s    eta 6m 15s
# physionet.org/files   5%[>                   ]   4.36M   166KB/s    eta 6m 15s
# physionet.org/files   5%[>                   ]   4.39M   164KB/s    eta 6m 15s
# physionet.org/files   6%[>                   ]   4.42M   163KB/s    eta 6m 15s
# physionet.org/files   6%[>                   ]   4.47M   164KB/s    eta 6m 15s
# physionet.org/files   6%[>                   ]   4.51M   169KB/s    eta 6m 15s
# physionet.org/files   6%[>                   ]   4.55M   162KB/s    eta 6m 17s
# physionet.org/files   6%[>                   ]   4.59M   167KB/s    eta 6m 17s
# physionet.org/files   6%[>                   ]   4.62M   167KB/s    eta 6m 17s
# physionet.org/files   6%[>                   ]   4.66M   166KB/s    eta 6m 17s
# physionet.org/files   6%[>                   ]   4.70M   167KB/s    eta 6m 17s
# physionet.org/files   6%[>                   ]   4.75M   167KB/s    eta 6m 16s
# physionet.org/files   6%[>                   ]   4.80M   167KB/s    eta 6m 16s
# physionet.org/files   6%[>                   ]   4.84M   167KB/s    eta 6m 16s
# physionet.org/files   6%[>                   ]   4.89M   175KB/s    eta 6m 16s
# physionet.org/files   6%[>                   ]   4.94M   170KB/s    eta 6m 16s
# physionet.org/files   6%[>                   ]   4.98M   176KB/s    eta 6m 13s
# physionet.org/files   6%[>                   ]   5.01M   175KB/s    eta 6m 13s
# physionet.org/files   6%[>                   ]   5.08M   182KB/s    eta 6m 13s
# physionet.org/files   6%[>                   ]   5.12M   187KB/s    eta 6m 13s
# physionet.org/files   7%[>                   ]   5.17M   190KB/s    eta 6m 13s
# physionet.org/files   7%[>                   ]   5.22M   187KB/s    eta 6m 11s
# physionet.org/files   7%[>                   ]   5.28M   194KB/s    eta 6m 11s
# physionet.org/files   7%[>                   ]   5.33M   198KB/s    eta 6m 11s
# physionet.org/files   7%[>                   ]   5.37M   199KB/s    eta 6m 11s
# physionet.org/files   7%[>                   ]   5.42M   201KB/s    eta 6m 11s
# physionet.org/files   7%[>                   ]   5.47M   202KB/s    eta 6m 8s
# physionet.org/files   7%[>                   ]   5.51M   204KB/s    eta 6m 8s
# physionet.org/files   7%[>                   ]   5.56M   206KB/s    eta 6m 8s
# physionet.org/files   7%[>                   ]   5.61M   204KB/s    eta 6m 8s
# physionet.org/files   7%[>                   ]   5.66M   204KB/s    eta 6m 8s
# physionet.org/files   7%[>                   ]   5.70M   204KB/s    eta 6m 6s
# physionet.org/files   7%[>                   ]   5.75M   199KB/s    eta 6m 6s
# physionet.org/files   7%[>                   ]   5.81M   197KB/s    eta 6m 6s
# physionet.org/files   7%[>                   ]   5.86M   196KB/s    eta 6m 6s
# physionet.org/files   8%[>                   ]   5.91M   193KB/s    eta 6m 6s
# physionet.org/files   8%[>                   ]   5.95M   190KB/s    eta 6m 6s
# physionet.org/files   8%[>                   ]   6.00M   185KB/s    eta 6m 6s
# physionet.org/files   8%[>                   ]   6.06M   188KB/s    eta 6m 6s
# physionet.org/files   8%[>                   ]   6.11M   187KB/s    eta 6m 5s
# physionet.org/files   8%[>                   ]   6.16M   186KB/s    eta 6m 5s
# physionet.org/files   8%[>                   ]   6.20M   191KB/s    eta 6m 5s
# physionet.org/files   8%[>                   ]   6.25M   180KB/s    eta 6m 5s
# physionet.org/files   8%[>                   ]   6.30M   183KB/s    eta 6m 4s
# physionet.org/files   8%[>                   ]   6.34M   181KB/s    eta 6m 4s
# physionet.org/files   8%[>                   ]   6.39M   186KB/s    eta 6m 4s
# physionet.org/files   8%[>                   ]   6.44M   183KB/s    eta 6m 4s
# physionet.org/files   8%[>                   ]   6.48M   187KB/s    eta 6m 4s
# physionet.org/files   8%[>                   ]   6.53M   183KB/s    eta 6m 3s
# physionet.org/files   8%[>                   ]   6.58M   186KB/s    eta 6m 3s
# physionet.org/files   9%[>                   ]   6.62M   184KB/s    eta 6m 3s
# physionet.org/files   9%[>                   ]   6.67M   190KB/s    eta 6m 3s
# physionet.org/files   9%[>                   ]   6.72M   187KB/s    eta 6m 3s
# physionet.org/files   9%[>                   ]   6.76M   189KB/s    eta 6m 2s
# physionet.org/files   9%[>                   ]   6.80M   184KB/s    eta 6m 2s
# physionet.org/files   9%[>                   ]   6.84M   185KB/s    eta 6m 2s
# physionet.org/files   9%[>                   ]   6.89M   183KB/s    eta 6m 2s
# physionet.org/files   9%[>                   ]   6.94M   189KB/s    eta 6m 2s
# physionet.org/files   9%[>                   ]   6.98M   187KB/s    eta 6m 1s
# physionet.org/files   9%[>                   ]   7.03M   189KB/s    eta 6m 1s
# physionet.org/files   9%[>                   ]   7.06M   183KB/s    eta 6m 1s
# physionet.org/files   9%[>                   ]   7.11M   186KB/s    eta 6m 1s
# physionet.org/files   9%[>                   ]   7.16M   183KB/s    eta 6m 1s
# physionet.org/files   9%[>                   ]   7.20M   187KB/s    eta 6m 0s
# physionet.org/files   9%[>                   ]   7.25M   186KB/s    eta 6m 0s
# physionet.org/files   9%[>                   ]   7.30M   188KB/s    eta 6m 0s
# physionet.org/files  10%[=>                  ]   7.34M   182KB/s    eta 6m 0s
# physionet.org/files  10%[=>                  ]   7.41M   185KB/s    eta 5m 59s
# physionet.org/files  10%[=>                  ]   7.45M   189KB/s    eta 5m 59s
# physionet.org/files  10%[=>                  ]   7.50M   186KB/s    eta 5m 59s
# physionet.org/files  10%[=>                  ]   7.55M   184KB/s    eta 5m 59s
# physionet.org/files  10%[=>                  ]   7.59M   184KB/s    eta 5m 59s
# physionet.org/files  10%[=>                  ]   7.62M   181KB/s    eta 5m 59s
# physionet.org/files  10%[=>                  ]   7.66M   179KB/s    eta 5m 59s
# physionet.org/files  10%[=>                  ]   7.70M   178KB/s    eta 5m 59s
# physionet.org/files  10%[=>                  ]   7.75M   178KB/s    eta 5m 59s
# physionet.org/files  10%[=>                  ]   7.80M   179KB/s    eta 5m 58s
# physionet.org/files  10%[=>                  ]   7.84M   181KB/s    eta 5m 58s
# physionet.org/files  10%[=>                  ]   7.89M   184KB/s    eta 5m 58s
# physionet.org/files  10%[=>                  ]   7.94M   185KB/s    eta 5m 58s
# physionet.org/files  10%[=>                  ]   8.00M   189KB/s    eta 5m 58s
# physionet.org/files  10%[=>                  ]   8.06M   192KB/s    eta 5m 54s
# physionet.org/files  11%[=>                  ]   8.09M   193KB/s    eta 5m 54s
# physionet.org/files  11%[=>                  ]   8.16M   195KB/s    eta 5m 54s
# physionet.org/files  11%[=>                  ]   8.20M   198KB/s    eta 5m 54s
# physionet.org/files  11%[=>                  ]   8.25M   200KB/s    eta 5m 54s
# physionet.org/files  11%[=>                  ]   8.30M   201KB/s    eta 5m 52s
# physionet.org/files  11%[=>                  ]   8.33M   201KB/s    eta 5m 52s
# physionet.org/files  11%[=>                  ]   8.39M   207KB/s    eta 5m 52s
# physionet.org/files  11%[=>                  ]   8.44M   207KB/s    eta 5m 52s
# physionet.org/files  11%[=>                  ]   8.48M   209KB/s    eta 5m 51s
# physionet.org/files  11%[=>                  ]   8.53M   210KB/s    eta 5m 51s
# physionet.org/files  11%[=>                  ]   8.58M   206KB/s    eta 5m 51s
# physionet.org/files  11%[=>                  ]   8.64M   208KB/s    eta 5m 51s
# physionet.org/files  11%[=>                  ]   8.67M   205KB/s    eta 5m 50s
# physionet.org/files  11%[=>                  ]   8.72M   200KB/s    eta 5m 50s
# physionet.org/files  11%[=>                  ]   8.76M   198KB/s    eta 5m 50s
# physionet.org/files  12%[=>                  ]   8.80M   198KB/s    eta 5m 50s
# physionet.org/files  12%[=>                  ]   8.86M   194KB/s    eta 5m 49s
# physionet.org/files  12%[=>                  ]   8.91M   193KB/s    eta 5m 49s
# physionet.org/files  12%[=>                  ]   8.95M   192KB/s    eta 5m 49s
# physionet.org/files  12%[=>                  ]   9.00M   191KB/s    eta 5m 49s
# physionet.org/files  12%[=>                  ]   9.05M   197KB/s    eta 5m 49s
# physionet.org/files  12%[=>                  ]   9.06M   187KB/s    eta 5m 48s
# physionet.org/files  12%[=>                  ]   9.12M   192KB/s    eta 5m 48s
# physionet.org/files  12%[=>                  ]   9.17M   191KB/s    eta 5m 48s
# physionet.org/files  12%[=>                  ]   9.22M   191KB/s    eta 5m 48s
# physionet.org/files  12%[=>                  ]   9.26M   191KB/s    eta 5m 46s
# physionet.org/files  12%[=>                  ]   9.31M   190KB/s    eta 5m 46s
# physionet.org/files  12%[=>                  ]   9.34M   191KB/s    eta 5m 46s
# physionet.org/files  12%[=>                  ]   9.39M   187KB/s    eta 5m 46s
# physionet.org/files  12%[=>                  ]   9.44M   186KB/s    eta 5m 46s
# physionet.org/files  12%[=>                  ]   9.48M   184KB/s    eta 5m 46s
# physionet.org/files  13%[=>                  ]   9.53M   189KB/s    eta 5m 46s
# physionet.org/files  13%[=>                  ]   9.55M   178KB/s    eta 5m 46s
# physionet.org/files  13%[=>                  ]   9.61M   182KB/s    eta 5m 46s
# physionet.org/files  13%[=>                  ]   9.66M   182KB/s    eta 5m 46s
# physionet.org/files  13%[=>                  ]   9.70M   181KB/s    eta 5m 46s
# physionet.org/files  13%[=>                  ]   9.73M   176KB/s    eta 5m 46s
# physionet.org/files  13%[=>                  ]   9.78M   178KB/s    eta 5m 46s
# physionet.org/files  13%[=>                  ]   9.81M   171KB/s    eta 5m 46s
# physionet.org/files  13%[=>                  ]   9.84M   171KB/s    eta 5m 46s
# physionet.org/files  13%[=>                  ]   9.89M   171KB/s    eta 5m 46s
# physionet.org/files  13%[=>                  ]   9.94M   169KB/s    eta 5m 46s
# physionet.org/files  13%[=>                  ]   9.98M   166KB/s    eta 5m 46s
# physionet.org/files  13%[=>                  ]  10.05M   169KB/s    eta 5m 46s
# physionet.org/files  13%[=>                  ]  10.09M   170KB/s    eta 5m 46s
# physionet.org/files  13%[=>                  ]  10.14M   172KB/s    eta 5m 46s
# physionet.org/files  13%[=>                  ]  10.19M   171KB/s    eta 5m 45s
# physionet.org/files  13%[=>                  ]  10.23M   180KB/s    eta 5m 45s
# physionet.org/files  14%[=>                  ]  10.28M   176KB/s    eta 5m 45s
# physionet.org/files  14%[=>                  ]  10.33M   178KB/s    eta 5m 45s
# physionet.org/files  14%[=>                  ]  10.39M   185KB/s    eta 5m 45s
# physionet.org/files  14%[=>                  ]  10.44M   186KB/s    eta 5m 42s
# physionet.org/files  14%[=>                  ]  10.50M   196KB/s    eta 5m 42s
# physionet.org/files  14%[=>                  ]  10.56M   202KB/s    eta 5m 42s
# physionet.org/files  14%[=>                  ]  10.59M   200KB/s    eta 5m 42s
# physionet.org/files  14%[=>                  ]  10.66M   207KB/s    eta 5m 42s
# physionet.org/files  14%[=>                  ]  10.70M   208KB/s    eta 5m 39s
# physionet.org/files  14%[=>                  ]  10.72M   202KB/s    eta 5m 39s
# physionet.org/files  14%[=>                  ]  10.80M   207KB/s    eta 5m 39s
# physionet.org/files  14%[=>                  ]  10.84M   210KB/s    eta 5m 39s
# physionet.org/files  14%[=>                  ]  10.89M   208KB/s    eta 5m 38s
# physionet.org/files  14%[=>                  ]  10.95M   208KB/s    eta 5m 38s
# physionet.org/files  15%[==>                 ]  11.00M   207KB/s    eta 5m 38s
# physionet.org/files  15%[==>                 ]  11.05M   204KB/s    eta 5m 38s
# physionet.org/files  15%[==>                 ]  11.08M   198KB/s    eta 5m 38s
# physionet.org/files  15%[==>                 ]  11.11M   194KB/s    eta 5m 38s
# physionet.org/files  15%[==>                 ]  11.14M   190KB/s    eta 5m 38s
# physionet.org/files  15%[==>                 ]  11.17M   185KB/s    eta 5m 38s
# physionet.org/files  15%[==>                 ]  11.22M   178KB/s    eta 5m 38s
# physionet.org/files  15%[==>                 ]  11.26M   175KB/s    eta 5m 38s
# physionet.org/files  15%[==>                 ]  11.31M   172KB/s    eta 5m 38s
# physionet.org/files  15%[==>                 ]  11.36M   171KB/s    eta 5m 38s
# physionet.org/files  15%[==>                 ]  11.41M   175KB/s    eta 5m 38s
# physionet.org/files  15%[==>                 ]  11.45M   168KB/s    eta 5m 37s
# physionet.org/files  15%[==>                 ]  11.50M   169KB/s    eta 5m 37s
# physionet.org/files  15%[==>                 ]  11.55M   174KB/s    eta 5m 37s
# physionet.org/files  15%[==>                 ]  11.59M   173KB/s    eta 5m 37s
# physionet.org/files  15%[==>                 ]  11.64M   172KB/s    eta 5m 36s
# physionet.org/files  15%[==>                 ]  11.67M   174KB/s    eta 5m 36s
# physionet.org/files  15%[==>                 ]  11.70M   168KB/s    eta 5m 36s
# physionet.org/files  16%[==>                 ]  11.73M   169KB/s    eta 5m 36s
# physionet.org/files  16%[==>                 ]  11.76M   170KB/s    eta 5m 36s
# physionet.org/files  16%[==>                 ]  11.80M   169KB/s    eta 5m 37s
# physionet.org/files  16%[==>                 ]  11.83M   169KB/s    eta 5m 37s
# physionet.org/files  16%[==>                 ]  11.87M   168KB/s    eta 5m 37s
# physionet.org/files  16%[==>                 ]  11.92M   168KB/s    eta 5m 37s
# physionet.org/files  16%[==>                 ]  11.95M   161KB/s    eta 5m 37s
# physionet.org/files  16%[==>                 ]  12.01M   168KB/s    eta 5m 37s
# physionet.org/files  16%[==>                 ]  12.06M   164KB/s    eta 5m 37s
# physionet.org/files  16%[==>                 ]  12.11M   164KB/s    eta 5m 37s
# physionet.org/files  16%[==>                 ]  12.16M   159KB/s    eta 5m 36s
# physionet.org/files  16%[==>                 ]  12.20M   160KB/s    eta 5m 36s
# physionet.org/files  16%[==>                 ]  12.23M   160KB/s    eta 5m 36s
# physionet.org/files  16%[==>                 ]  12.26M   158KB/s    eta 5m 36s
# physionet.org/files  16%[==>                 ]  12.30M   159KB/s    eta 5m 36s
# physionet.org/files  16%[==>                 ]  12.34M   163KB/s    eta 5m 36s
# physionet.org/files  16%[==>                 ]  12.37M   161KB/s    eta 5m 36s
# physionet.org/files  16%[==>                 ]  12.44M   166KB/s    eta 5m 36s
# physionet.org/files  17%[==>                 ]  12.48M   169KB/s    eta 5m 36s
# physionet.org/files  17%[==>                 ]  12.50M   164KB/s    eta 5m 36s
# physionet.org/files  17%[==>                 ]  12.55M   164KB/s    eta 5m 36s
# physionet.org/files  17%[==>                 ]  12.58M   162KB/s    eta 5m 36s
# physionet.org/files  17%[==>                 ]  12.62M   166KB/s    eta 5m 36s
# physionet.org/files  17%[==>                 ]  12.66M   161KB/s    eta 5m 36s
# physionet.org/files  17%[==>                 ]  12.70M   161KB/s    eta 5m 36s
# physionet.org/files  17%[==>                 ]  12.75M   161KB/s    eta 5m 36s
# physionet.org/files  17%[==>                 ]  12.80M   161KB/s    eta 5m 36s
# physionet.org/files  17%[==>                 ]  12.83M   158KB/s    eta 5m 35s
# physionet.org/files  17%[==>                 ]  12.86M   158KB/s    eta 5m 35s
# physionet.org/files  17%[==>                 ]  12.91M   160KB/s    eta 5m 35s
# physionet.org/files  17%[==>                 ]  12.95M   161KB/s    eta 5m 35s
# physionet.org/files  17%[==>                 ]  13.00M   162KB/s    eta 5m 35s
# physionet.org/files  17%[==>                 ]  13.05M   164KB/s    eta 5m 35s
# physionet.org/files  17%[==>                 ]  13.08M   164KB/s    eta 5m 35s
# physionet.org/files  17%[==>                 ]  13.12M   164KB/s    eta 5m 35s
# physionet.org/files  17%[==>                 ]  13.17M   168KB/s    eta 5m 34s
# physionet.org/files  18%[==>                 ]  13.22M   172KB/s    eta 5m 34s
# physionet.org/files  18%[==>                 ]  13.26M   176KB/s    eta 5m 34s
# physionet.org/files  18%[==>                 ]  13.31M   178KB/s    eta 5m 34s
# physionet.org/files  18%[==>                 ]  13.36M   179KB/s    eta 5m 34s
# physionet.org/files  18%[==>                 ]  13.41M   182KB/s    eta 5m 32s
# physionet.org/files  18%[==>                 ]  13.45M   187KB/s    eta 5m 32s
# physionet.org/files  18%[==>                 ]  13.50M   189KB/s    eta 5m 32s
# physionet.org/files  18%[==>                 ]  13.56M   198KB/s    eta 5m 32s
# physionet.org/files  18%[==>                 ]  13.61M   202KB/s    eta 5m 32s
# physionet.org/files  18%[==>                 ]  13.64M   199KB/s    eta 5m 30s
# physionet.org/files  18%[==>                 ]  13.70M   203KB/s    eta 5m 30s
# physionet.org/files  18%[==>                 ]  13.72M   197KB/s    eta 5m 30s
# physionet.org/files  18%[==>                 ]  13.78M   201KB/s    eta 5m 30s
# physionet.org/files  18%[==>                 ]  13.83M   199KB/s    eta 5m 29s
# physionet.org/files  18%[==>                 ]  13.87M   201KB/s    eta 5m 29s
# physionet.org/files  18%[==>                 ]  13.92M   202KB/s    eta 5m 29s
# physionet.org/files  19%[==>                 ]  13.97M   202KB/s    eta 5m 29s
# physionet.org/files  19%[==>                 ]  14.01M   200KB/s    eta 5m 28s
# physionet.org/files  19%[==>                 ]  14.05M   196KB/s    eta 5m 28s
# physionet.org/files  19%[==>                 ]  14.09M   195KB/s    eta 5m 28s
# physionet.org/files  19%[==>                 ]  14.14M   193KB/s    eta 5m 28s
# physionet.org/files  19%[==>                 ]  14.19M   189KB/s    eta 5m 27s
# physionet.org/files  19%[==>                 ]  14.23M   187KB/s    eta 5m 27s
# physionet.org/files  19%[==>                 ]  14.26M   179KB/s    eta 5m 27s
# physionet.org/files  19%[==>                 ]  14.31M   176KB/s    eta 5m 27s
# physionet.org/files  19%[==>                 ]  14.34M   179KB/s    eta 5m 27s
# physionet.org/files  19%[==>                 ]  14.39M   173KB/s    eta 5m 26s
# physionet.org/files  19%[==>                 ]  14.44M   173KB/s    eta 5m 26s
# physionet.org/files  19%[==>                 ]  14.48M   174KB/s    eta 5m 26s
# physionet.org/files  19%[==>                 ]  14.53M   177KB/s    eta 5m 26s
# physionet.org/files  19%[==>                 ]  14.58M   179KB/s    eta 5m 26s
# physionet.org/files  19%[==>                 ]  14.62M   177KB/s    eta 5m 25s
# physionet.org/files  20%[===>                ]  14.67M   177KB/s    eta 5m 25s
# physionet.org/files  20%[===>                ]  14.72M   181KB/s    eta 5m 25s
# physionet.org/files  20%[===>                ]  14.76M   181KB/s    eta 5m 25s
# physionet.org/files  20%[===>                ]  14.81M   182KB/s    eta 5m 24s
# physionet.org/files  20%[===>                ]  14.83M   177KB/s    eta 5m 24s
# physionet.org/files  20%[===>                ]  14.89M   181KB/s    eta 5m 24s
# physionet.org/files  20%[===>                ]  14.94M   180KB/s    eta 5m 24s
# physionet.org/files  20%[===>                ]  14.98M   184KB/s    eta 5m 23s
# physionet.org/files  20%[===>                ]  15.03M   185KB/s    eta 5m 23s
# physionet.org/files  20%[===>                ]  15.08M   188KB/s    eta 5m 23s
# physionet.org/files  20%[===>                ]  15.12M   184KB/s    eta 5m 23s
# physionet.org/files  20%[===>                ]  15.19M   188KB/s    eta 5m 22s
# physionet.org/files  20%[===>                ]  15.23M   187KB/s    eta 5m 22s
# physionet.org/files  20%[===>                ]  15.28M   186KB/s    eta 5m 22s
# physionet.org/files  20%[===>                ]  15.33M   185KB/s    eta 5m 22s
# physionet.org/files  20%[===>                ]  15.37M   182KB/s    eta 5m 21s
# physionet.org/files  21%[===>                ]  15.44M   187KB/s    eta 5m 21s
# physionet.org/files  21%[===>                ]  15.48M   185KB/s    eta 5m 21s
# physionet.org/files  21%[===>                ]  15.53M   185KB/s    eta 5m 21s
# physionet.org/files  21%[===>                ]  15.58M   192KB/s    eta 5m 19s
# physionet.org/files  21%[===>                ]  15.62M   183KB/s    eta 5m 19s
# physionet.org/files  21%[===>                ]  15.69M   189KB/s    eta 5m 19s
# physionet.org/files  21%[===>                ]  15.73M   187KB/s    eta 5m 19s
# physionet.org/files  21%[===>                ]  15.78M   186KB/s    eta 5m 18s
# physionet.org/files  21%[===>                ]  15.83M   187KB/s    eta 5m 18s
# physionet.org/files  21%[===>                ]  15.87M   184KB/s    eta 5m 18s
# physionet.org/files  21%[===>                ]  15.92M   187KB/s    eta 5m 18s
# physionet.org/files  21%[===>                ]  15.95M   185KB/s    eta 5m 18s
# physionet.org/files  21%[===>                ]  16.00M   184KB/s    eta 5m 18s
# physionet.org/files  21%[===>                ]  16.05M   184KB/s    eta 5m 18s
# physionet.org/files  21%[===>                ]  16.08M   177KB/s    eta 5m 18s
# physionet.org/files  22%[===>                ]  16.14M   178KB/s    eta 5m 17s
# physionet.org/files  22%[===>                ]  16.17M   177KB/s    eta 5m 17s
# physionet.org/files  22%[===>                ]  16.22M   178KB/s    eta 5m 17s
# physionet.org/files  22%[===>                ]  16.26M   175KB/s    eta 5m 17s
# physionet.org/files  22%[===>                ]  16.31M   174KB/s    eta 5m 16s
# physionet.org/files  22%[===>                ]  16.36M   174KB/s    eta 5m 16s
# physionet.org/files  22%[===>                ]  16.41M   175KB/s    eta 5m 16s
# physionet.org/files  22%[===>                ]  16.44M   172KB/s    eta 5m 16s
# physionet.org/files  22%[===>                ]  16.48M   173KB/s    eta 5m 16s
# physionet.org/files  22%[===>                ]  16.51M   170KB/s    eta 5m 15s
# physionet.org/files  22%[===>                ]  16.56M   174KB/s    eta 5m 15s
# physionet.org/files  22%[===>                ]  16.61M   173KB/s    eta 5m 15s
# physionet.org/files  22%[===>                ]  16.66M   176KB/s    eta 5m 15s
# physionet.org/files  22%[===>                ]  16.70M   177KB/s    eta 5m 15s
# physionet.org/files  22%[===>                ]  16.75M   178KB/s    eta 5m 14s
# physionet.org/files  22%[===>                ]  16.80M   191KB/s    eta 5m 14s
# physionet.org/files  22%[===>                ]  16.84M   187KB/s    eta 5m 14s
# physionet.org/files  23%[===>                ]  16.89M   191KB/s    eta 5m 14s
# physionet.org/files  23%[===>                ]  16.92M   191KB/s    eta 5m 14s
# physionet.org/files  23%[===>                ]  16.98M   195KB/s    eta 5m 12s
# physionet.org/files  23%[===>                ]  17.03M   196KB/s    eta 5m 12s
# physionet.org/files  23%[===>                ]  17.08M   197KB/s    eta 5m 12s
# physionet.org/files  23%[===>                ]  17.12M   192KB/s    eta 5m 12s
# physionet.org/files  23%[===>                ]  17.19M   202KB/s    eta 5m 10s
# physionet.org/files  23%[===>                ]  17.23M   202KB/s    eta 5m 10s
# physionet.org/files  23%[===>                ]  17.28M   202KB/s    eta 5m 10s
# physionet.org/files  23%[===>                ]  17.33M   204KB/s    eta 5m 10s
# physionet.org/files  23%[===>                ]  17.37M   205KB/s    eta 5m 10s
# physionet.org/files  23%[===>                ]  17.42M   206KB/s    eta 5m 9s
# physionet.org/files  23%[===>                ]  17.47M   207KB/s    eta 5m 9s
# physionet.org/files  23%[===>                ]  17.51M   209KB/s    eta 5m 9s
# physionet.org/files  23%[===>                ]  17.55M   204KB/s    eta 5m 9s
# physionet.org/files  24%[===>                ]  17.61M   203KB/s    eta 5m 9s
# physionet.org/files  24%[===>                ]  17.64M   198KB/s    eta 5m 7s
# physionet.org/files  24%[===>                ]  17.67M   195KB/s    eta 5m 7s
# physionet.org/files  24%[===>                ]  17.70M   189KB/s    eta 5m 7s
# physionet.org/files  24%[===>                ]  17.75M   187KB/s    eta 5m 7s
# physionet.org/files  24%[===>                ]  17.80M   185KB/s    eta 5m 7s
# physionet.org/files  24%[===>                ]  17.84M   188KB/s    eta 5m 7s
# physionet.org/files  24%[===>                ]  17.89M   185KB/s    eta 5m 7s
# physionet.org/files  24%[===>                ]  17.94M   187KB/s    eta 5m 7s
# physionet.org/files  24%[===>                ]  17.97M   181KB/s    eta 5m 6s
# physionet.org/files  24%[===>                ]  18.03M   185KB/s    eta 5m 6s
# physionet.org/files  24%[===>                ]  18.08M   178KB/s    eta 5m 6s
# physionet.org/files  24%[===>                ]  18.12M   178KB/s    eta 5m 6s
# physionet.org/files  24%[===>                ]  18.16M   173KB/s    eta 5m 5s
# physionet.org/files  24%[===>                ]  18.19M   169KB/s    eta 5m 5s
# physionet.org/files  24%[===>                ]  18.23M   173KB/s    eta 5m 5s
# physionet.org/files  24%[===>                ]  18.28M   169KB/s    eta 5m 5s
# physionet.org/files  25%[====>               ]  18.33M   172KB/s    eta 5m 5s
# physionet.org/files  25%[====>               ]  18.37M   178KB/s    eta 5m 5s
# physionet.org/files  25%[====>               ]  18.42M   180KB/s    eta 5m 5s
# physionet.org/files  25%[====>               ]  18.45M   175KB/s    eta 5m 5s
# physionet.org/files  25%[====>               ]  18.51M   181KB/s    eta 5m 5s
# physionet.org/files  25%[====>               ]  18.56M   179KB/s    eta 5m 3s
# physionet.org/files  25%[====>               ]  18.61M   178KB/s    eta 5m 3s
# physionet.org/files  25%[====>               ]  18.66M   185KB/s    eta 5m 3s
# physionet.org/files  25%[====>               ]  18.69M   167KB/s    eta 5m 3s
# physionet.org/files  25%[====>               ]  18.75M   173KB/s    eta 5m 3s
# physionet.org/files  25%[====>               ]  18.78M   167KB/s    eta 5m 3s
# physionet.org/files  25%[====>               ]  18.83M   162KB/s    eta 5m 3s
# physionet.org/files  25%[====>               ]  18.87M   158KB/s    eta 5m 3s
# physionet.org/files  25%[====>               ]  18.92M   158KB/s    eta 5m 3s
# physionet.org/files  25%[====>               ]  18.95M   158KB/s    eta 5m 3s
# physionet.org/files  25%[====>               ]  19.00M   155KB/s    eta 5m 3s
# physionet.org/files  25%[====>               ]  19.03M   153KB/s    eta 5m 3s
# physionet.org/files  26%[====>               ]  19.08M   153KB/s    eta 5m 2s
# physionet.org/files  26%[====>               ]  19.12M   152KB/s    eta 5m 2s
# physionet.org/files  26%[====>               ]  19.17M   145KB/s    eta 5m 2s
# physionet.org/files  26%[====>               ]  19.23M   144KB/s    eta 5m 2s
# physionet.org/files  26%[====>               ]  19.26M   150KB/s    eta 5m 2s
# physionet.org/files  26%[====>               ]  19.30M   143KB/s    eta 5m 2s
# physionet.org/files  26%[====>               ]  19.33M   142KB/s    eta 5m 2s
# physionet.org/files  26%[====>               ]  19.36M   140KB/s    eta 5m 2s
# physionet.org/files  26%[====>               ]  19.39M   145KB/s    eta 5m 2s
# physionet.org/files  26%[====>               ]  19.42M   145KB/s    eta 5m 2s
# physionet.org/files  26%[====>               ]  19.45M   148KB/s    eta 5m 2s
# physionet.org/files  26%[====>               ]  19.50M   148KB/s    eta 5m 2s
# physionet.org/files  26%[====>               ]  19.51M   142KB/s    eta 5m 2s
# physionet.org/files  26%[====>               ]  19.56M   145KB/s    eta 5m 2s
# physionet.org/files  26%[====>               ]  19.61M   145KB/s    eta 5m 2s
# physionet.org/files  26%[====>               ]  19.62M   140KB/s    eta 5m 2s
# physionet.org/files  26%[====>               ]  19.67M   140KB/s    eta 5m 2s
# physionet.org/files  26%[====>               ]  19.70M   135KB/s    eta 5m 2s
# physionet.org/files  26%[====>               ]  19.73M   133KB/s    eta 5m 2s
# physionet.org/files  26%[====>               ]  19.76M   136KB/s    eta 5m 2s
# physionet.org/files  27%[====>               ]  19.81M   135KB/s    eta 5m 2s
# physionet.org/files  27%[====>               ]  19.84M   133KB/s    eta 5m 2s
# physionet.org/files  27%[====>               ]  19.89M   137KB/s    eta 5m 2s
# physionet.org/files  27%[====>               ]  19.94M   141KB/s    eta 5m 2s
# physionet.org/files  27%[====>               ]  19.98M   147KB/s    eta 5m 1s
# physionet.org/files  27%[====>               ]  20.01M   146KB/s    eta 5m 1s
# physionet.org/files  27%[====>               ]  20.08M   152KB/s    eta 5m 1s
# physionet.org/files  27%[====>               ]  20.12M   155KB/s    eta 5m 1s
# physionet.org/files  27%[====>               ]  20.17M   156KB/s    eta 5m 0s
# physionet.org/files  27%[====>               ]  20.22M   158KB/s    eta 5m 0s
# physionet.org/files  27%[====>               ]  20.26M   162KB/s    eta 5m 0s
# physionet.org/files  27%[====>               ]  20.31M   168KB/s    eta 5m 0s
# physionet.org/files  27%[====>               ]  20.36M   168KB/s    eta 4m 59s
# physionet.org/files  27%[====>               ]  20.41M   173KB/s    eta 4m 59s
# physionet.org/files  27%[====>               ]  20.45M   180KB/s    eta 4m 59s
# physionet.org/files  27%[====>               ]  20.50M   179KB/s    eta 4m 59s
# physionet.org/files  28%[====>               ]  20.55M   182KB/s    eta 4m 58s
# physionet.org/files  28%[====>               ]  20.58M   177KB/s    eta 4m 58s
# physionet.org/files  28%[====>               ]  20.62M   177KB/s    eta 4m 58s
# physionet.org/files  28%[====>               ]  20.66M   171KB/s    eta 4m 58s
# physionet.org/files  28%[====>               ]  20.69M   171KB/s    eta 4m 58s
# physionet.org/files  28%[====>               ]  20.72M   166KB/s    eta 4m 58s
# physionet.org/files  28%[====>               ]  20.75M   164KB/s    eta 4m 58s
# physionet.org/files  28%[====>               ]  20.80M   164KB/s    eta 4m 58s
# physionet.org/files  28%[====>               ]  20.84M   162KB/s    eta 4m 58s
# physionet.org/files  28%[====>               ]  20.89M   167KB/s    eta 4m 57s
# physionet.org/files  28%[====>               ]  20.94M   166KB/s    eta 4m 57s
# physionet.org/files  28%[====>               ]  20.98M   169KB/s    eta 4m 57s
# physionet.org/files  28%[====>               ]  21.03M   168KB/s    eta 4m 57s
# physionet.org/files  28%[====>               ]  21.08M   168KB/s    eta 4m 56s
# physionet.org/files  28%[====>               ]  21.11M   163KB/s    eta 4m 56s
# physionet.org/files  28%[====>               ]  21.17M   165KB/s    eta 4m 56s
# physionet.org/files  28%[====>               ]  21.20M   164KB/s    eta 4m 56s
# physionet.org/files  28%[====>               ]  21.23M   166KB/s    eta 4m 55s
# physionet.org/files  29%[====>               ]  21.28M   169KB/s    eta 4m 55s
# physionet.org/files  29%[====>               ]  21.33M   168KB/s    eta 4m 55s
# physionet.org/files  29%[====>               ]  21.37M   177KB/s    eta 4m 55s
# physionet.org/files  29%[====>               ]  21.42M   179KB/s    eta 4m 54s
# physionet.org/files  29%[====>               ]  21.47M   182KB/s    eta 4m 54s
# physionet.org/files  29%[====>               ]  21.50M   180KB/s    eta 4m 54s
# physionet.org/files  29%[====>               ]  21.55M   179KB/s    eta 4m 54s
# physionet.org/files  29%[====>               ]  21.59M   180KB/s    eta 4m 54s
# physionet.org/files  29%[====>               ]  21.64M   181KB/s    eta 4m 53s
# physionet.org/files  29%[====>               ]  21.69M   181KB/s    eta 4m 53s
# physionet.org/files  29%[====>               ]  21.73M   185KB/s    eta 4m 53s
# physionet.org/files  29%[====>               ]  21.78M   184KB/s    eta 4m 53s
# physionet.org/files  29%[====>               ]  21.83M   188KB/s    eta 4m 53s
# physionet.org/files  29%[====>               ]  21.87M   196KB/s    eta 4m 51s
# physionet.org/files  29%[====>               ]  21.92M   195KB/s    eta 4m 51s
# physionet.org/files  29%[====>               ]  21.97M   195KB/s    eta 4m 51s
# physionet.org/files  30%[=====>              ]  22.05M   204KB/s    eta 4m 51s
# physionet.org/files  30%[=====>              ]  22.09M   206KB/s    eta 4m 49s
# physionet.org/files  30%[=====>              ]  22.14M   202KB/s    eta 4m 49s
# physionet.org/files  30%[=====>              ]  22.20M   207KB/s    eta 4m 49s
# physionet.org/files  30%[=====>              ]  22.25M   206KB/s    eta 4m 49s
# physionet.org/files  30%[=====>              ]  22.30M   209KB/s    eta 4m 48s
# physionet.org/files  30%[=====>              ]  22.34M   210KB/s    eta 4m 48s
# physionet.org/files  30%[=====>              ]  22.39M   212KB/s    eta 4m 48s
# physionet.org/files  30%[=====>              ]  22.42M   206KB/s    eta 4m 48s
# physionet.org/files  30%[=====>              ]  22.48M   209KB/s    eta 4m 48s
# physionet.org/files  30%[=====>              ]  22.53M   206KB/s    eta 4m 46s
# physionet.org/files  30%[=====>              ]  22.58M   205KB/s    eta 4m 46s
# physionet.org/files  30%[=====>              ]  22.61M   198KB/s    eta 4m 46s
# physionet.org/files  30%[=====>              ]  22.66M   197KB/s    eta 4m 46s
# physionet.org/files  30%[=====>              ]  22.70M   193KB/s    eta 4m 46s
# physionet.org/files  31%[=====>              ]  22.75M   191KB/s    eta 4m 45s
# physionet.org/files  31%[=====>              ]  22.80M   191KB/s    eta 4m 45s
# physionet.org/files  31%[=====>              ]  22.84M   196KB/s    eta 4m 45s
# physionet.org/files  31%[=====>              ]  22.89M   190KB/s    eta 4m 45s
# physionet.org/files  31%[=====>              ]  22.91M   184KB/s    eta 4m 45s
# physionet.org/files  31%[=====>              ]  22.97M   187KB/s    eta 4m 44s
# physionet.org/files  31%[=====>              ]  23.01M   184KB/s    eta 4m 44s
# physionet.org/files  31%[=====>              ]  23.06M   182KB/s    eta 4m 44s
# physionet.org/files  31%[=====>              ]  23.11M   187KB/s    eta 4m 44s
# physionet.org/files  31%[=====>              ]  23.14M   175KB/s    eta 4m 43s
# physionet.org/files  31%[=====>              ]  23.20M   179KB/s    eta 4m 43s
# physionet.org/files  31%[=====>              ]  23.23M   177KB/s    eta 4m 43s
# physionet.org/files  31%[=====>              ]  23.28M   179KB/s    eta 4m 43s
# physionet.org/files  31%[=====>              ]  23.33M   178KB/s    eta 4m 42s
# physionet.org/files  31%[=====>              ]  23.37M   180KB/s    eta 4m 42s
# physionet.org/files  31%[=====>              ]  23.42M   183KB/s    eta 4m 42s
# physionet.org/files  32%[=====>              ]  23.47M   184KB/s    eta 4m 42s
# physionet.org/files  32%[=====>              ]  23.50M   179KB/s    eta 4m 42s
# physionet.org/files  32%[=====>              ]  23.56M   181KB/s    eta 4m 40s
# physionet.org/files  32%[=====>              ]  23.61M   186KB/s    eta 4m 40s
# physionet.org/files  32%[=====>              ]  23.64M   176KB/s    eta 4m 40s
# physionet.org/files  32%[=====>              ]  23.70M   183KB/s    eta 4m 40s
# physionet.org/files  32%[=====>              ]  23.75M   181KB/s    eta 4m 39s
# physionet.org/files  32%[=====>              ]  23.80M   179KB/s    eta 4m 39s
# physionet.org/files  32%[=====>              ]  23.84M   185KB/s    eta 4m 39s
# physionet.org/files  32%[=====>              ]  23.89M   183KB/s    eta 4m 39s
# physionet.org/files  32%[=====>              ]  23.94M   185KB/s    eta 4m 38s
# physionet.org/files  32%[=====>              ]  23.97M   180KB/s    eta 4m 38s
# physionet.org/files  32%[=====>              ]  24.03M   182KB/s    eta 4m 38s
# physionet.org/files  32%[=====>              ]  24.08M   180KB/s    eta 4m 38s
# physionet.org/files  32%[=====>              ]  24.12M   178KB/s    eta 4m 37s
# physionet.org/files  32%[=====>              ]  24.16M   179KB/s    eta 4m 37s
# physionet.org/files  33%[=====>              ]  24.20M   174KB/s    eta 4m 37s
# physionet.org/files  33%[=====>              ]  24.23M   173KB/s    eta 4m 37s
# physionet.org/files  33%[=====>              ]  24.26M   171KB/s    eta 4m 37s
# physionet.org/files  33%[=====>              ]  24.31M   178KB/s    eta 4m 36s
# physionet.org/files  33%[=====>              ]  24.36M   173KB/s    eta 4m 36s
# physionet.org/files  33%[=====>              ]  24.41M   177KB/s    eta 4m 36s
# physionet.org/files  33%[=====>              ]  24.45M   180KB/s    eta 4m 36s
# physionet.org/files  33%[=====>              ]  24.50M   182KB/s    eta 4m 36s
# physionet.org/files  33%[=====>              ]  24.55M   184KB/s    eta 4m 35s
# physionet.org/files  33%[=====>              ]  24.58M   181KB/s    eta 4m 35s
# physionet.org/files  33%[=====>              ]  24.64M   184KB/s    eta 4m 35s
# physionet.org/files  33%[=====>              ]  24.69M   183KB/s    eta 4m 35s
# physionet.org/files  33%[=====>              ]  24.75M   186KB/s    eta 4m 33s
# physionet.org/files  33%[=====>              ]  24.80M   185KB/s    eta 4m 33s
# physionet.org/files  33%[=====>              ]  24.84M   188KB/s    eta 4m 33s
# physionet.org/files  33%[=====>              ]  24.89M   185KB/s    eta 4m 33s
# physionet.org/files  34%[=====>              ]  24.94M   189KB/s    eta 4m 32s
# physionet.org/files  34%[=====>              ]  24.98M   191KB/s    eta 4m 32s
# physionet.org/files  34%[=====>              ]  25.03M   194KB/s    eta 4m 32s
# physionet.org/files  34%[=====>              ]  25.08M   197KB/s    eta 4m 32s
# physionet.org/files  34%[=====>              ]  25.12M   195KB/s    eta 4m 31s
# physionet.org/files  34%[=====>              ]  25.20M   201KB/s    eta 4m 31s
# physionet.org/files  34%[=====>              ]  25.25M   200KB/s    eta 4m 31s
# physionet.org/files  34%[=====>              ]  25.30M   200KB/s    eta 4m 31s
# physionet.org/files  34%[=====>              ]  25.34M   200KB/s    eta 4m 31s
# physionet.org/files  34%[=====>              ]  25.39M   205KB/s    eta 4m 29s
# physionet.org/files  34%[=====>              ]  25.42M   195KB/s    eta 4m 29s
# physionet.org/files  34%[=====>              ]  25.48M   207KB/s    eta 4m 29s
# physionet.org/files  34%[=====>              ]  25.53M   201KB/s    eta 4m 29s
# physionet.org/files  34%[=====>              ]  25.58M   202KB/s    eta 4m 28s
# physionet.org/files  34%[=====>              ]  25.61M   200KB/s    eta 4m 28s
# physionet.org/files  34%[=====>              ]  25.64M   200KB/s    eta 4m 28s
# physionet.org/files  35%[======>             ]  25.69M   199KB/s    eta 4m 28s
# physionet.org/files  35%[======>             ]  25.73M   197KB/s    eta 4m 28s
# physionet.org/files  35%[======>             ]  25.76M   191KB/s    eta 4m 27s
# physionet.org/files  35%[======>             ]  25.81M   188KB/s    eta 4m 27s
# physionet.org/files  35%[======>             ]  25.84M   190KB/s    eta 4m 27s
# physionet.org/files  35%[======>             ]  25.89M   181KB/s    eta 4m 27s
# physionet.org/files  35%[======>             ]  25.94M   181KB/s    eta 4m 26s
# physionet.org/files  35%[======>             ]  25.98M   172KB/s    eta 4m 26s
# physionet.org/files  35%[======>             ]  26.03M   170KB/s    eta 4m 26s
# physionet.org/files  35%[======>             ]  26.08M   173KB/s    eta 4m 26s
# physionet.org/files  35%[======>             ]  26.12M   168KB/s    eta 4m 26s
# physionet.org/files  35%[======>             ]  26.17M   167KB/s    eta 4m 26s
# physionet.org/files  35%[======>             ]  26.22M   171KB/s    eta 4m 26s
# physionet.org/files  35%[======>             ]  26.26M   171KB/s    eta 4m 26s
# physionet.org/files  35%[======>             ]  26.31M   174KB/s    eta 4m 26s
# physionet.org/files  35%[======>             ]  26.36M   176KB/s    eta 4m 24s
# physionet.org/files  36%[======>             ]  26.41M   179KB/s    eta 4m 24s
# physionet.org/files  36%[======>             ]  26.45M   179KB/s    eta 4m 24s
# physionet.org/files  36%[======>             ]  26.53M   186KB/s    eta 4m 24s
# physionet.org/files  36%[======>             ]  26.58M   190KB/s    eta 4m 22s
# physionet.org/files  36%[======>             ]  26.62M   192KB/s    eta 4m 22s
# physionet.org/files  36%[======>             ]  26.67M   192KB/s    eta 4m 22s
# physionet.org/files  36%[======>             ]  26.72M   191KB/s    eta 4m 22s
# ...
# physionet.org/files  81%[===============>    ]  59.51M   311KB/s    eta 78s
# physionet.org/files  81%[===============>    ]  59.58M   310KB/s    eta 78s
# physionet.org/files  81%[===============>    ]  59.64M   311KB/s    eta 76s
# physionet.org/files  81%[===============>    ]  59.70M   311KB/s    eta 76s
# physionet.org/files  81%[===============>    ]  59.75M   301KB/s    eta 76s
# physionet.org/files  81%[===============>    ]  59.84M   305KB/s    eta 76s
# physionet.org/files  81%[===============>    ]  59.89M   299KB/s    eta 76s
# physionet.org/files  81%[===============>    ]  59.95M   309KB/s    eta 74s
# physionet.org/files  81%[===============>    ]  60.01M   296KB/s    eta 74s
# physionet.org/files  81%[===============>    ]  60.08M   296KB/s    eta 74s
# physionet.org/files  82%[===============>    ]  60.14M   295KB/s    eta 74s
# physionet.org/files  82%[===============>    ]  60.20M   293KB/s    eta 74s
# physionet.org/files  82%[===============>    ]  60.28M   292KB/s    eta 72s
# physionet.org/files  82%[===============>    ]  60.34M   291KB/s    eta 72s
# physionet.org/files  82%[===============>    ]  60.42M   291KB/s    eta 72s
# physionet.org/files  82%[===============>    ]  60.50M   290KB/s    eta 72s
# physionet.org/files  82%[===============>    ]  60.58M   295KB/s    eta 72s
# physionet.org/files  82%[===============>    ]  60.64M   287KB/s    eta 70s
# physionet.org/files  82%[===============>    ]  60.75M   296KB/s    eta 70s
# physionet.org/files  82%[===============>    ]  60.81M   295KB/s    eta 70s
# physionet.org/files  83%[===============>    ]  60.87M   296KB/s    eta 70s
# physionet.org/files  83%[===============>    ]  60.95M   302KB/s    eta 70s
# physionet.org/files  83%[===============>    ]  61.03M   307KB/s    eta 68s
# physionet.org/files  83%[===============>    ]  61.11M   312KB/s    eta 68s
# physionet.org/files  83%[===============>    ]  61.17M   305KB/s    eta 68s
# physionet.org/files  83%[===============>    ]  61.28M   318KB/s    eta 68s
# physionet.org/files  83%[===============>    ]  61.34M   318KB/s    eta 66s
# physionet.org/files  83%[===============>    ]  61.41M   317KB/s    eta 66s
# physionet.org/files  83%[===============>    ]  61.47M   316KB/s    eta 66s
# physionet.org/files  83%[===============>    ]  61.53M   316KB/s    eta 66s
# physionet.org/files  84%[===============>    ]  61.59M   315KB/s    eta 66s
# physionet.org/files  84%[===============>    ]  61.66M   314KB/s    eta 64s
# physionet.org/files  84%[===============>    ]  61.73M   313KB/s    eta 64s
# physionet.org/files  84%[===============>    ]  61.81M   324KB/s    eta 64s
# physionet.org/files  84%[===============>    ]  61.87M   302KB/s    eta 64s
# physionet.org/files  84%[===============>    ]  61.98M   316KB/s    eta 62s
# physionet.org/files  84%[===============>    ]  62.05M   314KB/s    eta 62s
# physionet.org/files  84%[===============>    ]  62.11M   313KB/s    eta 62s
# physionet.org/files  84%[===============>    ]  62.17M   313KB/s    eta 62s
# physionet.org/files  84%[===============>    ]  62.25M   312KB/s    eta 62s
# physionet.org/files  85%[================>   ]  62.33M   312KB/s    eta 60s
# physionet.org/files  85%[================>   ]  62.41M   314KB/s    eta 60s
# physionet.org/files  85%[================>   ]  62.45M   307KB/s    eta 60s
# physionet.org/files  85%[================>   ]  62.56M   317KB/s    eta 60s
# physionet.org/files  85%[================>   ]  62.62M   316KB/s    eta 60s
# physionet.org/files  85%[================>   ]  62.69M   317KB/s    eta 58s
# physionet.org/files  85%[================>   ]  62.76M   318KB/s    eta 58s
# physionet.org/files  85%[================>   ]  62.84M   319KB/s    eta 58s
# physionet.org/files  85%[================>   ]  62.89M   308KB/s    eta 58s
# physionet.org/files  85%[================>   ]  63.00M   316KB/s    eta 56s
# physionet.org/files  86%[================>   ]  63.06M   311KB/s    eta 56s
# physionet.org/files  86%[================>   ]  63.12M   309KB/s    eta 56s
# physionet.org/files  86%[================>   ]  63.19M   311KB/s    eta 56s
# physionet.org/files  86%[================>   ]  63.25M   310KB/s    eta 56s
# physionet.org/files  86%[================>   ]  63.31M   310KB/s    eta 54s
# physionet.org/files  86%[================>   ]  63.37M   309KB/s    eta 54s
# physionet.org/files  86%[================>   ]  63.44M   307KB/s    eta 54s
# physionet.org/files  86%[================>   ]  63.51M   308KB/s    eta 54s
# physionet.org/files  86%[================>   ]  63.58M   307KB/s    eta 54s
# physionet.org/files  86%[================>   ]  63.67M   304KB/s    eta 52s
# physionet.org/files  86%[================>   ]  63.73M   303KB/s    eta 52s
# physionet.org/files  87%[================>   ]  63.80M   304KB/s    eta 52s
# physionet.org/files  87%[================>   ]  63.86M   302KB/s    eta 52s
# physionet.org/files  87%[================>   ]  63.94M   302KB/s    eta 52s
# physionet.org/files  87%[================>   ]  64.01M   314KB/s    eta 50s
# physionet.org/files  87%[================>   ]  64.09M   306KB/s    eta 50s
# physionet.org/files  87%[================>   ]  64.14M   299KB/s    eta 50s
# physionet.org/files  87%[================>   ]  64.25M   310KB/s    eta 50s
# physionet.org/files  87%[================>   ]  64.31M   310KB/s    eta 50s
# physionet.org/files  87%[================>   ]  64.37M   311KB/s    eta 48s
# physionet.org/files  87%[================>   ]  64.44M   311KB/s    eta 48s
# physionet.org/files  88%[================>   ]  64.51M   313KB/s    eta 48s
# physionet.org/files  88%[================>   ]  64.58M   313KB/s    eta 48s
# physionet.org/files  88%[================>   ]  64.66M   303KB/s    eta 47s
# physionet.org/files  88%[================>   ]  64.75M   320KB/s    eta 47s
# physionet.org/files  88%[================>   ]  64.81M   310KB/s    eta 47s
# physionet.org/files  88%[================>   ]  64.87M   312KB/s    eta 47s
# physionet.org/files  88%[================>   ]  64.95M   313KB/s    eta 47s
# physionet.org/files  88%[================>   ]  65.03M   315KB/s    eta 44s
# physionet.org/files  88%[================>   ]  65.11M   314KB/s    eta 44s
# physionet.org/files  88%[================>   ]  65.17M   304KB/s    eta 44s
# physionet.org/files  89%[================>   ]  65.25M   306KB/s    eta 44s
# physionet.org/files  89%[================>   ]  65.31M   304KB/s    eta 44s
# physionet.org/files  89%[================>   ]  65.37M   305KB/s    eta 42s
# physionet.org/files  89%[================>   ]  65.41M   297KB/s    eta 42s
# physionet.org/files  89%[================>   ]  65.48M   302KB/s    eta 42s
# physionet.org/files  89%[================>   ]  65.55M   298KB/s    eta 42s
# physionet.org/files  89%[================>   ]  65.61M   293KB/s    eta 42s
# physionet.org/files  89%[================>   ]  65.67M   288KB/s    eta 41s
# physionet.org/files  89%[================>   ]  65.73M   295KB/s    eta 41s
# physionet.org/files  89%[================>   ]  65.80M   286KB/s    eta 41s
# physionet.org/files  89%[================>   ]  65.86M   287KB/s    eta 41s
# physionet.org/files  89%[================>   ]  65.92M   288KB/s    eta 41s
# physionet.org/files  90%[=================>  ]  66.00M   289KB/s    eta 39s
# physionet.org/files  90%[=================>  ]  66.08M   289KB/s    eta 39s
# physionet.org/files  90%[=================>  ]  66.16M   287KB/s    eta 39s
# physionet.org/files  90%[=================>  ]  66.25M   287KB/s    eta 39s
# physionet.org/files  90%[=================>  ]  66.31M   288KB/s    eta 37s
# physionet.org/files  90%[=================>  ]  66.37M   289KB/s    eta 37s
# physionet.org/files  90%[=================>  ]  66.44M   291KB/s    eta 37s
# physionet.org/files  90%[=================>  ]  66.51M   295KB/s    eta 37s
# physionet.org/files  90%[=================>  ]  66.59M   301KB/s    eta 37s
# physionet.org/files  90%[=================>  ]  66.67M   306KB/s    eta 35s
# physionet.org/files  91%[=================>  ]  66.72M   300KB/s    eta 35s
# physionet.org/files  91%[=================>  ]  66.81M   306KB/s    eta 35s
# physionet.org/files  91%[=================>  ]  66.87M   307KB/s    eta 35s
# physionet.org/files  91%[=================>  ]  66.94M   308KB/s    eta 35s
# physionet.org/files  91%[=================>  ]  67.01M   309KB/s    eta 33s
# physionet.org/files  91%[=================>  ]  67.09M   311KB/s    eta 33s
# physionet.org/files  91%[=================>  ]  67.17M   312KB/s    eta 33s
# physionet.org/files  91%[=================>  ]  67.25M   313KB/s    eta 33s
# physionet.org/files  91%[=================>  ]  67.28M   312KB/s    eta 33s
# physionet.org/files  91%[=================>  ]  67.39M   313KB/s    eta 31s
# physionet.org/files  92%[=================>  ]  67.45M   312KB/s    eta 31s
# physionet.org/files  92%[=================>  ]  67.51M   313KB/s    eta 31s
# physionet.org/files  92%[=================>  ]  67.58M   313KB/s    eta 31s
# physionet.org/files  92%[=================>  ]  67.66M   313KB/s    eta 31s
# physionet.org/files  92%[=================>  ]  67.73M   313KB/s    eta 29s
# physionet.org/files  92%[=================>  ]  67.81M   322KB/s    eta 29s
# physionet.org/files  92%[=================>  ]  67.86M   308KB/s    eta 29s
# physionet.org/files  92%[=================>  ]  67.95M   316KB/s    eta 29s
# physionet.org/files  92%[=================>  ]  68.01M   315KB/s    eta 29s
# physionet.org/files  92%[=================>  ]  68.08M   314KB/s    eta 28s
# physionet.org/files  92%[=================>  ]  68.14M   314KB/s    eta 28s
# physionet.org/files  93%[=================>  ]  68.22M   314KB/s    eta 28s
# physionet.org/files  93%[=================>  ]  68.30M   314KB/s    eta 28s
# physionet.org/files  93%[=================>  ]  68.37M   304KB/s    eta 26s
# physionet.org/files  93%[=================>  ]  68.47M   322KB/s    eta 26s
# physionet.org/files  93%[=================>  ]  68.53M   310KB/s    eta 26s
# physionet.org/files  93%[=================>  ]  68.59M   312KB/s    eta 26s
# physionet.org/files  93%[=================>  ]  68.67M   313KB/s    eta 26s
# physionet.org/files  93%[=================>  ]  68.75M   314KB/s    eta 24s
# physionet.org/files  93%[=================>  ]  68.83M   315KB/s    eta 24s
# physionet.org/files  94%[=================>  ]  68.91M   305KB/s    eta 24s
# physionet.org/files  94%[=================>  ]  69.00M   311KB/s    eta 24s
# physionet.org/files  94%[=================>  ]  69.06M   317KB/s    eta 22s
# physionet.org/files  94%[=================>  ]  69.12M   309KB/s    eta 22s
# physionet.org/files  94%[=================>  ]  69.20M   313KB/s    eta 22s
# physionet.org/files  94%[=================>  ]  69.28M   314KB/s    eta 22s
# physionet.org/files  94%[=================>  ]  69.36M   316KB/s    eta 22s
# physionet.org/files  94%[=================>  ]  69.44M   318KB/s    eta 20s
# physionet.org/files  94%[=================>  ]  69.51M   318KB/s    eta 20s
# physionet.org/files  94%[=================>  ]  69.59M   328KB/s    eta 20s
# physionet.org/files  95%[==================> ]  69.67M   322KB/s    eta 20s
# physionet.org/files  95%[==================> ]  69.75M   328KB/s    eta 20s
# physionet.org/files  95%[==================> ]  69.80M   321KB/s    eta 18s
# physionet.org/files  95%[==================> ]  69.89M   328KB/s    eta 18s
# physionet.org/files  95%[==================> ]  69.95M   326KB/s    eta 18s
# physionet.org/files  95%[==================> ]  70.01M   324KB/s    eta 18s
# physionet.org/files  95%[==================> ]  70.09M   324KB/s    eta 18s
# physionet.org/files  95%[==================> ]  70.17M   327KB/s    eta 16s
# physionet.org/files  95%[==================> ]  70.25M   331KB/s    eta 16s
# physionet.org/files  95%[==================> ]  70.30M   323KB/s    eta 16s
# physionet.org/files  96%[==================> ]  70.39M   330KB/s    eta 16s
# physionet.org/files  96%[==================> ]  70.45M   329KB/s    eta 16s
# physionet.org/files  96%[==================> ]  70.51M   326KB/s    eta 14s
# physionet.org/files  96%[==================> ]  70.58M   323KB/s    eta 14s
# physionet.org/files  96%[==================> ]  70.64M   321KB/s    eta 14s
# physionet.org/files  96%[==================> ]  70.72M   318KB/s    eta 14s
# physionet.org/files  96%[==================> ]  70.80M   317KB/s    eta 14s
# physionet.org/files  96%[==================> ]  70.87M   314KB/s    eta 13s
# physionet.org/files  96%[==================> ]  70.94M   315KB/s    eta 13s
# physionet.org/files  96%[==================> ]  71.03M   314KB/s    eta 13s
# physionet.org/files  96%[==================> ]  71.09M   313KB/s    eta 13s
# physionet.org/files  97%[==================> ]  71.16M   313KB/s    eta 13s
# physionet.org/files  97%[==================> ]  71.23M   312KB/s    eta 11s
# physionet.org/files  97%[==================> ]  71.31M   312KB/s    eta 11s
# physionet.org/files  97%[==================> ]  71.39M   319KB/s    eta 11s
# physionet.org/files  97%[==================> ]  71.47M   304KB/s    eta 11s
# physionet.org/files  97%[==================> ]  71.58M   314KB/s    eta 9s
# physionet.org/files  97%[==================> ]  71.64M   313KB/s    eta 9s
# physionet.org/files  97%[==================> ]  71.70M   313KB/s    eta 9s
# physionet.org/files  97%[==================> ]  71.78M   314KB/s    eta 9s
# physionet.org/files  98%[==================> ]  71.86M   314KB/s    eta 9s
# physionet.org/files  98%[==================> ]  71.94M   314KB/s    eta 7s
# physionet.org/files  98%[==================> ]  72.01M   313KB/s    eta 7s
# physionet.org/files  98%[==================> ]  72.12M   313KB/s    eta 7s
# physionet.org/files  98%[==================> ]  72.19M   314KB/s    eta 7s
# physionet.org/files  98%[==================> ]  72.25M   314KB/s    eta 5s
# physionet.org/files  98%[==================> ]  72.31M   314KB/s    eta 5s
# physionet.org/files  98%[==================> ]  72.39M   313KB/s    eta 5s
# physionet.org/files  98%[==================> ]  72.44M   307KB/s    eta 5s
# physionet.org/files  98%[==================> ]  72.48M   301KB/s    eta 5s
# physionet.org/files  98%[==================> ]  72.55M   297KB/s    eta 4s
# physionet.org/files  99%[==================> ]  72.61M   292KB/s    eta 4s
# physionet.org/files  99%[==================> ]  72.67M   293KB/s    eta 4s
# physionet.org/files  99%[==================> ]  72.73M   293KB/s    eta 4s
# physionet.org/files  99%[==================> ]  72.80M   290KB/s    eta 4s
# physionet.org/files  99%[==================> ]  72.86M   289KB/s    eta 2s
# physionet.org/files  99%[==================> ]  72.92M   289KB/s    eta 2s
# physionet.org/files  99%[==================> ]  73.00M   291KB/s    eta 2s
# physionet.org/files  99%[==================> ]  73.08M   291KB/s    eta 2s
# physionet.org/files  99%[==================> ]  73.12M   281KB/s    eta 2s
# physionet.org/files  99%[==================> ]  73.22M   293KB/s    eta 0s
# physionet.org/files  99%[==================> ]  73.28M   292KB/s    eta 0s
# physionet.org/files 100%[===================>]  73.30M   293KB/s    in 6m 17s
#
# 2025-11-20 21:27:45 (199 KB/s) - 'physionet.org/files/mimic-cxr/2.1.0/SHA256SUMS.txt' saved [76859934/76859934]
#
# FINISHED --2025-11-20 21:27:45--
# Total wall clock time: 6m 18s
# Downloaded: 1 files, 73M in 6m 17s (199 KB/s)
#
# ✅ Files folder download complete.

# %% [markdown]
# ## 3.2 `Generate filelist for wget`

# %%
# Add project root to sys.path

import sys
from pathlib import Path
import os, sys, subprocess
from getpass import getpass



ROOT = Path.cwd()
for parent in [ROOT] + list(ROOT.parents):
    if (parent / "config").is_dir():
        ROOT = parent
        break
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

print( '[X] Root fount' )

from xrh.settings import write_parameter, read_parameter
# Out:
# [X] Root fount

# %%
from pathlib import Path
from collections import defaultdict
import math
import subprocess
from getpass import getpass
from urllib.parse import urljoin

patient_size = 2000
wget_threads_num = 15
wget_root = "https://physionet.org/files/mimic-cxr/2.1.0"
tmp_dir_name = "tmp.filelist"

location = read_parameter("MIMIC_CXR_src_data_path")

location = Path(location)

# %%
def build_patient_url_table(location, patient_size, wget_root):
    if wget_root is None:
        raise ValueError("wget_root must be provided")

    location = Path(location)
    sha_file = location / "physionet.org" / "files" / "mimic-cxr" / "2.1.0" / "SHA256SUMS.txt"

    if not sha_file.is_file():
        raise FileNotFoundError(f"SHA256SUMS.txt not found at: {sha_file}")

    patient_to_urls = defaultdict(list)

    with sha_file.open("r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue

            # Expected format: "<checksum> <relative_path>"
            try:
                checksum, rel_path = line.split(maxsplit=1)
            except ValueError:
                # Malformed line, skip
                continue

            # Only DICOM files
            if not rel_path.endswith(".dcm"):
                continue

            parts = rel_path.split("/")
            # Expected: ["files", "p10", "p10000032", "s50414267", "xxxxx.dcm"]
            if len(parts) < 5:
                # Unexpected format, skip
                continue

            patient_id = parts[2]  # e.g. "p10000032"

            full_url = f"{wget_root}/{rel_path}"
            patient_to_urls[patient_id].append(full_url)

    # Sort patient IDs and select first N
    all_patients = sorted(patient_to_urls.keys())
    selected_patients = all_patients[:patient_size]

    reduced_table = {pid: patient_to_urls[pid] for pid in selected_patients}
    return reduced_table


def write_wget_filelists(patient_url_table, location, wget_threads_num=50, tmp_dir_name="tmp.filelist"):
    """
    Flatten URLs from the hash table and split into K filelists for wget.

    patient_url_table : dict
        Mapping patient_id -> list of URLs.
    location : Path or str
        Base folder where tmp_dir_name will be created.
    wget_threads_num : int
        Desired number of filelists (upper bound).
    tmp_dir_name : str
        Name of temporary subfolder.
    """
    location = Path(location)
    tmp_dir = location / tmp_dir_name
    tmp_dir.mkdir(parents=True, exist_ok=True)

    # Flatten URLs
    all_urls = []
    for urls in patient_url_table.values():
        all_urls.extend(urls)

    if not all_urls:
        raise ValueError("No URLs found in patient_url_table.")

    # Number of chunks (cannot exceed number of URLs)
    k = min(wget_threads_num, len(all_urls))
    chunk_size = math.ceil(len(all_urls) / k)

    filelist_paths = []
    for i in range(k):
        start = i * chunk_size
        end = start + chunk_size
        chunk = all_urls[start:end]
        if not chunk:
            continue

        fname = tmp_dir / f"filelist_{i:03d}.txt"
        with fname.open("w", encoding="utf-8") as f:
            for url in chunk:
                f.write(url + "\n")

        filelist_paths.append(fname)

    return filelist_paths


# Cell 3: build patient→URLs mapping and create filelists

patient_url_table = build_patient_url_table(
    location=location,
    patient_size=patient_size,
    wget_root=wget_root,
)

print(f"Number of patients in table: {len(patient_url_table)}")

filelists = write_wget_filelists(
    patient_url_table=patient_url_table,
    location=location,
    wget_threads_num=wget_threads_num,
    tmp_dir_name=tmp_dir_name,
)

print("Created wget filelists:")
for p in filelists:
    print("  ", p)
# Out:
# Number of patients in table: 500
# Created wget filelists:
#    D:\003.Data\MIMIC-CXR.v2.1\tmp.filelist\filelist_000.txt
#    D:\003.Data\MIMIC-CXR.v2.1\tmp.filelist\filelist_001.txt
#    D:\003.Data\MIMIC-CXR.v2.1\tmp.filelist\filelist_002.txt
#    D:\003.Data\MIMIC-CXR.v2.1\tmp.filelist\filelist_003.txt
#    D:\003.Data\MIMIC-CXR.v2.1\tmp.filelist\filelist_004.txt
#    D:\003.Data\MIMIC-CXR.v2.1\tmp.filelist\filelist_005.txt
#    D:\003.Data\MIMIC-CXR.v2.1\tmp.filelist\filelist_006.txt
#    D:\003.Data\MIMIC-CXR.v2.1\tmp.filelist\filelist_007.txt
#    D:\003.Data\MIMIC-CXR.v2.1\tmp.filelist\filelist_008.txt
#    D:\003.Data\MIMIC-CXR.v2.1\tmp.filelist\filelist_009.txt
#    D:\003.Data\MIMIC-CXR.v2.1\tmp.filelist\filelist_010.txt
#    D:\003.Data\MIMIC-CXR.v2.1\tmp.filelist\filelist_011.txt
#    D:\003.Data\MIMIC-CXR.v2.1\tmp.filelist\filelist_012.txt
#    D:\003.Data\MIMIC-CXR.v2.1\tmp.filelist\filelist_013.txt
#    D:\003.Data\MIMIC-CXR.v2.1\tmp.filelist\filelist_014.txt

# %%
checkSUM_path = Path(location) / "physionet.org" / "files" / "mimic-cxr" / "2.1.0" / "SHA256SUMS.txt"

root_file_paths = []
patient_dict = {}
pid_list = []

# Note: need to update - the last patient does not downloaded properly

with checkSUM_path.open("r", encoding="utf-8") as f:
    for line in f:
        line = line.strip()
        (checkSum, rel_path) = line.split(" ")
        path_type = rel_path.count('/')

        if path_type == 4:
            (file, GID, PID, SID, img_name) = rel_path.split("/")

            if len(patient_dict) >= patient_size:
                break
            if PID not in patient_dict:
                if len(patient_dict) >= patient_size:
                    break
                patient_dict[PID] = []
            full_url = wget_root + "/" + rel_path
            patient_dict[PID].append(full_url)

        elif path_type == 3:
            (file, GID, PID, txt_name) = rel_path.split("/")

            if PID not in patient_dict:
                if len(patient_dict) >= patient_size:
                    break
                patient_dict[PID] = []
            full_url = wget_root + "/" + rel_path
            patient_dict[PID].append(full_url)
        else:
            full_url = wget_root + "/" + rel_path
            root_file_paths.append(full_url)
        
print(f"Number of patients in table: {len(patient_dict)}")

patien_per_file = math.ceil(len(patient_dict) / wget_threads_num)
filelist_paths = location / tmp_dir_name
filelist_paths.mkdir(parents=True, exist_ok=True)

for i in range(wget_threads_num):
    start = i * patien_per_file
    end = start + patien_per_file
    chunk_PIDs = list(patient_dict.keys())[start:end]
    if not chunk_PIDs:
        continue

    fname = filelist_paths / f"filelist_{i:03d}.txt"
    with fname.open("w", encoding="utf-8") as f:
        for PID in chunk_PIDs:
            for url in patient_dict[PID]:
                f.write(url + "\n")

    #print("  ", fname)

print("[X] Created wget filelists")
# Out:
# Number of patients in table: 500
# [X] Created wget filelists

# %% [markdown]
# ## 3.3 `Download files`

# %%
import subprocess
from pathlib import Path
from concurrent.futures import ThreadPoolExecutor, as_completed

username = input("Enter PhysioNet username: ")
password = getpass("Enter PhysioNet password: ")

# Get all filelist_*.txt files
filelist_list = sorted(filelist_paths.glob("filelist_*.txt"))

# === Function to download one filelist ===
def download_filelist(filelist_path: Path):
    print(f"🚀 Process started: {filelist_path.name}")
    
    cmd = [
    "wget",
    "-r",               # recursive
    "-N",               # only download if newer
    "-c",               # continue downloads
    "-np",              # no parent directories
    "--user", username,
    "--password", password,
    "-i", str(filelist_path),
    "-P", str(location)  # where to save downloads
]
    proc = subprocess.run(cmd, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
    return filelist_path.name, proc


# === Run all in parallel ===
with ThreadPoolExecutor(max_workers=wget_threads_num) as executor:
    futures = [executor.submit(download_filelist, fp) for fp in filelist_list]
    
    for future in as_completed(futures):
        filelist_name, code = future.result()
        status = "✅ OK" if code == 0 else f"❌ Failed)"
        print(f"{filelist_name}: {status}")
# Out:
# 🚀 Process started: filelist_000.txt🚀 Process started: filelist_001.txt
#
# 🚀 Process started: filelist_002.txt
# 🚀 Process started: filelist_003.txt
# 🚀 Process started: filelist_004.txt
# 🚀 Process started: filelist_005.txt
# 🚀 Process started: filelist_006.txt
# 🚀 Process started: filelist_007.txt
# 🚀 Process started: filelist_008.txt
# 🚀 Process started: filelist_009.txt
# 🚀 Process started: filelist_010.txt
# 🚀 Process started: filelist_011.txt
# 🚀 Process started: filelist_012.txt
# 🚀 Process started: filelist_013.txt
# 🚀 Process started: filelist_014.txt
# filelist_014.txt: ❌ Failed)
# filelist_002.txt: ❌ Failed)
# filelist_000.txt: ❌ Failed)
# filelist_008.txt: ❌ Failed)
# filelist_013.txt: ❌ Failed)
# filelist_006.txt: ❌ Failed)
# filelist_004.txt: ❌ Failed)
# filelist_011.txt: ❌ Failed)
# filelist_010.txt: ❌ Failed)
# filelist_003.txt: ❌ Failed)
# filelist_007.txt: ❌ Failed)
# filelist_005.txt: ❌ Failed)
# filelist_009.txt: ❌ Failed)
# filelist_001.txt: ❌ Failed)
# filelist_012.txt: ❌ Failed)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## 3.4 Data Checksum Validation

# %%
import hashlib

data_path = Path(location) / "physionet.org" / "files" / "mimic-cxr" / "2.1.0" / "files"
checkSUM_path = Path(location) / "physionet.org" / "files" / "mimic-cxr" / "2.1.0" / "SHA256SUMS.txt"

root_file_paths = []
patient_dict = {}
pid_list = []
checkSum_dict = {}

patient_ids = []

data_subfolders = [p.name for p in data_path.iterdir() if p.is_dir()]

for gid in data_subfolders:
    gfolder = data_path / gid

pid_list = [p.name for p in gfolder.iterdir() if p.is_dir()]


with checkSUM_path.open("r", encoding="utf-8") as f:
    for line in f:
        line = line.strip()
        (checkSum, rel_path) = line.split(" ")
        path_type = rel_path.count('/')

        if path_type == 4:
            (file, GID, PID, SID, img_name) = rel_path.split("/")
            if PID in pid_list:
                file_path = data_path / GID / PID / SID / img_name
                checkSum_dict[file_path] = checkSum
        
        elif path_type == 3:
            (file, GID, PID, txt_name) = rel_path.split("/")
            if PID in pid_list:
                file_path = data_path / GID / PID / txt_name
                checkSum_dict[file_path] = checkSum
            

def sha256(path: Path, chunk_size=1024 * 1024):
    h = hashlib.sha256()
    with path.open("rb") as f:
        for chunk in iter(lambda: f.read(chunk_size), b""):
            h.update(chunk)
    return h.hexdigest()

missing = []
mismatch = []
ok = []

for file_path, expected_checksum in checkSum_dict.items():
    path = Path(file_path)

    if not path.exists():
        missing.append(file_path)
        continue

    actual_checksum = sha256(path)

    if actual_checksum != expected_checksum:
        mismatch.append(file_path)
    else:
        ok.append(file_path)

print(f"Missing files: {len(missing)}")
print(f"Mismatched files: {len(mismatch)}")
print(f"OK files: {len(ok)}")
# Out:
# Missing files: 0
# Mismatched files: 0
# OK files: 18876

# %%
# Create file list for re-downloading corrupted or missing files

filelist_paths = location / tmp_dir_name

for p in filelist_paths.iterdir():
    path = Path(p)
    if path.is_file():
        path.unlink()

missing_filelist_path = filelist_paths / "missing_files.txt"
with open(missing_filelist_path, "w") as f:
    for missing_file_path in missing:
        fid = missing_file_path.name          # last
        sid = missing_file_path.parts[-2]     # second from end
        pid = missing_file_path.parts[-3]     # third from end
        gid = missing_file_path.parts[-4]     # fourth from end
        if ".dcm" in fid:
            rel_path = 'files/' + gid + '/' + pid + '/' + sid + '/' + fid
        else:
            rel_path = gid + '/' + pid + '/' + sid + '/' + fid

        full_url = wget_root + "/" + rel_path
        f.write(full_url + "\n")

    for mismatch_file_path in mismatch:
        fid = mismatch_file_path.name          # last
        sid = mismatch_file_path.parts[-2]     # second from end
        pid = mismatch_file_path.parts[-3]     # third from end
        gid = mismatch_file_path.parts[-4]     # fourth from end

        if ".dcm" in fid:
            rel_path = 'files/' + gid + '/' + pid + '/' + sid + '/' + fid
        else:
            rel_path = gid + '/' + pid + '/' + sid + '/' + fid

        full_url = wget_root + "/" + rel_path
        f.write(full_url + "\n")

# %%
# download missing/corrupted files
username = input("Enter PhysioNet username: ")
password = getpass("Enter PhysioNet password: ")
location = Path(read_parameter("MIMIC_CXR_src_data_path"))

location.mkdir(parents=True, exist_ok=True)

# Build wget command
wget_cmd = [
    "wget",
    "-r",
    "-N",
    "-c",
    "-np",
    "--user", username,
    "--password", password,
    "-P", str(location),
    "-i", str(missing_filelist_path)
]

# Run the command
try:
    subprocess.run(wget_cmd, check=True)
except subprocess.CalledProcessError as e:
    print(f"\n❌ Download failed with exit code {e.returncode}")
