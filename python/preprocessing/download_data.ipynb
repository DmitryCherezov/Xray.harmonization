# %% [markdown]
# # 1 `MIMIC-IV`

# %% [markdown]
# ## 1.1 `Download Data`

# %%
import os, sys, subprocess
from getpass import getpass

username = input("Enter PhysioNet username: ")
password = getpass("Enter PhysioNet password: ")
location = input("Enter download location (full path): ")

os.makedirs(location, exist_ok=True)
os.chdir(location)

url = "https://physionet.org/files/mimiciv/3.1/"

# Force progress bar output even in Jupyter
cmd = [
    "wget",
    "-r", "-N", "-c", "-np",
    "--show-progress", "--progress=bar:force:noscroll",
    "--user", username,
    "--password", password,
    url,
]

# Stream wget output live so progress is visible
proc = subprocess.Popen(
    cmd,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1,
)

for line in proc.stdout:
    print(line, end="")
    sys.stdout.flush()

proc.wait()
if proc.returncode == 0:
    print("\n✅ Download complete.")
else:
    print(f"\n❌ wget exited with code {proc.returncode}")

# %% [markdown]
# ## 1.2 `Check files`

# %%
import os
import hashlib
from pathlib import Path

# --- Step 1: Define and check the base location ---
# location = Path("E:/Data/MIMIC_IV")  # example path — adjust for your setup
if 'location' not in locals():
    location = Path(input("Enter download location (full path): "))

print(f"\n✅ Checking data in folder: {location}")


# --- Step 2: Define checksum file path ---
checksum_file = location / "SHA256SUMS.txt"
if not checksum_file.exists():
    raise FileNotFoundError(f"Checksum file not found: {checksum_file}")

# --- Step 3: Load checksums ---
checksums = {}
with open(checksum_file, "r", encoding="utf-8") as f:
    for line in f:
        hash_val, rel_path = line.split(" ")
        cur_path = location / rel_path.strip()
        checksums[ cur_path ] = hash_val.strip()

print(f"Found {len(checksums)} entries in {checksum_file.name}")


# --- Step 4: Verify files ---
def sha256sum(file_path):
    """Compute SHA256 hash for a file."""
    h = hashlib.sha256()
    with open(file_path, "rb") as f:
        for chunk in iter(lambda: f.read(8192), b""):
            h.update(chunk)
    return h.hexdigest()

results = []
for rel_path, expected_hash in checksums.items():
    file_path = location / rel_path
    if not file_path.exists():
        results.append((rel_path, "❌ Missing", None))
        continue

    actual_hash = sha256sum(file_path)
    if actual_hash.lower() == expected_hash.lower():
        results.append((rel_path, "✅ OK", actual_hash))
    else:
        results.append((rel_path, "⚠️ Mismatch", actual_hash))

# --- Step 5: Display results ---
print("\n=== Verification Report ===")
for rel_path, status, actual in results:
    print(f"{status:10s}  {rel_path}")

# Optional: summary counts
ok = sum(1 for r in results if "OK" in r[1])
missing = sum(1 for r in results if "Missing" in r[1])
mismatch = sum(1 for r in results if "Mismatch" in r[1])
print(f"\nSummary: {ok} OK, {missing} Missing, {mismatch} Mismatch\n")

# %% [markdown]
# ## 1.3. `UnZip Files`

# %%
import os
import gzip
import shutil
from pathlib import Path

# --- 0) Base folder ---
if 'location' not in locals():
    location = Path(input("Enter download location (full path): ").strip()).expanduser().resolve()

print(f"\n📁 Using folder: {location}")

checksum_file = location / "SHA256SUMS.txt"
if not checksum_file.exists():
    raise FileNotFoundError(f"Checksum file not found: {checksum_file}")

# --- 1) Read relative paths from SHA256SUMS.txt ---
rel_paths = []
with open(checksum_file, "r", encoding="utf-8") as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        # Robust split: first token is hash, the rest is the path (may contain spaces)
        parts = line.split(maxsplit=1)
        if len(parts) != 2:
            continue
        _, rel_path = parts
        rel_paths.append(rel_path.strip())

# --- 2) Filter only .gz files ---
gz_paths = [rp for rp in rel_paths if rp.endswith(".gz")]
print(f"Found {len(gz_paths)} .gz files to process")

# --- 3) Decompress settings ---
OVERWRITE = False  # set to True to overwrite existing outputs
CHUNK_SIZE = 1024 * 1024  # 1 MB chunks

# --- 4) Decompress loop ---
done = 0
skipped = 0
missing = 0
failed = 0
log = []

for rp in gz_paths:
    src = (location / rp).resolve()
    # Destination: remove the final ".gz" only
    dst = src.with_name(src.name[:-3])  # e.g., "file.csv.gz" -> "file.csv"

    if not src.exists():
        missing += 1
        log.append(("❌ Missing", rp))
        continue

    # Ensure destination folder exists
    dst.parent.mkdir(parents=True, exist_ok=True)

    if dst.exists() and not OVERWRITE:
        skipped += 1
        log.append(("⏩ Skipped (exists)", str(dst.relative_to(location))))
        continue

    try:
        with gzip.open(src, "rb") as f_in, open(dst, "wb") as f_out:
            shutil.copyfileobj(f_in, f_out, length=CHUNK_SIZE)
        done += 1
        log.append(("✅ Unzipped", f"{rp}  ->  {dst.relative_to(location)}"))
    except Exception as e:
        failed += 1
        log.append(("⚠️ Failed", f"{rp}  ({e})"))

# --- 5) Report ---
print("\n=== Decompression Report ===")
for status, msg in log:
    print(f"{status:16s} {msg}")

print(
    f"\nSummary: {done} unzipped, {skipped} skipped, {missing} missing, {failed} failed.\n"
    f"Outputs are written next to sources (e.g., *.csv beside *.csv.gz)."
)

# %% [markdown]
# # 2 `MIMIC-CXR`

# %% [markdown]
# ## 2.1 `Download Data`

# %%
import os, sys, subprocess
from getpass import getpass

username = input("Enter PhysioNet username: ")
password = getpass("Enter PhysioNet password: ")
location = input("Enter download location (full path): ")

os.makedirs(location, exist_ok=True)
os.chdir(location)

"""
#url = "https://physionet.org/files/mimic-cxr/2.1.0/files/p10/"
url = "https://physionet.org/files/mimic-cxr/2.1.0/"

# Download data parent folder excluding pXX subfolders
# Force progress bar output even in Jupyter
cmd = [
    "wget",
    "-r", "-N", "-c", "-np",
    "--show-progress", "--progress=bar:force:noscroll",
    "--reject-regex", ".*/files/p[0-9]+",
    "--user", username,
    "--password", password,
    url,
]

# Stream wget output live so progress is visible
proc = subprocess.Popen(
    cmd,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1,
)

for line in proc.stdout:
    print(line, end="")
    sys.stdout.flush()

proc.wait()
if proc.returncode == 0:
    print("\n✅ Root Folder download complete.")
else:
    print(f"\n❌ wget exited with code {proc.returncode}")

"""

url = "https://physionet.org/files/mimic-cxr/2.1.0/"
cmd = [
    "wget",
    "-r", "-N", "-c", "-np",
    "--show-progress", "--progress=bar:force:noscroll",
#    "--accept-regex", "(/files/|/files/p10/|/files/p10/p1000.*)",
    "--user", username,
    "--password", password,
    url,
]

# Stream wget output live so progress is visible
proc = subprocess.Popen(
    cmd,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1,
)

for line in proc.stdout:
    print(line, end="")
    sys.stdout.flush()

proc.wait()
if proc.returncode == 0:
    print("\n✅ Files folder download complete.")
else:
    print(f"\n❌ wget exited with code {proc.returncode}")
# Out:
# --2025-11-10 12:30:14--  https://physionet.org/files/mimic-cxr/2.1.0/
# Resolving physionet.org (physionet.org)... 18.18.42.54
# Connecting to physionet.org (physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="PhysioNet", charset="UTF-8"
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'physionet.org/files/mimic-cxr/2.1.0/index.html'
#
#
# physionet.org/files     [<=>                 ]       0  --.-KB/s
# physionet.org/files     [ <=>                ]   1.05K  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-11-10 12:30:15 (198 MB/s) - 'physionet.org/files/mimic-cxr/2.1.0/index.html' saved [1079]
#
# Loading robots.txt; please ignore errors.
# --2025-11-10 12:30:15--  https://physionet.org/robots.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 22 [text/plain]
# Saving to: 'physionet.org/robots.txt'
#
#
# physionet.org/robot   0%[                    ]       0  --.-KB/s
# physionet.org/robot 100%[===================>]      22  --.-KB/s    in 0s
#
# 2025-11-10 12:30:15 (15.0 MB/s) - 'physionet.org/robots.txt' saved [22/22]
#
# --2025-11-10 12:30:15--  https://physionet.org/files/mimic-cxr/2.1.0/files/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'physionet.org/files/mimic-cxr/2.1.0/files/index.html'
#
#
# physionet.org/files     [<=>                 ]       0  --.-KB/s
# physionet.org/files     [ <=>                ]   1.30K  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-11-10 12:30:15 (383 MB/s) - 'physionet.org/files/mimic-cxr/2.1.0/files/index.html' saved [1327]
#
# --2025-11-10 12:30:15--  https://physionet.org/files/mimic-cxr/2.1.0/LICENSE.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2518 (2.5K) [text/plain]
# Saving to: 'physionet.org/files/mimic-cxr/2.1.0/LICENSE.txt'
#
#
# physionet.org/files   0%[                    ]       0  --.-KB/s
# physionet.org/files 100%[===================>]   2.46K  --.-KB/s    in 0s
#
# 2025-11-10 12:30:15 (1.68 GB/s) - 'physionet.org/files/mimic-cxr/2.1.0/LICENSE.txt' saved [2518/2518]
#
# --2025-11-10 12:30:15--  https://physionet.org/files/mimic-cxr/2.1.0/SHA256SUMS.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 76859934 (73M) [text/plain]
# Saving to: 'physionet.org/files/mimic-cxr/2.1.0/SHA256SUMS.txt'
#
#
# physionet.org/files   0%[                    ]       0  --.-KB/s
# physionet.org/files   0%[                    ] 111.64K   481KB/s
# physionet.org/files   0%[                    ] 159.64K   322KB/s
# physionet.org/files   0%[                    ] 335.64K   482KB/s
# physionet.org/files   0%[                    ] 415.64K   423KB/s
# physionet.org/files   0%[                    ] 575.64K   480KB/s
# physionet.org/files   1%[                    ] 751.64K   523KB/s
# physionet.org/files   1%[                    ] 847.64K   503KB/s
# physionet.org/files   1%[                    ] 927.64K   490KB/s
# physionet.org/files   1%[                    ]   1008K   479KB/s
# physionet.org/files   1%[                    ]   1.08M   473KB/s
# physionet.org/files   1%[                    ]   1.16M   467KB/s
# physionet.org/files   1%[                    ]   1.23M   449KB/s
# physionet.org/files   1%[                    ]   1.34M   453KB/s    eta 2m 43s
# physionet.org/files   1%[                    ]   1.42M   444KB/s    eta 2m 43s
# physionet.org/files   2%[                    ]   1.50M   440KB/s    eta 2m 43s
# physionet.org/files   2%[                    ]   1.58M   436KB/s    eta 2m 43s
# physionet.org/files   2%[                    ]   1.67M   420KB/s    eta 2m 53s
# physionet.org/files   2%[                    ]   1.78M   440KB/s    eta 2m 53s
# physionet.org/files   2%[                    ]   1.84M   411KB/s    eta 2m 53s
# physionet.org/files   2%[                    ]   1.91M   415KB/s    eta 2m 53s
# physionet.org/files   2%[                    ]   1.97M   381KB/s    eta 2m 53s
# physionet.org/files   2%[                    ]   2.05M   372KB/s    eta 2m 58s
# physionet.org/files   2%[                    ]   2.11M   359KB/s    eta 2m 58s
# physionet.org/files   2%[                    ]   2.19M   358KB/s    eta 2m 58s
# physionet.org/files   3%[                    ]   2.26M   355KB/s    eta 2m 58s
# physionet.org/files   3%[                    ]   2.34M   353KB/s    eta 2m 58s
# physionet.org/files   3%[                    ]   2.42M   354KB/s    eta 3m 2s
# physionet.org/files   3%[                    ]   2.50M   361KB/s    eta 3m 2s
# physionet.org/files   3%[                    ]   2.59M   355KB/s    eta 3m 2s
# physionet.org/files   3%[                    ]   2.62M   344KB/s    eta 3m 2s
# physionet.org/files   3%[                    ]   2.73M   353KB/s    eta 3m 2s
# physionet.org/files   3%[                    ]   2.80M   348KB/s    eta 3m 4s
# physionet.org/files   3%[                    ]   2.87M   355KB/s    eta 3m 4s
# physionet.org/files   4%[                    ]   2.95M   347KB/s    eta 3m 4s
# physionet.org/files   4%[                    ]   3.03M   350KB/s    eta 3m 4s
# physionet.org/files   4%[                    ]   3.12M   358KB/s    eta 3m 4s
# physionet.org/files   4%[                    ]   3.20M   361KB/s    eta 3m 4s
# physionet.org/files   4%[                    ]   3.30M   366KB/s    eta 3m 4s
# physionet.org/files   4%[                    ]   3.37M   361KB/s    eta 3m 4s
# physionet.org/files   4%[                    ]   3.48M   368KB/s    eta 3m 4s
# physionet.org/files   4%[                    ]   3.53M   357KB/s    eta 3m 6s
# physionet.org/files   4%[                    ]   3.62M   358KB/s    eta 3m 6s
# physionet.org/files   5%[>                   ]   3.69M   344KB/s    eta 3m 6s
# physionet.org/files   5%[>                   ]   3.75M   329KB/s    eta 3m 6s
# physionet.org/files   5%[>                   ]   3.81M   322KB/s    eta 3m 11s
# physionet.org/files   5%[>                   ]   3.86M   318KB/s    eta 3m 11s
# physionet.org/files   5%[>                   ]   3.91M   311KB/s    eta 3m 11s
# physionet.org/files   5%[>                   ]   3.95M   305KB/s    eta 3m 11s
# physionet.org/files   5%[>                   ]   4.01M   297KB/s    eta 3m 11s
# physionet.org/files   5%[>                   ]   4.05M   285KB/s    eta 3m 19s
# physionet.org/files   5%[>                   ]   4.09M   277KB/s    eta 3m 19s
# physionet.org/files   5%[>                   ]   4.14M   268KB/s    eta 3m 19s
# physionet.org/files   5%[>                   ]   4.19M   259KB/s    eta 3m 19s
# physionet.org/files   5%[>                   ]   4.23M   243KB/s    eta 3m 19s
# physionet.org/files   5%[>                   ]   4.30M   245KB/s    eta 3m 25s
# physionet.org/files   5%[>                   ]   4.34M   234KB/s    eta 3m 25s
# physionet.org/files   5%[>                   ]   4.39M   226KB/s    eta 3m 25s
# physionet.org/files   6%[>                   ]   4.45M   222KB/s    eta 3m 25s
# physionet.org/files   6%[>                   ]   4.50M   218KB/s    eta 3m 30s
# physionet.org/files   6%[>                   ]   4.55M   218KB/s    eta 3m 30s
# physionet.org/files   6%[>                   ]   4.59M   216KB/s    eta 3m 30s
# physionet.org/files   6%[>                   ]   4.64M   217KB/s    eta 3m 30s
# physionet.org/files   6%[>                   ]   4.70M   220KB/s    eta 3m 30s
# physionet.org/files   6%[>                   ]   4.76M   224KB/s    eta 3m 33s
# physionet.org/files   6%[>                   ]   4.81M   225KB/s    eta 3m 33s
# physionet.org/files   6%[>                   ]   4.87M   228KB/s    eta 3m 33s
# physionet.org/files   6%[>                   ]   4.91M   227KB/s    eta 3m 33s
# physionet.org/files   6%[>                   ]   4.98M   233KB/s    eta 3m 33s
# physionet.org/files   6%[>                   ]   5.03M   233KB/s    eta 3m 37s
# physionet.org/files   6%[>                   ]   5.09M   236KB/s    eta 3m 37s
# physionet.org/files   7%[>                   ]   5.16M   237KB/s    eta 3m 37s
# physionet.org/files   7%[>                   ]   5.22M   240KB/s    eta 3m 37s
# physionet.org/files   7%[>                   ]   5.28M   249KB/s    eta 3m 37s
# physionet.org/files   7%[>                   ]   5.34M   250KB/s    eta 3m 38s
# physionet.org/files   7%[>                   ]   5.37M   247KB/s    eta 3m 38s
# physionet.org/files   7%[>                   ]   5.45M   253KB/s    eta 3m 38s
# physionet.org/files   7%[>                   ]   5.51M   252KB/s    eta 3m 38s
# physionet.org/files   7%[>                   ]   5.58M   255KB/s    eta 3m 40s
# physionet.org/files   7%[>                   ]   5.64M   254KB/s    eta 3m 40s
# physionet.org/files   7%[>                   ]   5.70M   257KB/s    eta 3m 40s
# physionet.org/files   7%[>                   ]   5.76M   257KB/s    eta 3m 40s
# physionet.org/files   7%[>                   ]   5.83M   257KB/s    eta 3m 40s
# physionet.org/files   8%[>                   ]   5.89M   262KB/s    eta 3m 41s
# physionet.org/files   8%[>                   ]   5.95M   260KB/s    eta 3m 41s
# physionet.org/files   8%[>                   ]   6.03M   264KB/s    eta 3m 41s
# physionet.org/files   8%[>                   ]   6.09M   264KB/s    eta 3m 41s
# physionet.org/files   8%[>                   ]   6.16M   261KB/s    eta 3m 42s
# physionet.org/files   8%[>                   ]   6.22M   262KB/s    eta 3m 42s
# physionet.org/files   8%[>                   ]   6.25M   254KB/s    eta 3m 42s
# physionet.org/files   8%[>                   ]   6.33M   257KB/s    eta 3m 42s
# physionet.org/files   8%[>                   ]   6.37M   261KB/s    eta 3m 42s
# physionet.org/files   8%[>                   ]   6.44M   257KB/s    eta 3m 44s
# physionet.org/files   8%[>                   ]   6.50M   259KB/s    eta 3m 44s
# physionet.org/files   8%[>                   ]   6.56M   258KB/s    eta 3m 44s
# physionet.org/files   9%[>                   ]   6.62M   260KB/s    eta 3m 44s
# physionet.org/files   9%[>                   ]   6.69M   259KB/s    eta 3m 44s
# physionet.org/files   9%[>                   ]   6.75M   259KB/s    eta 3m 44s
# physionet.org/files   9%[>                   ]   6.81M   262KB/s    eta 3m 44s
# physionet.org/files   9%[>                   ]   6.87M   262KB/s    eta 3m 44s
# physionet.org/files   9%[>                   ]   6.95M   264KB/s    eta 3m 44s
# physionet.org/files   9%[>                   ]   7.03M   263KB/s    eta 3m 43s
# physionet.org/files   9%[>                   ]   7.09M   268KB/s    eta 3m 43s
# physionet.org/files   9%[>                   ]   7.16M   266KB/s    eta 3m 43s
# physionet.org/files   9%[>                   ]   7.22M   267KB/s    eta 3m 43s
# physionet.org/files   9%[>                   ]   7.26M   264KB/s    eta 3m 43s
# physionet.org/files   9%[>                   ]   7.31M   267KB/s    eta 3m 45s
# physionet.org/files  10%[=>                  ]   7.36M   260KB/s    eta 3m 45s
# physionet.org/files  10%[=>                  ]   7.41M   262KB/s    eta 3m 45s
# physionet.org/files  10%[=>                  ]   7.47M   263KB/s    eta 3m 45s
# physionet.org/files  10%[=>                  ]   7.53M   263KB/s    eta 3m 45s
# physionet.org/files  10%[=>                  ]   7.58M   264KB/s    eta 3m 46s
# physionet.org/files  10%[=>                  ]   7.64M   265KB/s    eta 3m 46s
# physionet.org/files  10%[=>                  ]   7.67M   255KB/s    eta 3m 46s
# physionet.org/files  10%[=>                  ]   7.73M   256KB/s    eta 3m 46s
# physionet.org/files  10%[=>                  ]   7.80M   254KB/s    eta 3m 46s
# physionet.org/files  10%[=>                  ]   7.86M   254KB/s    eta 3m 46s
# physionet.org/files  10%[=>                  ]   7.91M   249KB/s    eta 3m 46s
# physionet.org/files  10%[=>                  ]   7.97M   244KB/s    eta 3m 46s
# physionet.org/files  10%[=>                  ]   8.03M   246KB/s    eta 3m 46s
# physionet.org/files  11%[=>                  ]   8.08M   243KB/s    eta 3m 46s
# physionet.org/files  11%[=>                  ]   8.12M   247KB/s    eta 3m 47s
# physionet.org/files  11%[=>                  ]   8.19M   242KB/s    eta 3m 47s
# physionet.org/files  11%[=>                  ]   8.23M   242KB/s    eta 3m 47s
# physionet.org/files  11%[=>                  ]   8.30M   246KB/s    eta 3m 47s
# physionet.org/files  11%[=>                  ]   8.36M   247KB/s    eta 3m 47s
# physionet.org/files  11%[=>                  ]   8.42M   251KB/s    eta 3m 47s
# physionet.org/files  11%[=>                  ]   8.48M   251KB/s    eta 3m 47s
# physionet.org/files  11%[=>                  ]   8.56M   255KB/s    eta 3m 47s
# physionet.org/files  11%[=>                  ]   8.64M   259KB/s    eta 3m 47s
# physionet.org/files  11%[=>                  ]   8.70M   267KB/s    eta 3m 47s
# physionet.org/files  11%[=>                  ]   8.78M   271KB/s    eta 3m 45s
# physionet.org/files  12%[=>                  ]   8.86M   279KB/s    eta 3m 45s
# physionet.org/files  12%[=>                  ]   8.95M   288KB/s    eta 3m 45s
# physionet.org/files  12%[=>                  ]   9.03M   292KB/s    eta 3m 45s
# physionet.org/files  12%[=>                  ]   9.12M   309KB/s    eta 3m 45s
# physionet.org/files  12%[=>                  ]   9.22M   321KB/s    eta 3m 41s
# physionet.org/files  12%[=>                  ]   9.31M   334KB/s    eta 3m 41s
# physionet.org/files  12%[=>                  ]   9.41M   350KB/s    eta 3m 41s
# physionet.org/files  12%[=>                  ]   9.50M   363KB/s    eta 3m 41s
# physionet.org/files  13%[=>                  ]   9.61M   374KB/s    eta 3m 41s
# physionet.org/files  13%[=>                  ]   9.72M   390KB/s    eta 3m 35s
# physionet.org/files  13%[=>                  ]   9.83M   407KB/s    eta 3m 35s
# physionet.org/files  13%[=>                  ]   9.94M   417KB/s    eta 3m 35s
# physionet.org/files  13%[=>                  ]  10.05M   429KB/s    eta 3m 35s
# physionet.org/files  13%[=>                  ]  10.17M   445KB/s    eta 3m 35s
# physionet.org/files  14%[=>                  ]  10.30M   466KB/s    eta 3m 28s
# physionet.org/files  14%[=>                  ]  10.44M   481KB/s    eta 3m 28s
# physionet.org/files  14%[=>                  ]  10.59M   505KB/s    eta 3m 28s
# physionet.org/files  14%[=>                  ]  10.76M   533KB/s    eta 3m 28s
# physionet.org/files  14%[=>                  ]  10.94M   552KB/s    eta 3m 28s
# physionet.org/files  15%[==>                 ]  11.03M   557KB/s    eta 3m 18s
# physionet.org/files  15%[==>                 ]  11.23M   586KB/s    eta 3m 18s
# physionet.org/files  15%[==>                 ]  11.37M   608KB/s    eta 3m 18s
# physionet.org/files  15%[==>                 ]  11.51M   623KB/s    eta 3m 18s
# physionet.org/files  15%[==>                 ]  11.66M   631KB/s    eta 3m 18s
# physionet.org/files  16%[==>                 ]  11.75M   632KB/s    eta 3m 9s
# physionet.org/files  16%[==>                 ]  11.83M   611KB/s    eta 3m 9s
# physionet.org/files  16%[==>                 ]  11.94M   604KB/s    eta 3m 9s
# physionet.org/files  16%[==>                 ]  12.00M   591KB/s    eta 3m 9s
# physionet.org/files  16%[==>                 ]  12.06M   576KB/s    eta 3m 8s
# physionet.org/files  16%[==>                 ]  12.14M   562KB/s    eta 3m 8s
# physionet.org/files  16%[==>                 ]  12.20M   544KB/s    eta 3m 8s
# physionet.org/files  16%[==>                 ]  12.28M   519KB/s    eta 3m 8s
# physionet.org/files  16%[==>                 ]  12.34M   503KB/s    eta 3m 8s
# physionet.org/files  16%[==>                 ]  12.42M   476KB/s    eta 3m 7s
# physionet.org/files  17%[==>                 ]  12.50M   458KB/s    eta 3m 7s
# physionet.org/files  17%[==>                 ]  12.58M   417KB/s    eta 3m 7s
# physionet.org/files  17%[==>                 ]  12.67M   407KB/s    eta 3m 7s
# physionet.org/files  17%[==>                 ]  12.75M   377KB/s    eta 3m 7s
# physionet.org/files  17%[==>                 ]  12.81M   372KB/s    eta 3m 5s
# physionet.org/files  17%[==>                 ]  12.91M   360KB/s    eta 3m 5s
# physionet.org/files  17%[==>                 ]  12.97M   341KB/s    eta 3m 5s
# physionet.org/files  17%[==>                 ]  13.05M   340KB/s    eta 3m 5s
# physionet.org/files  17%[==>                 ]  13.12M   346KB/s    eta 3m 5s
# physionet.org/files  18%[==>                 ]  13.20M   350KB/s    eta 3m 4s
# physionet.org/files  18%[==>                 ]  13.28M   356KB/s    eta 3m 4s
# physionet.org/files  18%[==>                 ]  13.37M   362KB/s    eta 3m 4s
# physionet.org/files  18%[==>                 ]  13.47M   369KB/s    eta 3m 4s
# physionet.org/files  18%[==>                 ]  13.56M   372KB/s    eta 3m 4s
# physionet.org/files  18%[==>                 ]  13.66M   377KB/s    eta 3m 1s
# physionet.org/files  18%[==>                 ]  13.73M   380KB/s    eta 3m 1s
# physionet.org/files  18%[==>                 ]  13.83M   384KB/s    eta 3m 1s
# physionet.org/files  18%[==>                 ]  13.92M   389KB/s    eta 3m 1s
# physionet.org/files  19%[==>                 ]  14.01M   390KB/s    eta 3m 1s
# physionet.org/files  19%[==>                 ]  14.11M   393KB/s    eta 2m 59s
# physionet.org/files  19%[==>                 ]  14.20M   406KB/s    eta 2m 59s
# physionet.org/files  19%[==>                 ]  14.31M   408KB/s    eta 2m 59s
# physionet.org/files  19%[==>                 ]  14.42M   416KB/s    eta 2m 59s
# physionet.org/files  19%[==>                 ]  14.53M   428KB/s    eta 2m 59s
# physionet.org/files  19%[==>                 ]  14.64M   435KB/s    eta 2m 55s
# physionet.org/files  20%[===>                ]  14.76M   445KB/s    eta 2m 55s
# physionet.org/files  20%[===>                ]  14.87M   456KB/s    eta 2m 55s
# physionet.org/files  20%[===>                ]  15.00M   453KB/s    eta 2m 55s
# physionet.org/files  20%[===>                ]  15.16M   473KB/s    eta 2m 51s
# physionet.org/files  20%[===>                ]  15.25M   473KB/s    eta 2m 51s
# physionet.org/files  20%[===>                ]  15.34M   475KB/s    eta 2m 51s
# physionet.org/files  21%[===>                ]  15.45M   482KB/s    eta 2m 51s
# physionet.org/files  21%[===>                ]  15.56M   489KB/s    eta 2m 51s
# physionet.org/files  21%[===>                ]  15.67M   493KB/s    eta 2m 48s
# physionet.org/files  21%[===>                ]  15.80M   499KB/s    eta 2m 48s
# physionet.org/files  21%[===>                ]  15.92M   506KB/s    eta 2m 48s
# physionet.org/files  21%[===>                ]  16.05M   514KB/s    eta 2m 48s
# physionet.org/files  22%[===>                ]  16.17M   518KB/s    eta 2m 48s
# physionet.org/files  22%[===>                ]  16.28M   523KB/s    eta 2m 44s
# physionet.org/files  22%[===>                ]  16.41M   526KB/s    eta 2m 44s
# physionet.org/files  22%[===>                ]  16.53M   531KB/s    eta 2m 44s
# physionet.org/files  22%[===>                ]  16.64M   516KB/s    eta 2m 44s
# physionet.org/files  22%[===>                ]  16.80M   522KB/s    eta 2m 41s
# physionet.org/files  23%[===>                ]  16.89M   531KB/s    eta 2m 41s
# physionet.org/files  23%[===>                ]  17.00M   518KB/s    eta 2m 41s
# physionet.org/files  23%[===>                ]  17.09M   517KB/s    eta 2m 41s
# physionet.org/files  23%[===>                ]  17.20M   524KB/s    eta 2m 41s
# physionet.org/files  23%[===>                ]  17.33M   526KB/s    eta 2m 38s
# physionet.org/files  23%[===>                ]  17.44M   524KB/s    eta 2m 38s
# physionet.org/files  23%[===>                ]  17.51M   513KB/s    eta 2m 38s
# physionet.org/files  24%[===>                ]  17.61M   502KB/s    eta 2m 38s
# physionet.org/files  24%[===>                ]  17.70M   498KB/s    eta 2m 38s
# physionet.org/files  24%[===>                ]  17.80M   491KB/s    eta 2m 36s
# physionet.org/files  24%[===>                ]  17.89M   480KB/s    eta 2m 36s
# physionet.org/files  24%[===>                ]  17.98M   467KB/s    eta 2m 36s
# physionet.org/files  24%[===>                ]  18.09M   457KB/s    eta 2m 36s
# physionet.org/files  24%[===>                ]  18.19M   456KB/s    eta 2m 36s
# physionet.org/files  24%[===>                ]  18.30M   447KB/s    eta 2m 34s
# physionet.org/files  25%[====>               ]  18.41M   444KB/s    eta 2m 34s
# physionet.org/files  25%[====>               ]  18.48M   441KB/s    eta 2m 34s
# physionet.org/files  25%[====>               ]  18.59M   441KB/s    eta 2m 34s
# physionet.org/files  25%[====>               ]  18.70M   437KB/s    eta 2m 34s
# physionet.org/files  25%[====>               ]  18.83M   442KB/s    eta 2m 32s
# physionet.org/files  25%[====>               ]  18.92M   439KB/s    eta 2m 32s
# physionet.org/files  25%[====>               ]  19.05M   437KB/s    eta 2m 32s
# physionet.org/files  26%[====>               ]  19.16M   451KB/s    eta 2m 32s
# physionet.org/files  26%[====>               ]  19.25M   436KB/s    eta 2m 32s
# physionet.org/files  26%[====>               ]  19.34M   433KB/s    eta 2m 30s
# physionet.org/files  26%[====>               ]  19.47M   434KB/s    eta 2m 30s
# physionet.org/files  26%[====>               ]  19.55M   427KB/s    eta 2m 30s
# physionet.org/files  26%[====>               ]  19.66M   434KB/s    eta 2m 30s
# physionet.org/files  26%[====>               ]  19.78M   448KB/s    eta 2m 30s
# physionet.org/files  27%[====>               ]  19.91M   450KB/s    eta 2m 28s
# physionet.org/files  27%[====>               ]  20.03M   458KB/s    eta 2m 28s
# physionet.org/files  27%[====>               ]  20.16M   462KB/s    eta 2m 28s
# physionet.org/files  27%[====>               ]  20.28M   471KB/s    eta 2m 28s
# physionet.org/files  27%[====>               ]  20.39M   486KB/s    eta 2m 28s
# physionet.org/files  28%[====>               ]  20.53M   493KB/s    eta 2m 24s
# physionet.org/files  28%[====>               ]  20.66M   498KB/s    eta 2m 24s
# physionet.org/files  28%[====>               ]  20.78M   516KB/s    eta 2m 24s
# physionet.org/files  28%[====>               ]  20.91M   512KB/s    eta 2m 24s
# physionet.org/files  28%[====>               ]  21.03M   525KB/s    eta 2m 24s
# physionet.org/files  28%[====>               ]  21.16M   542KB/s    eta 2m 21s
# physionet.org/files  29%[====>               ]  21.26M   554KB/s    eta 2m 21s
# physionet.org/files  29%[====>               ]  21.41M   569KB/s    eta 2m 21s
# physionet.org/files  29%[====>               ]  21.55M   583KB/s    eta 2m 21s
# physionet.org/files  29%[====>               ]  21.62M   557KB/s    eta 2m 21s
# physionet.org/files  29%[====>               ]  21.72M   556KB/s    eta 2m 19s
# physionet.org/files  29%[====>               ]  21.83M   552KB/s    eta 2m 19s
# physionet.org/files  29%[====>               ]  21.91M   539KB/s    eta 2m 19s
# physionet.org/files  29%[====>               ]  21.98M   530KB/s    eta 2m 19s
# physionet.org/files  30%[=====>              ]  22.08M   520KB/s    eta 2m 19s
# physionet.org/files  30%[=====>              ]  22.16M   513KB/s    eta 2m 17s
# physionet.org/files  30%[=====>              ]  22.25M   500KB/s    eta 2m 17s
# physionet.org/files  30%[=====>              ]  22.34M   487KB/s    eta 2m 17s
# physionet.org/files  30%[=====>              ]  22.42M   480KB/s    eta 2m 17s
# physionet.org/files  30%[=====>              ]  22.48M   456KB/s    eta 2m 17s
# physionet.org/files  30%[=====>              ]  22.53M   440KB/s    eta 2m 16s
# physionet.org/files  30%[=====>              ]  22.59M   412KB/s    eta 2m 16s
# physionet.org/files  30%[=====>              ]  22.66M   392KB/s    eta 2m 16s
# physionet.org/files  30%[=====>              ]  22.70M   376KB/s    eta 2m 16s
# physionet.org/files  31%[=====>              ]  22.75M   340KB/s    eta 2m 16s
# physionet.org/files  31%[=====>              ]  22.81M   319KB/s    eta 2m 17s
# physionet.org/files  31%[=====>              ]  22.86M   325KB/s    eta 2m 17s
# physionet.org/files  31%[=====>              ]  22.91M   309KB/s    eta 2m 17s
# physionet.org/files  31%[=====>              ]  22.94M   289KB/s    eta 2m 17s
# physionet.org/files  31%[=====>              ]  22.98M   274KB/s    eta 2m 17s
# physionet.org/files  31%[=====>              ]  23.01M   258KB/s    eta 2m 18s
# physionet.org/files  31%[=====>              ]  23.06M   253KB/s    eta 2m 18s
# physionet.org/files  31%[=====>              ]  23.09M   239KB/s    eta 2m 18s
# physionet.org/files  31%[=====>              ]  23.14M   232KB/s    eta 2m 18s
# physionet.org/files  31%[=====>              ]  23.19M   223KB/s    eta 2m 18s
# physionet.org/files  31%[=====>              ]  23.25M   216KB/s    eta 2m 18s
# physionet.org/files  31%[=====>              ]  23.30M   220KB/s    eta 2m 18s
# physionet.org/files  31%[=====>              ]  23.36M   218KB/s    eta 2m 18s
# physionet.org/files  31%[=====>              ]  23.42M   221KB/s    eta 2m 18s
# physionet.org/files  32%[=====>              ]  23.48M   222KB/s    eta 2m 18s
# physionet.org/files  32%[=====>              ]  23.55M   223KB/s    eta 2m 18s
# physionet.org/files  32%[=====>              ]  23.62M   236KB/s    eta 2m 18s
# physionet.org/files  32%[=====>              ]  23.67M   231KB/s    eta 2m 18s
# physionet.org/files  32%[=====>              ]  23.76M   244KB/s    eta 2m 18s
# physionet.org/files  32%[=====>              ]  23.83M   249KB/s    eta 2m 18s
# physionet.org/files  32%[=====>              ]  23.89M   255KB/s    eta 2m 17s
# physionet.org/files  32%[=====>              ]  23.95M   263KB/s    eta 2m 17s
# physionet.org/files  32%[=====>              ]  24.00M   263KB/s    eta 2m 17s
# physionet.org/files  32%[=====>              ]  24.06M   268KB/s    eta 2m 17s
# physionet.org/files  32%[=====>              ]  24.11M   268KB/s    eta 2m 17s
# physionet.org/files  32%[=====>              ]  24.17M   268KB/s    eta 2m 17s
# physionet.org/files  33%[=====>              ]  24.22M   268KB/s    eta 2m 17s
# physionet.org/files  33%[=====>              ]  24.28M   268KB/s    eta 2m 17s
# physionet.org/files  33%[=====>              ]  24.33M   265KB/s    eta 2m 17s
# physionet.org/files  33%[=====>              ]  24.37M   260KB/s    eta 2m 17s
# physionet.org/files  33%[=====>              ]  24.42M   256KB/s    eta 2m 17s
# physionet.org/files  33%[=====>              ]  24.48M   254KB/s    eta 2m 17s
# physionet.org/files  33%[=====>              ]  24.53M   252KB/s    eta 2m 17s
# physionet.org/files  33%[=====>              ]  24.59M   246KB/s    eta 2m 17s
# physionet.org/files  33%[=====>              ]  24.66M   251KB/s    eta 2m 17s
# physionet.org/files  33%[=====>              ]  24.72M   244KB/s    eta 2m 17s
# physionet.org/files  33%[=====>              ]  24.78M   244KB/s    eta 2m 17s
# physionet.org/files  33%[=====>              ]  24.84M   244KB/s    eta 2m 17s
# physionet.org/files  33%[=====>              ]  24.92M   247KB/s    eta 2m 17s
# physionet.org/files  34%[=====>              ]  25.00M   255KB/s    eta 2m 17s
# physionet.org/files  34%[=====>              ]  25.06M   259KB/s    eta 2m 17s
# physionet.org/files  34%[=====>              ]  25.14M   267KB/s    eta 2m 17s
# physionet.org/files  34%[=====>              ]  25.22M   275KB/s    eta 2m 17s
# physionet.org/files  34%[=====>              ]  25.30M   279KB/s    eta 2m 17s
# physionet.org/files  34%[=====>              ]  25.39M   299KB/s    eta 2m 17s
# physionet.org/files  34%[=====>              ]  25.47M   308KB/s    eta 2m 16s
# physionet.org/files  34%[=====>              ]  25.53M   307KB/s    eta 2m 16s
# physionet.org/files  35%[======>             ]  25.66M   326KB/s    eta 2m 16s
# physionet.org/files  35%[======>             ]  25.72M   326KB/s    eta 2m 16s
# physionet.org/files  35%[======>             ]  25.78M   323KB/s    eta 2m 15s
# physionet.org/files  35%[======>             ]  25.89M   335KB/s    eta 2m 15s
# physionet.org/files  35%[======>             ]  25.94M   332KB/s    eta 2m 15s
# physionet.org/files  35%[======>             ]  26.00M   334KB/s    eta 2m 15s
# physionet.org/files  35%[======>             ]  26.06M   334KB/s    eta 2m 15s
# physionet.org/files  35%[======>             ]  26.12M   333KB/s    eta 2m 14s
# physionet.org/files  35%[======>             ]  26.20M   334KB/s    eta 2m 14s
# physionet.org/files  35%[======>             ]  26.26M   331KB/s    eta 2m 14s
# physionet.org/files  35%[======>             ]  26.33M   329KB/s    eta 2m 14s
# physionet.org/files  35%[======>             ]  26.37M   321KB/s    eta 2m 14s
# physionet.org/files  36%[======>             ]  26.41M   308KB/s    eta 2m 14s
# physionet.org/files  36%[======>             ]  26.45M   299KB/s    eta 2m 14s
# physionet.org/files  36%[======>             ]  26.50M   289KB/s    eta 2m 14s
# physionet.org/files  36%[======>             ]  26.55M   274KB/s    eta 2m 14s
# physionet.org/files  36%[======>             ]  26.59M   278KB/s    eta 2m 14s
# physionet.org/files  36%[======>             ]  26.64M   250KB/s    eta 2m 14s
# physionet.org/files  36%[======>             ]  26.70M   248KB/s    eta 2m 14s
# physionet.org/files  36%[======>             ]  26.75M   251KB/s    eta 2m 14s
# physionet.org/files  36%[======>             ]  26.80M   236KB/s    eta 2m 14s
# physionet.org/files  36%[======>             ]  26.84M   236KB/s    eta 2m 14s
# physionet.org/files  36%[======>             ]  26.89M   233KB/s    eta 2m 14s
# physionet.org/files  36%[======>             ]  26.94M   229KB/s    eta 2m 14s
# physionet.org/files  36%[======>             ]  26.98M   225KB/s    eta 2m 14s
# physionet.org/files  36%[======>             ]  27.05M   223KB/s    eta 2m 14s
# physionet.org/files  36%[======>             ]  27.09M   220KB/s    eta 2m 14s
# physionet.org/files  37%[======>             ]  27.16M   219KB/s    eta 2m 14s
# physionet.org/files  37%[======>             ]  27.22M   219KB/s    eta 2m 14s
# physionet.org/files  37%[======>             ]  27.25M   214KB/s    eta 2m 14s
# physionet.org/files  37%[======>             ]  27.34M   229KB/s    eta 2m 14s
# physionet.org/files  37%[======>             ]  27.39M   229KB/s    eta 2m 14s
# physionet.org/files  37%[======>             ]  27.44M   232KB/s    eta 2m 14s
# physionet.org/files  37%[======>             ]  27.48M   233KB/s    eta 2m 14s
# physionet.org/files  37%[======>             ]  27.55M   236KB/s    eta 2m 14s
# physionet.org/files  37%[======>             ]  27.61M   241KB/s    eta 2m 14s
# physionet.org/files  37%[======>             ]  27.67M   245KB/s    eta 2m 14s
# physionet.org/files  37%[======>             ]  27.73M   253KB/s    eta 2m 13s
# physionet.org/files  37%[======>             ]  27.81M   261KB/s    eta 2m 13s
# physionet.org/files  37%[======>             ]  27.83M   255KB/s    eta 2m 13s
# physionet.org/files  38%[======>             ]  27.92M   264KB/s    eta 2m 13s
# physionet.org/files  38%[======>             ]  27.97M   264KB/s    eta 2m 13s
# physionet.org/files  38%[======>             ]  28.01M   264KB/s    eta 2m 13s
# physionet.org/files  38%[======>             ]  28.08M   267KB/s    eta 2m 13s
# physionet.org/files  38%[======>             ]  28.14M   270KB/s    eta 2m 13s
# physionet.org/files  38%[======>             ]  28.20M   270KB/s    eta 2m 13s
# physionet.org/files  38%[======>             ]  28.26M   280KB/s    eta 2m 13s
# physionet.org/files  38%[======>             ]  28.33M   274KB/s    eta 2m 12s
# physionet.org/files  38%[======>             ]  28.39M   278KB/s    eta 2m 12s
# physionet.org/files  38%[======>             ]  28.47M   285KB/s    eta 2m 12s
# physionet.org/files  38%[======>             ]  28.55M   287KB/s    eta 2m 12s
# physionet.org/files  39%[======>             ]  28.62M   291KB/s    eta 2m 12s
# physionet.org/files  39%[======>             ]  28.70M   296KB/s    eta 2m 11s
# physionet.org/files  39%[======>             ]  28.78M   297KB/s    eta 2m 11s
# physionet.org/files  39%[======>             ]  28.86M   314KB/s    eta 2m 11s
# physionet.org/files  39%[======>             ]  28.94M   311KB/s    eta 2m 11s
# physionet.org/files  39%[======>             ]  29.03M   324KB/s    eta 2m 11s
# physionet.org/files  39%[======>             ]  29.12M   336KB/s    eta 2m 10s
# physionet.org/files  39%[======>             ]  29.19M   337KB/s    eta 2m 10s
# physionet.org/files  39%[======>             ]  29.25M   339KB/s    eta 2m 10s
# physionet.org/files  40%[=======>            ]  29.33M   344KB/s    eta 2m 10s
# physionet.org/files  40%[=======>            ]  29.41M   347KB/s    eta 2m 10s
# physionet.org/files  40%[=======>            ]  29.48M   354KB/s    eta 2m 9s
# physionet.org/files  40%[=======>            ]  29.58M   361KB/s    eta 2m 9s
# physionet.org/files  40%[=======>            ]  29.67M   369KB/s    eta 2m 9s
# physionet.org/files  40%[=======>            ]  29.76M   376KB/s    eta 2m 9s
# physionet.org/files  40%[=======>            ]  29.86M   382KB/s    eta 2m 9s
# physionet.org/files  40%[=======>            ]  29.94M   369KB/s    eta 2m 7s
# physionet.org/files  40%[=======>            ]  30.03M   372KB/s    eta 2m 7s
# physionet.org/files  41%[=======>            ]  30.09M   359KB/s    eta 2m 7s
# physionet.org/files  41%[=======>            ]  30.14M   348KB/s    eta 2m 7s
# physionet.org/files  41%[=======>            ]  30.19M   340KB/s    eta 2m 7s
# physionet.org/files  41%[=======>            ]  30.25M   342KB/s    eta 2m 7s
# physionet.org/files  41%[=======>            ]  30.30M   318KB/s    eta 2m 7s
# physionet.org/files  41%[=======>            ]  30.36M   314KB/s    eta 2m 7s
# physionet.org/files  41%[=======>            ]  30.41M   304KB/s    eta 2m 7s
# physionet.org/files  41%[=======>            ]  30.45M   301KB/s    eta 2m 7s
# physionet.org/files  41%[=======>            ]  30.51M   291KB/s    eta 2m 7s
# physionet.org/files  41%[=======>            ]  30.56M   288KB/s    eta 2m 7s
# physionet.org/files  41%[=======>            ]  30.62M   278KB/s    eta 2m 7s
# physionet.org/files  41%[=======>            ]  30.67M   272KB/s    eta 2m 7s
# physionet.org/files  41%[=======>            ]  30.73M   259KB/s    eta 2m 7s
# physionet.org/files  42%[=======>            ]  30.80M   251KB/s    eta 2m 6s
# physionet.org/files  42%[=======>            ]  30.86M   255KB/s    eta 2m 6s
# physionet.org/files  42%[=======>            ]  30.92M   249KB/s    eta 2m 6s
# physionet.org/files  42%[=======>            ]  30.98M   253KB/s    eta 2m 6s
# physionet.org/files  42%[=======>            ]  31.03M   249KB/s    eta 2m 6s
# physionet.org/files  42%[=======>            ]  31.11M   258KB/s    eta 2m 5s
# physionet.org/files  42%[=======>            ]  31.14M   252KB/s    eta 2m 5s
# physionet.org/files  42%[=======>            ]  31.20M   253KB/s    eta 2m 5s
# physionet.org/files  42%[=======>            ]  31.25M   250KB/s    eta 2m 5s
# physionet.org/files  42%[=======>            ]  31.30M   253KB/s    eta 2m 5s
# physionet.org/files  42%[=======>            ]  31.34M   253KB/s    eta 2m 5s
# physionet.org/files  42%[=======>            ]  31.39M   252KB/s    eta 2m 5s
# physionet.org/files  42%[=======>            ]  31.45M   252KB/s    eta 2m 5s
# physionet.org/files  42%[=======>            ]  31.51M   251KB/s    eta 2m 5s
# physionet.org/files  43%[=======>            ]  31.58M   253KB/s    eta 2m 5s
# physionet.org/files  43%[=======>            ]  31.64M   253KB/s    eta 2m 5s
# physionet.org/files  43%[=======>            ]  31.67M   245KB/s    eta 2m 5s
# physionet.org/files  43%[=======>            ]  31.75M   249KB/s    eta 2m 5s
# physionet.org/files  43%[=======>            ]  31.81M   245KB/s    eta 2m 5s
# physionet.org/files  43%[=======>            ]  31.87M   243KB/s    eta 2m 5s
# physionet.org/files  43%[=======>            ]  31.92M   243KB/s    eta 2m 4s
# physionet.org/files  43%[=======>            ]  31.98M   239KB/s    eta 2m 4s
# physionet.org/files  43%[=======>            ]  32.05M   247KB/s    eta 2m 4s
# physionet.org/files  43%[=======>            ]  32.11M   249KB/s    eta 2m 4s
# physionet.org/files  43%[=======>            ]  32.17M   253KB/s    eta 2m 4s
# physionet.org/files  43%[=======>            ]  32.23M   257KB/s    eta 2m 4s
# physionet.org/files  44%[=======>            ]  32.30M   264KB/s    eta 2m 4s
# physionet.org/files  44%[=======>            ]  32.37M   270KB/s    eta 2m 4s
# physionet.org/files  44%[=======>            ]  32.44M   273KB/s    eta 2m 4s
# physionet.org/files  44%[=======>            ]  32.51M   278KB/s    eta 2m 4s
# physionet.org/files  44%[=======>            ]  32.59M   283KB/s    eta 2m 3s
# physionet.org/files  44%[=======>            ]  32.64M   286KB/s    eta 2m 3s
# physionet.org/files  44%[=======>            ]  32.73M   291KB/s    eta 2m 3s
# physionet.org/files  44%[=======>            ]  32.80M   295KB/s    eta 2m 3s
# physionet.org/files  44%[=======>            ]  32.86M   299KB/s    eta 2m 3s
# physionet.org/files  44%[=======>            ]  32.94M   307KB/s    eta 2m 2s
# physionet.org/files  45%[========>           ]  33.01M   312KB/s    eta 2m 2s
# physionet.org/files  45%[========>           ]  33.09M   315KB/s    eta 2m 2s
# physionet.org/files  45%[========>           ]  33.17M   318KB/s    eta 2m 2s
# physionet.org/files  45%[========>           ]  33.26M   326KB/s    eta 2m 2s
# physionet.org/files  45%[========>           ]  33.34M   331KB/s    eta 2m 1s
# physionet.org/files  45%[========>           ]  33.42M   337KB/s    eta 2m 1s
# physionet.org/files  45%[========>           ]  33.50M   329KB/s    eta 2m 1s
# physionet.org/files  45%[========>           ]  33.61M   344KB/s    eta 2m 1s
# physionet.org/files  45%[========>           ]  33.67M   339KB/s    eta 2m 1s
# physionet.org/files  46%[========>           ]  33.75M   340KB/s    eta 1m 59s
# physionet.org/files  46%[========>           ]  33.83M   350KB/s    eta 1m 59s
# physionet.org/files  46%[========>           ]  33.91M   343KB/s    eta 1m 59s
# physionet.org/files  46%[========>           ]  33.98M   336KB/s    eta 1m 59s
# physionet.org/files  46%[========>           ]  34.09M   350KB/s    eta 1m 58s
# physionet.org/files  46%[========>           ]  34.16M   347KB/s    eta 1m 58s
# physionet.org/files  46%[========>           ]  34.22M   346KB/s    eta 1m 58s
# physionet.org/files  46%[========>           ]  34.28M   340KB/s    eta 1m 58s
# physionet.org/files  46%[========>           ]  34.34M   330KB/s    eta 1m 58s
# physionet.org/files  46%[========>           ]  34.44M   329KB/s    eta 1m 57s
# physionet.org/files  47%[========>           ]  34.50M   325KB/s    eta 1m 57s
# physionet.org/files  47%[========>           ]  34.56M   320KB/s    eta 1m 57s
# physionet.org/files  47%[========>           ]  34.62M   316KB/s    eta 1m 57s
# physionet.org/files  47%[========>           ]  34.69M   313KB/s    eta 1m 57s
# physionet.org/files  47%[========>           ]  34.75M   309KB/s    eta 1m 57s
# physionet.org/files  47%[========>           ]  34.81M   308KB/s    eta 1m 57s
# physionet.org/files  47%[========>           ]  34.86M   303KB/s    eta 1m 57s
# physionet.org/files  47%[========>           ]  34.91M   297KB/s    eta 1m 57s
# physionet.org/files  47%[========>           ]  34.97M   293KB/s    eta 1m 57s
# physionet.org/files  47%[========>           ]  35.05M   290KB/s    eta 1m 56s
# physionet.org/files  47%[========>           ]  35.11M   300KB/s    eta 1m 56s
# physionet.org/files  47%[========>           ]  35.17M   286KB/s    eta 1m 56s
# physionet.org/files  48%[========>           ]  35.25M   280KB/s    eta 1m 56s
# physionet.org/files  48%[========>           ]  35.34M   287KB/s    eta 1m 55s
# physionet.org/files  48%[========>           ]  35.39M   276KB/s    eta 1m 55s
# physionet.org/files  48%[========>           ]  35.47M   285KB/s    eta 1m 55s
# physionet.org/files  48%[========>           ]  35.51M   273KB/s    eta 1m 55s
# physionet.org/files  48%[========>           ]  35.56M   270KB/s    eta 1m 55s
# physionet.org/files  48%[========>           ]  35.61M   266KB/s    eta 1m 55s
# physionet.org/files  48%[========>           ]  35.66M   264KB/s    eta 1m 55s
# physionet.org/files  48%[========>           ]  35.72M   259KB/s    eta 1m 55s
# physionet.org/files  48%[========>           ]  35.78M   256KB/s    eta 1m 55s
# physionet.org/files  48%[========>           ]  35.84M   256KB/s    eta 1m 54s
# physionet.org/files  48%[========>           ]  35.89M   252KB/s    eta 1m 54s
# physionet.org/files  49%[========>           ]  35.97M   256KB/s    eta 1m 54s
# physionet.org/files  49%[========>           ]  36.01M   241KB/s    eta 1m 54s
# physionet.org/files  49%[========>           ]  36.08M   242KB/s    eta 1m 54s
# physionet.org/files  49%[========>           ]  36.12M   235KB/s    eta 1m 54s
# physionet.org/files  49%[========>           ]  36.17M   232KB/s    eta 1m 54s
# physionet.org/files  49%[========>           ]  36.22M   222KB/s    eta 1m 54s
# physionet.org/files  49%[========>           ]  36.26M   227KB/s    eta 1m 54s
# physionet.org/files  49%[========>           ]  36.31M   219KB/s    eta 1m 54s
# physionet.org/files  49%[========>           ]  36.37M   222KB/s    eta 1m 54s
# physionet.org/files  49%[========>           ]  36.44M   228KB/s    eta 1m 54s
# physionet.org/files  49%[========>           ]  36.50M   232KB/s    eta 1m 54s
# physionet.org/files  49%[========>           ]  36.56M   235KB/s    eta 1m 54s
# physionet.org/files  49%[========>           ]  36.62M   237KB/s    eta 1m 53s
# physionet.org/files  50%[=========>          ]  36.69M   240KB/s    eta 1m 53s
# physionet.org/files  50%[=========>          ]  36.75M   243KB/s    eta 1m 53s
# physionet.org/files  50%[=========>          ]  36.80M   246KB/s    eta 1m 53s
# physionet.org/files  50%[=========>          ]  36.86M   244KB/s    eta 1m 53s
# physionet.org/files  50%[=========>          ]  36.92M   255KB/s    eta 1m 52s
# physionet.org/files  50%[=========>          ]  36.98M   254KB/s    eta 1m 52s
# physionet.org/files  50%[=========>          ]  37.05M   261KB/s    eta 1m 52s
# physionet.org/files  50%[=========>          ]  37.11M   267KB/s    eta 1m 52s
# physionet.org/files  50%[=========>          ]  37.19M   278KB/s    eta 1m 52s
# physionet.org/files  50%[=========>          ]  37.25M   283KB/s    eta 1m 51s
# physionet.org/files  50%[=========>          ]  37.33M   292KB/s    eta 1m 51s
# physionet.org/files  51%[=========>          ]  37.41M   296KB/s    eta 1m 51s
# physionet.org/files  51%[=========>          ]  37.45M   292KB/s    eta 1m 51s
# physionet.org/files  51%[=========>          ]  37.56M   301KB/s    eta 1m 51s
# physionet.org/files  51%[=========>          ]  37.62M   300KB/s    eta 1m 50s
# physionet.org/files  51%[=========>          ]  37.70M   304KB/s    eta 1m 50s
# physionet.org/files  51%[=========>          ]  37.73M   296KB/s    eta 1m 50s
# physionet.org/files  51%[=========>          ]  37.81M   308KB/s    eta 1m 50s
# physionet.org/files  51%[=========>          ]  37.87M   299KB/s    eta 1m 50s
# physionet.org/files  51%[=========>          ]  37.92M   298KB/s    eta 1m 50s
# physionet.org/files  51%[=========>          ]  37.95M   290KB/s    eta 1m 50s
# physionet.org/files  51%[=========>          ]  38.01M   291KB/s    eta 1m 50s
# physionet.org/files  51%[=========>          ]  38.06M   286KB/s    eta 1m 50s
# physionet.org/files  51%[=========>          ]  38.11M   282KB/s    eta 1m 50s
# physionet.org/files  52%[=========>          ]  38.17M   278KB/s    eta 1m 49s
# physionet.org/files  52%[=========>          ]  38.22M   274KB/s    eta 1m 49s
# physionet.org/files  52%[=========>          ]  38.28M   274KB/s    eta 1m 49s
# physionet.org/files  52%[=========>          ]  38.34M   269KB/s    eta 1m 49s
# physionet.org/files  52%[=========>          ]  38.39M   261KB/s    eta 1m 49s
# physionet.org/files  52%[=========>          ]  38.44M   261KB/s    eta 1m 49s
# physionet.org/files  52%[=========>          ]  38.47M   240KB/s    eta 1m 49s
# physionet.org/files  52%[=========>          ]  38.51M   231KB/s    eta 1m 49s
# physionet.org/files  52%[=========>          ]  38.55M   221KB/s    eta 1m 49s
# physionet.org/files  52%[=========>          ]  38.59M   215KB/s    eta 1m 49s
# physionet.org/files  52%[=========>          ]  38.64M   212KB/s    eta 1m 49s
# physionet.org/files  52%[=========>          ]  38.69M   207KB/s    eta 1m 49s
# physionet.org/files  52%[=========>          ]  38.73M   203KB/s    eta 1m 49s
# physionet.org/files  52%[=========>          ]  38.78M   204KB/s    eta 1m 48s
# physionet.org/files  52%[=========>          ]  38.83M   200KB/s    eta 1m 48s
# physionet.org/files  53%[=========>          ]  38.87M   199KB/s    eta 1m 48s
# physionet.org/files  53%[=========>          ]  38.92M   186KB/s    eta 1m 48s
# physionet.org/files  53%[=========>          ]  38.98M   184KB/s    eta 1m 48s
# physionet.org/files  53%[=========>          ]  39.01M   177KB/s    eta 1m 48s
# physionet.org/files  53%[=========>          ]  39.06M   178KB/s    eta 1m 48s
# physionet.org/files  53%[=========>          ]  39.11M   178KB/s    eta 1m 48s
# physionet.org/files  53%[=========>          ]  39.16M   182KB/s    eta 1m 48s
# physionet.org/files  53%[=========>          ]  39.19M   178KB/s    eta 1m 48s
# physionet.org/files  53%[=========>          ]  39.23M   180KB/s    eta 1m 48s
# physionet.org/files  53%[=========>          ]  39.26M   178KB/s    eta 1m 48s
# physionet.org/files  53%[=========>          ]  39.31M   178KB/s    eta 1m 48s
# physionet.org/files  53%[=========>          ]  39.36M   177KB/s    eta 1m 48s
# physionet.org/files  53%[=========>          ]  39.41M   177KB/s    eta 1m 48s
# physionet.org/files  53%[=========>          ]  39.45M   180KB/s    eta 1m 48s
# physionet.org/files  53%[=========>          ]  39.50M   180KB/s    eta 1m 48s
# physionet.org/files  53%[=========>          ]  39.55M   182KB/s    eta 1m 48s
# physionet.org/files  54%[=========>          ]  39.59M   185KB/s    eta 1m 47s
# physionet.org/files  54%[=========>          ]  39.62M   181KB/s    eta 1m 47s
# physionet.org/files  54%[=========>          ]  39.69M   185KB/s    eta 1m 47s
# physionet.org/files  54%[=========>          ]  39.73M   186KB/s    eta 1m 47s
# physionet.org/files  54%[=========>          ]  39.78M   189KB/s    eta 1m 47s
# physionet.org/files  54%[=========>          ]  39.83M   193KB/s    eta 1m 47s
# physionet.org/files  54%[=========>          ]  39.87M   195KB/s    eta 1m 47s
# physionet.org/files  54%[=========>          ]  39.92M   195KB/s    eta 1m 47s
# physionet.org/files  54%[=========>          ]  39.97M   196KB/s    eta 1m 47s
# physionet.org/files  54%[=========>          ]  40.01M   197KB/s    eta 1m 47s
# physionet.org/files  54%[=========>          ]  40.06M   195KB/s    eta 1m 47s
# physionet.org/files  54%[=========>          ]  40.12M   197KB/s    eta 1m 47s
# physionet.org/files  54%[=========>          ]  40.16M   194KB/s    eta 1m 47s
# physionet.org/files  54%[=========>          ]  40.19M   191KB/s    eta 1m 47s
# physionet.org/files  54%[=========>          ]  40.22M   185KB/s    eta 1m 47s
# physionet.org/files  54%[=========>          ]  40.25M   179KB/s    eta 1m 47s
# physionet.org/files  54%[=========>          ]  40.28M   173KB/s    eta 1m 47s
# physionet.org/files  54%[=========>          ]  40.30M   166KB/s    eta 1m 47s
# physionet.org/files  55%[==========>         ]  40.33M   166KB/s    eta 1m 47s
# physionet.org/files  55%[==========>         ]  40.36M   160KB/s    eta 1m 47s
# physionet.org/files  55%[==========>         ]  40.39M   156KB/s    eta 1m 47s
# ...
# physionet.org/files  98%[==================> ] 132.81M   214KB/s    eta 10s
# physionet.org/files  98%[==================> ] 132.87M   212KB/s    eta 10s
# physionet.org/files  98%[==================> ] 132.94M   222KB/s    eta 10s
# physionet.org/files  98%[==================> ] 133.00M   225KB/s    eta 10s
# physionet.org/files  98%[==================> ] 133.03M   220KB/s    eta 10s
# physionet.org/files  98%[==================> ] 133.12M   232KB/s    eta 8s
# physionet.org/files  98%[==================> ] 133.17M   236KB/s    eta 8s
# physionet.org/files  98%[==================> ] 133.23M   243KB/s    eta 8s
# physionet.org/files  98%[==================> ] 133.28M   244KB/s    eta 8s
# physionet.org/files  98%[==================> ] 133.34M   248KB/s    eta 8s
# physionet.org/files  98%[==================> ] 133.41M   252KB/s    eta 7s
# physionet.org/files  98%[==================> ] 133.47M   256KB/s    eta 7s
# physionet.org/files  98%[==================> ] 133.53M   257KB/s    eta 7s
# physionet.org/files  98%[==================> ] 133.59M   258KB/s    eta 7s
# physionet.org/files  98%[==================> ] 133.66M   261KB/s    eta 7s
# physionet.org/files  98%[==================> ] 133.72M   260KB/s    eta 6s
# physionet.org/files  98%[==================> ] 133.80M   271KB/s    eta 6s
# physionet.org/files  98%[==================> ] 133.86M   271KB/s    eta 6s
# physionet.org/files  98%[==================> ] 133.92M   274KB/s    eta 6s
# physionet.org/files  98%[==================> ] 133.98M   272KB/s    eta 6s
# physionet.org/files  99%[==================> ] 134.05M   272KB/s    eta 5s
# physionet.org/files  99%[==================> ] 134.11M   283KB/s    eta 5s
# physionet.org/files  99%[==================> ] 134.19M   280KB/s    eta 5s
# physionet.org/files  99%[==================> ] 134.25M   286KB/s    eta 5s
# physionet.org/files  99%[==================> ] 134.33M   289KB/s    eta 5s
# physionet.org/files  99%[==================> ] 134.41M   302KB/s    eta 4s
# physionet.org/files  99%[==================> ] 134.48M   305KB/s    eta 4s
# physionet.org/files  99%[==================> ] 134.56M   308KB/s    eta 4s
# physionet.org/files  99%[==================> ] 134.61M   300KB/s    eta 4s
# physionet.org/files  99%[==================> ] 134.72M   312KB/s    eta 4s
# physionet.org/files  99%[==================> ] 134.75M   300KB/s    eta 2s
# physionet.org/files  99%[==================> ] 134.83M   303KB/s    eta 2s
# physionet.org/files  99%[==================> ] 134.87M   298KB/s    eta 2s
# physionet.org/files  99%[==================> ] 134.92M   290KB/s    eta 2s
# physionet.org/files  99%[==================> ] 134.98M   290KB/s    eta 2s
# physionet.org/files  99%[==================> ] 135.03M   287KB/s    eta 1s
# physionet.org/files  99%[==================> ] 135.09M   287KB/s    eta 1s
# physionet.org/files  99%[==================> ] 135.16M   286KB/s    eta 1s
# physionet.org/files  99%[==================> ] 135.22M   287KB/s    eta 1s
# physionet.org/files  99%[==================> ] 135.28M   287KB/s    eta 1s
# physionet.org/files  99%[==================> ] 135.34M   284KB/s    eta 0s
# physionet.org/files 100%[===================>] 135.37M   283KB/s    in 8m 32s
#
# 2025-11-10 12:43:57 (271 KB/s) - 'physionet.org/files/mimic-cxr/2.1.0/mimic-cxr-reports.zip' saved [141942511/141942511]
#
# --2025-11-10 12:43:57--  https://physionet.org/files/mimic-cxr/2.1.0/files/p10/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'physionet.org/files/mimic-cxr/2.1.0/files/p10/index.html'
#
#
# physionet.org/files     [<=>                 ]       0  --.-KB/s
# physionet.org/files     [ <=>                ] 463.74K  2.16MB/s
# physionet.org/files     [  <=>               ] 543.74K  1.25MB/s
# physionet.org/files     [   <=>              ] 639.74K   987KB/s
# physionet.org/files     [    <=>             ] 718.65K   856KB/s    in 0.8s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-11-10 12:43:59 (856 KB/s) - 'physionet.org/files/mimic-cxr/2.1.0/files/p10/index.html' saved [735900]
#
# --2025-11-10 12:44:00--  https://physionet.org/files/mimic-cxr/2.1.0/files/p11/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'physionet.org/files/mimic-cxr/2.1.0/files/p11/index.html'
#
#
# physionet.org/files     [<=>                 ]       0  --.-KB/s
# physionet.org/files     [ <=>                ] 335.74K  1.51MB/s
# physionet.org/files     [  <=>               ] 399.74K   817KB/s
# physionet.org/files     [   <=>              ] 415.74K   597KB/s
# physionet.org/files     [    <=>             ] 495.74K   528KB/s
# physionet.org/files     [     <=>            ] 543.74K   465KB/s
# physionet.org/files     [      <=>           ] 591.74K   429KB/s
# physionet.org/files     [       <=>          ] 639.74K   402KB/s
# physionet.org/files     [        <=>         ] 687.74K   382KB/s
# physionet.org/files     [         <=>        ] 738.19K   368KB/s
# physionet.org/files     [          <=>       ] 738.19K   368KB/s    in 2.0s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-11-10 12:44:03 (368 KB/s) - 'physionet.org/files/mimic-cxr/2.1.0/files/p11/index.html' saved [755910]
#
# --2025-11-10 12:44:03--  https://physionet.org/files/mimic-cxr/2.1.0/files/p12/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'physionet.org/files/mimic-cxr/2.1.0/files/p12/index.html'
#
#
# physionet.org/files     [<=>                 ]       0  --.-KB/s
# physionet.org/files     [ <=>                ] 319.74K  1.30MB/s
# physionet.org/files     [  <=>               ] 383.74K   803KB/s
# physionet.org/files     [   <=>              ] 431.74K   613KB/s
# physionet.org/files     [    <=>             ] 479.74K   457KB/s
# physionet.org/files     [     <=>            ] 511.74K   390KB/s
# physionet.org/files     [      <=>           ] 543.74K   350KB/s
# physionet.org/files     [       <=>          ] 575.74K   294KB/s
# physionet.org/files     [        <=>         ] 623.74K   272KB/s
# physionet.org/files     [         <=>        ] 655.74K   248KB/s
# physionet.org/files     [          <=>       ] 687.74K   231KB/s
# physionet.org/files     [           <=>      ] 719.74K   217KB/s
# physionet.org/files     [            <=>     ] 733.36K   213KB/s    in 3.4s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-11-10 12:44:08 (213 KB/s) - 'physionet.org/files/mimic-cxr/2.1.0/files/p12/index.html' saved [750965]
#
# --2025-11-10 12:44:08--  https://physionet.org/files/mimic-cxr/2.1.0/files/p13/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'physionet.org/files/mimic-cxr/2.1.0/files/p13/index.html'
#
#
# physionet.org/files     [<=>                 ]       0  --.-KB/s
# physionet.org/files     [ <=>                ] 239.74K  1.07MB/s
# physionet.org/files     [  <=>               ] 287.74K   656KB/s
# physionet.org/files     [   <=>              ] 335.74K   510KB/s
# physionet.org/files     [    <=>             ] 399.74K   431KB/s
# physionet.org/files     [     <=>            ] 463.74K   398KB/s
# physionet.org/files     [      <=>           ] 527.74K   380KB/s
# physionet.org/files     [       <=>          ] 591.74K   359KB/s
# physionet.org/files     [        <=>         ] 671.74K   356KB/s
# physionet.org/files     [         <=>        ] 735.74K   347KB/s
# physionet.org/files     [          <=>       ] 735.83K   347KB/s    in 2.1s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-11-10 12:44:11 (347 KB/s) - 'physionet.org/files/mimic-cxr/2.1.0/files/p13/index.html' saved [753495]
#
# --2025-11-10 12:44:12--  https://physionet.org/files/mimic-cxr/2.1.0/files/p14/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'physionet.org/files/mimic-cxr/2.1.0/files/p14/index.html'
#
#
# physionet.org/files     [<=>                 ]       0  --.-KB/s
# physionet.org/files     [ <=>                ] 351.74K  1.34MB/s
# physionet.org/files     [  <=>               ] 399.74K   827KB/s
# physionet.org/files     [   <=>              ] 447.74K   631KB/s
# physionet.org/files     [    <=>             ] 495.74K   531KB/s
# physionet.org/files     [     <=>            ] 543.74K   471KB/s
# physionet.org/files     [      <=>           ] 591.74K   432KB/s
# physionet.org/files     [       <=>          ] 655.74K   377KB/s
# physionet.org/files     [        <=>         ] 731.01K   366KB/s
# physionet.org/files     [         <=>        ] 731.01K   366KB/s    in 2.0s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-11-10 12:44:15 (366 KB/s) - 'physionet.org/files/mimic-cxr/2.1.0/files/p14/index.html' saved [748550]
#
# --2025-11-10 12:44:15--  https://physionet.org/files/mimic-cxr/2.1.0/files/p15/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'physionet.org/files/mimic-cxr/2.1.0/files/p15/index.html'
#
#
# physionet.org/files     [<=>                 ]       0  --.-KB/s
# physionet.org/files     [ <=>                ] 287.74K  1.07MB/s
# physionet.org/files     [  <=>               ] 319.74K   619KB/s
# physionet.org/files     [   <=>              ] 367.74K   491KB/s
# physionet.org/files     [    <=>             ] 399.74K   416KB/s
# physionet.org/files     [     <=>            ] 447.74K   371KB/s
# physionet.org/files     [      <=>           ] 495.74K   322KB/s
# physionet.org/files     [       <=>          ] 543.74K   302KB/s
# physionet.org/files     [        <=>         ] 575.74K   285KB/s
# physionet.org/files     [         <=>        ] 623.74K   271KB/s
# physionet.org/files     [          <=>       ] 671.74K   262KB/s
# physionet.org/files     [           <=>      ] 719.74K   254KB/s
# physionet.org/files     [            <=>     ] 740.66K   249KB/s    in 3.0s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-11-10 12:44:19 (249 KB/s) - 'physionet.org/files/mimic-cxr/2.1.0/files/p15/index.html' saved [758440]
#
# --2025-11-10 12:44:20--  https://physionet.org/files/mimic-cxr/2.1.0/files/p16/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'physionet.org/files/mimic-cxr/2.1.0/files/p16/index.html'
#
#
# physionet.org/files     [<=>                 ]       0  --.-KB/s
# physionet.org/files     [ <=>                ] 335.74K  1.52MB/s
# physionet.org/files     [  <=>               ] 383.74K   761KB/s
# physionet.org/files     [   <=>              ] 463.74K   643KB/s
# physionet.org/files     [    <=>             ] 479.74K   502KB/s
# physionet.org/files     [     <=>            ] 559.74K   449KB/s
# physionet.org/files     [      <=>           ] 607.74K   408KB/s
# physionet.org/files     [       <=>          ] 655.74K   375KB/s
# physionet.org/files     [        <=>         ] 703.74K   356KB/s
# physionet.org/files     [         <=>        ] 727.52K   346KB/s    in 2.1s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-11-10 12:44:23 (346 KB/s) - 'physionet.org/files/mimic-cxr/2.1.0/files/p16/index.html' saved [744985]
#
# --2025-11-10 12:44:23--  https://physionet.org/files/mimic-cxr/2.1.0/files/p17/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'physionet.org/files/mimic-cxr/2.1.0/files/p17/index.html'
#
#
# physionet.org/files     [<=>                 ]       0  --.-KB/s
# physionet.org/files     [ <=>                ] 255.74K   901KB/s
# physionet.org/files     [  <=>               ] 287.74K   577KB/s
# physionet.org/files     [   <=>              ] 335.74K   430KB/s
# physionet.org/files     [    <=>             ] 367.74K   337KB/s
# physionet.org/files     [     <=>            ] 415.74K   303KB/s
# physionet.org/files     [      <=>           ] 447.74K   279KB/s
# physionet.org/files     [       <=>          ] 479.74K   265KB/s
# physionet.org/files     [        <=>         ] 511.74K   251KB/s
# physionet.org/files     [         <=>        ] 543.74K   235KB/s
# physionet.org/files     [          <=>       ] 575.74K   227KB/s
# physionet.org/files     [           <=>      ] 607.74K   217KB/s
# physionet.org/files     [            <=>     ] 639.74K   212KB/s
# physionet.org/files     [             <=>    ] 687.74K   208KB/s
# physionet.org/files     [              <=>   ] 719.74K   205KB/s
# physionet.org/files     [               <=>  ] 746.39K   202KB/s    in 3.7s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-11-10 12:44:28 (202 KB/s) - 'physionet.org/files/mimic-cxr/2.1.0/files/p17/index.html' saved [764305]
#
# --2025-11-10 12:44:29--  https://physionet.org/files/mimic-cxr/2.1.0/files/p18/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'physionet.org/files/mimic-cxr/2.1.0/files/p18/index.html'
#
#
# physionet.org/files     [<=>                 ]       0  --.-KB/s
# physionet.org/files     [ <=>                ] 239.74K  1.07MB/s
# physionet.org/files     [  <=>               ] 271.74K   646KB/s
# physionet.org/files     [   <=>              ] 319.74K   483KB/s
# physionet.org/files     [    <=>             ] 367.74K   398KB/s
# physionet.org/files     [     <=>            ] 415.74K   348KB/s
# physionet.org/files     [      <=>           ] 447.74K   308KB/s
# physionet.org/files     [       <=>          ] 511.74K   293KB/s
# physionet.org/files     [        <=>         ] 527.74K   264KB/s
# physionet.org/files     [         <=>        ] 575.74K   259KB/s
# physionet.org/files     [          <=>       ] 607.74K   248KB/s
# physionet.org/files     [           <=>      ] 639.74K   236KB/s
# physionet.org/files     [            <=>     ] 671.74K   229KB/s
# physionet.org/files     [             <=>    ] 703.74K   223KB/s
# physionet.org/files     [              <=>   ] 735.05K   219KB/s    in 3.4s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-11-10 12:44:33 (219 KB/s) - 'physionet.org/files/mimic-cxr/2.1.0/files/p18/index.html' saved [752690]
#
# --2025-11-10 12:44:34--  https://physionet.org/files/mimic-cxr/2.1.0/files/p19/
# Reusing existing connection to physionet.org:443.

# %% [markdown]
# ## 2.2 `Check files`

# %%
import os
import hashlib
from pathlib import Path

# --- Step 1: Define and check the base location ---
# location = Path("E:/Data/MIMIC_IV")  # example path — adjust for your setup
if 'location' not in locals():
    location = Path(input("Enter download location (full path): "))

print(f"\n✅ Checking data in folder: {location}")


# --- Step 2: Define checksum file path ---
checksum_file = location / "SHA256SUMS.txt"
if not checksum_file.exists():
    raise FileNotFoundError(f"Checksum file not found: {checksum_file}")

# --- Step 3: Load checksums ---
checksums = {}
with open(checksum_file, "r", encoding="utf-8") as f:
    for line in f:
        hash_val, rel_path = line.split(" ")
        cur_path = location / rel_path.strip()
        checksums[ cur_path ] = hash_val.strip()

print(f"Found {len(checksums)} entries in {checksum_file.name}")


# --- Step 4: Verify files ---
def sha256sum(file_path):
    """Compute SHA256 hash for a file."""
    h = hashlib.sha256()
    with open(file_path, "rb") as f:
        for chunk in iter(lambda: f.read(8192), b""):
            h.update(chunk)
    return h.hexdigest()

results = []
for rel_path, expected_hash in checksums.items():
    file_path = location / rel_path
    if not file_path.exists():
        results.append((rel_path, "❌ Missing", None))
        continue

    actual_hash = sha256sum(file_path)
    if actual_hash.lower() == expected_hash.lower():
        results.append((rel_path, "✅ OK", actual_hash))
    else:
        results.append((rel_path, "⚠️ Mismatch", actual_hash))

# --- Step 5: Display results ---
print("\n=== Verification Report ===")
for rel_path, status, actual in results:
    print(f"{status:10s}  {rel_path}")

# Optional: summary counts
ok = sum(1 for r in results if "OK" in r[1])
missing = sum(1 for r in results if "Missing" in r[1])
mismatch = sum(1 for r in results if "Mismatch" in r[1])
print(f"\nSummary: {ok} OK, {missing} Missing, {mismatch} Mismatch\n")
